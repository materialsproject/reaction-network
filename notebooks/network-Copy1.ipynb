# %% [markdown]
# # reaction-network (Demo Notebook): Networks
#
# ### Author: Matthew McDermott
# Last Updated: 12/12/21
#
# The code provided in this notebook is an updated walkthrough of the first example (YMnO3) in the accompanying manuscript (see citation below). The refactored `reaction-network` package contains similar code to what was released with the manuscript; however, many processes/functions are now separated into their own defined classes/methods. For a look at the previous demo notebook (which also contained some of the raw results that went into the manuscript), please check out the _archived_ folder.
#
# **If you use this code or Python package in your work, please consider citing the following paper:**
#
# McDermott, M. J., Dwaraknath, S. S., and Persson, K. A. (2021). A graph-based network for predicting chemical reaction pathways in solid-state materials synthesis.
# Nature Communications, 12(1). https://doi.org/10.1038/s41467-021-23339-x

# %% [markdown]
# ### Imports

# %%
import logging 

from pymatgen.ext.matproj import MPRester
from rxn_network.enumerators.basic import BasicEnumerator, BasicOpenEnumerator
from rxn_network.enumerators.minimize import MinimizeGibbsEnumerator, MinimizeGrandPotentialEnumerator
from pymatgen.analysis.phase_diagram import PhaseDiagram, PDPlotter
from rxn_network.thermo.chempot_diagram import ChemicalPotentialDiagram

from rxn_network.costs.softplus import Softplus
from pymatgen.core.composition import Composition, Element
from rxn_network.entries.entry_set import GibbsEntrySet
from rxn_network.network.network import ReactionNetwork
from rxn_network.entries.nist import NISTReferenceEntry
from rxn_network.reactions.computed import ComputedReaction
from rxn_network.reactions.reaction_set import ReactionSet
from rxn_network.reactions.open import OpenComputedReaction
from rxn_network.network.entry import NetworkEntry, NetworkEntryType
from rxn_network.network.visualize import plot_network_on_graphistry, plot_network
from rxn_network.pathways.solver import PathwaySolver

#import graphistry

# %load_ext autoreload
# %autoreload 2

logging.info("Logging initialized")

# %% [markdown]
# ### Case Study: YMnO3 assisted metathesis

# %% [markdown]
# We will be using the assisted metathesis synthesis of YMnO3 as a case study for the reaction network code. This is the first example discussed in the original manuscript. The assisted metathesis reaction reported by Todd & Neilson (JACS, 2019) corresponds to a net reaction equation:
#
# $$ Mn_2O_3 + 2 YCl_3 + 3Li_2CO_3 \to 2YMnO_3 + 6LiCl + 3CO_2 $$
#
# In the paper, they report a reaction pathway involving the formation of intermediates LiMnO2 and YOCl. These react to form YMnO3 product and LiCl byproduct. (The CO2 is released when Li2CO3 reacts initially to form LiMnO2).

# %% [markdown]
# ### Downloading and modifying entries
#
# First, we acquire entries for phases in the Y-Mn-O-Li-Cl-C chemical system from the Materials Project (MP), a computed materials database containing calculations for over 130,000 materials.

# %%
with MPRester() as mpr:  # insert your Materials Project API key here if it's not stored in .pmgrc.yaml
    entries = mpr.get_entries_in_chemsys("Bi-O-Fe-K-F", inc_structure="final")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 957/957 [00:05<00:00, 184.45it/s]

# %% [markdown]
# The `GibbsEntrySet` class allows us to automatically converet `ComputedStructureEntry` objects downloaded from the MP database into `GibbsComputedEntry` objects, where DFT-calculated energies have been converted to machine learning (ML)-estimated equivalent values of the Gibbs free energies of formation, $\Delta G_f$ for all entries at the specified temperature.
#
# For more information, check out the citation in the documentation for `GibbsComputedEntry`.

# %%
temp = 900  # units: Kelvin
entry_set = GibbsEntrySet.from_entries(entries, temp, include_freed_data=True)
# Out:
# WARNING:root:Compound KO2 is in FREED tables but not at this temperature! Temperature must be selected from range: 300.0 K to 800.0 K

# %% [markdown]
# We can print the entries by calling `.entries` or `.entries_list`:

# %%
entry_set.entries
# Out:
# {FREEDReferenceEntry | Bi2O3
#  Gibbs Energy (900 K) = -3.3635,
#  FREEDReferenceEntry | BiF3
#  Gibbs Energy (900 K) = -7.2191,
#  FREEDReferenceEntry | BiO
#  Gibbs Energy (900 K) = -0.2136,
#  FREEDReferenceEntry | Fe2O3
#  Gibbs Energy (900 K) = -6.0690,
#  FREEDReferenceEntry | Fe3O4
#  Gibbs Energy (900 K) = -8.5183,
#  FREEDReferenceEntry | FeF2
#  Gibbs Energy (900 K) = -6.0261,
#  FREEDReferenceEntry | FeF3
#  Gibbs Energy (900 K) = -8.6737,
#  FREEDReferenceEntry | FeO
#  Gibbs Energy (900 K) = -2.2090,
#  FREEDReferenceEntry | K2O
#  Gibbs Energy (900 K) = -2.2443,
#  FREEDReferenceEntry | K2O2
#  Gibbs Energy (900 K) = 0.3126,
#  FREEDReferenceEntry | KF
#  Gibbs Energy (900 K) = -4.9317,
#  FREEDReferenceEntry | OF2
#  Gibbs Energy (900 K) = 0.7947,
#  GibbsComputedEntry | mp-1022722 | Bi3 O2 (Bi3O2)
#  Gibbs Energy (900 K) = -2.6462,
#  GibbsComputedEntry | mp-1062652 | Fe1 O2 (FeO2)
#  Gibbs Energy (900 K) = -1.4627,
#  GibbsComputedEntry | mp-1069079 | Fe2 Bi2 O6 (FeBiO3)
#  Gibbs Energy (900 K) = -11.7059,
#  GibbsComputedEntry | mp-1080550 | K2 O4 F2 (KO2F)
#  Gibbs Energy (900 K) = 1.2822,
#  GibbsComputedEntry | mp-1095382 | Fe5 O7 (Fe5O7)
#  Gibbs Energy (900 K) = -12.2126,
#  GibbsComputedEntry | mp-1095521 | K2 F10 (KF5)
#  Gibbs Energy (900 K) = -4.4176,
#  GibbsComputedEntry | mp-1097003 | Fe2 O4 (FeO2)
#  Gibbs Energy (900 K) = 1.5138,
#  GibbsComputedEntry | mp-1097017 | K2 Fe2 (KFe)
#  Gibbs Energy (900 K) = 4.3672,
#  GibbsComputedEntry | mp-1097023 | K4 Fe4 O12 (KFeO3)
#  Gibbs Energy (900 K) = -13.8638,
#  GibbsComputedEntry | mp-1102773 | K8 Bi1 O3 (K8BiO3)
#  Gibbs Energy (900 K) = -5.5048,
#  GibbsComputedEntry | mp-1103327 | Fe4 O8 (FeO2)
#  Gibbs Energy (900 K) = -8.2642,
#  GibbsComputedEntry | mp-1104355 | Fe3 O2 F8 (Fe3(OF4)2)
#  Gibbs Energy (900 K) = -18.4179,
#  GibbsComputedEntry | mp-1105532 | K4 Fe2 O2 F10 (K2FeOF5)
#  Gibbs Energy (900 K) = -31.3872,
#  GibbsComputedEntry | mp-1106389 | K2 Bi2 F12 (KBiF6)
#  Gibbs Energy (900 K) = -31.3438,
#  GibbsComputedEntry | mp-1111491 | K3 Fe1 F6 (K3FeF6)
#  Gibbs Energy (900 K) = -24.0286,
#  GibbsComputedEntry | mp-1120752 | K2 Fe4 O7 (K2Fe4O7)
#  Gibbs Energy (900 K) = -15.8645,
#  GibbsComputedEntry | mp-1178195 | K2 Fe22 O34 (KFe11O17)
#  Gibbs Energy (900 K) = -68.9299,
#  GibbsComputedEntry | mp-1178210 | Fe4 O4 F4 (FeOF)
#  Gibbs Energy (900 K) = -19.1887,
#  GibbsComputedEntry | mp-1178215 | Fe4 O4 F4 (FeOF)
#  Gibbs Energy (900 K) = -19.0747,
#  GibbsComputedEntry | mp-1178224 | Fe4 O4 F4 (FeOF)
#  Gibbs Energy (900 K) = -17.3134,
#  GibbsComputedEntry | mp-1178228 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.8876,
#  GibbsComputedEntry | mp-1178229 | Fe3 O3 F3 (FeOF)
#  Gibbs Energy (900 K) = -13.2528,
#  GibbsComputedEntry | mp-1178238 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -44.2774,
#  GibbsComputedEntry | mp-1178241 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -81.5858,
#  GibbsComputedEntry | mp-1178244 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -81.9388,
#  GibbsComputedEntry | mp-1178245 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -81.4753,
#  GibbsComputedEntry | mp-1178250 | Fe5 O1 F11 (Fe5OF11)
#  Gibbs Energy (900 K) = -32.4453,
#  GibbsComputedEntry | mp-1178251 | Fe5 O1 F11 (Fe5OF11)
#  Gibbs Energy (900 K) = -32.4191,
#  GibbsComputedEntry | mp-1178252 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -19.2080,
#  GibbsComputedEntry | mp-1178253 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.2534,
#  GibbsComputedEntry | mp-1178254 | Fe7 O7 F1 (Fe7O7F)
#  Gibbs Energy (900 K) = -16.5683,
#  GibbsComputedEntry | mp-1178256 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -36.7114,
#  GibbsComputedEntry | mp-1178260 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -35.9032,
#  GibbsComputedEntry | mp-1178262 | Fe10 O4 F16 (Fe5(OF4)2)
#  Gibbs Energy (900 K) = -53.9738,
#  GibbsComputedEntry | mp-1178269 | Fe10 O4 F16 (Fe5(OF4)2)
#  Gibbs Energy (900 K) = -53.8709,
#  GibbsComputedEntry | mp-1178270 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -10.9551,
#  GibbsComputedEntry | mp-1178273 | Fe10 O4 F16 (Fe5(OF4)2)
#  Gibbs Energy (900 K) = -54.4752,
#  GibbsComputedEntry | mp-1178274 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.7216,
#  GibbsComputedEntry | mp-1178275 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -11.4307,
#  GibbsComputedEntry | mp-1178278 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -31.1147,
#  GibbsComputedEntry | mp-1178279 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -30.1445,
#  GibbsComputedEntry | mp-1178280 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.6991,
#  GibbsComputedEntry | mp-1178281 | Fe10 O4 F16 (Fe5(OF4)2)
#  Gibbs Energy (900 K) = -39.5409,
#  GibbsComputedEntry | mp-1178282 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -31.2306,
#  GibbsComputedEntry | mp-1178284 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -15.6817,
#  GibbsComputedEntry | mp-1178286 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -31.2508,
#  GibbsComputedEntry | mp-1178287 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -22.2831,
#  GibbsComputedEntry | mp-1178288 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -9.5067,
#  GibbsComputedEntry | mp-1178289 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -33.6373,
#  GibbsComputedEntry | mp-1178290 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.8607,
#  GibbsComputedEntry | mp-1178291 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -39.2284,
#  GibbsComputedEntry | mp-1178293 | Fe10 O4 F16 (Fe5(OF4)2)
#  Gibbs Energy (900 K) = -54.6768,
#  GibbsComputedEntry | mp-1178294 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -9.1765,
#  GibbsComputedEntry | mp-1178295 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -30.2152,
#  GibbsComputedEntry | mp-1178298 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -25.3838,
#  GibbsComputedEntry | mp-1178299 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -31.5216,
#  GibbsComputedEntry | mp-1178302 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -33.2124,
#  GibbsComputedEntry | mp-1178303 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -33.1168,
#  GibbsComputedEntry | mp-1178306 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -17.6918,
#  GibbsComputedEntry | mp-1178308 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -4.6998,
#  GibbsComputedEntry | mp-1178310 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -19.2183,
#  GibbsComputedEntry | mp-1178311 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -20.3411,
#  GibbsComputedEntry | mp-1178312 | Fe10 O5 F15 (Fe2OF3)
#  Gibbs Energy (900 K) = -52.4636,
#  GibbsComputedEntry | mp-1178314 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.6974,
#  GibbsComputedEntry | mp-1178318 | Fe12 O8 F8 (Fe3(OF)2)
#  Gibbs Energy (900 K) = -38.7345,
#  GibbsComputedEntry | mp-1178321 | Fe10 O6 F14 (Fe5O3F7)
#  Gibbs Energy (900 K) = -50.6484,
#  GibbsComputedEntry | mp-1178324 | Fe6 O2 F14 (Fe3OF7)
#  Gibbs Energy (900 K) = -32.0467,
#  GibbsComputedEntry | mp-1178326 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -11.0312,
#  GibbsComputedEntry | mp-1178327 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -18.3381,
#  GibbsComputedEntry | mp-1178331 | Fe10 O1 F19 (Fe10OF19)
#  Gibbs Energy (900 K) = -60.2925,
#  GibbsComputedEntry | mp-1178334 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -29.4447,
#  GibbsComputedEntry | mp-1178337 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -33.7647,
#  GibbsComputedEntry | mp-1178341 | Fe10 O11 F9 (Fe10O11F9)
#  Gibbs Energy (900 K) = -43.0803,
#  GibbsComputedEntry | mp-1178342 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.5757,
#  GibbsComputedEntry | mp-1178343 | Fe10 O11 F9 (Fe10O11F9)
#  Gibbs Energy (900 K) = -43.0591,
#  GibbsComputedEntry | mp-1178344 | Fe10 O11 F9 (Fe10O11F9)
#  Gibbs Energy (900 K) = -43.1050,
#  GibbsComputedEntry | mp-1178349 | Fe10 O11 F9 (Fe10O11F9)
#  Gibbs Energy (900 K) = -43.1700,
#  GibbsComputedEntry | mp-1178377 | Fe10 O1 F19 (Fe10OF19)
#  Gibbs Energy (900 K) = -60.2905,
#  GibbsComputedEntry | mp-1178379 | Fe10 O1 F19 (Fe10OF19)
#  Gibbs Energy (900 K) = -60.4319,
#  GibbsComputedEntry | mp-1178401 | Fe10 O1 F19 (Fe10OF19)
#  Gibbs Energy (900 K) = -60.6080,
#  GibbsComputedEntry | mp-1178402 | Fe10 O4 F16 (Fe5(OF4)2)
#  Gibbs Energy (900 K) = -54.5233,
#  GibbsComputedEntry | mp-1178447 | Fe8 O4 F12 (Fe2OF3)
#  Gibbs Energy (900 K) = -41.4655,
#  GibbsComputedEntry | mp-1178466 | Fe12 O6 F12 (Fe2OF2)
#  Gibbs Energy (900 K) = -48.4474,
#  GibbsComputedEntry | mp-1178468 | Fe10 O5 F15 (Fe2OF3)
#  Gibbs Energy (900 K) = -53.3619,
#  GibbsComputedEntry | mp-1178487 | Bi10 O14 F2 (Bi5O7F)
#  Gibbs Energy (900 K) = -30.1115,
#  GibbsComputedEntry | mp-1178488 | Bi6 O8 F2 (Bi3O4F)
#  Gibbs Energy (900 K) = -20.4520,
#  GibbsComputedEntry | mp-1178491 | Bi4 O4 F4 (BiOF)
#  Gibbs Energy (900 K) = -18.7025,
#  GibbsComputedEntry | mp-1178496 | Bi6 O5 F8 (Bi6O5F8)
#  Gibbs Energy (900 K) = -32.1380,
#  GibbsComputedEntry | mp-1181334 | Fe4 O13 (Fe4O13)
#  Gibbs Energy (900 K) = 4.3194,
#  GibbsComputedEntry | mp-1181411 | Fe4 O13 (Fe4O13)
#  Gibbs Energy (900 K) = 2.9705,
#  GibbsComputedEntry | mp-1181766 | Fe8 O16 (FeO2)
#  Gibbs Energy (900 K) = -10.6022,
#  GibbsComputedEntry | mp-1182503 | Fe16 O34 (Fe8O17)
#  Gibbs Energy (900 K) = -26.7722,
#  GibbsComputedEntry | mp-1182718 | Fe2 Bi2 O6 (FeBiO3)
#  Gibbs Energy (900 K) = 16.5073,
#  GibbsComputedEntry | mp-1182806 | K16 Fe4 (K4Fe)
#  Gibbs Energy (900 K) = 25.8239,
#  GibbsComputedEntry | mp-1184279 | Fe3 F1 (Fe3F)
#  Gibbs Energy (900 K) = 3.5781,
#  GibbsComputedEntry | mp-1184320 | Fe6 O2 (Fe3O)
#  Gibbs Energy (900 K) = 8.0256,
#  GibbsComputedEntry | mp-1184760 | K2 Bi2 O5 (K2Bi2O5)
#  Gibbs Energy (900 K) = -9.5478,
#  GibbsComputedEntry | mp-1184905 | K20 (K)
#  Gibbs Energy (900 K) = 0.0000,
#  GibbsComputedEntry | mp-1184943 | K1 Bi3 (KBi3)
#  Gibbs Energy (900 K) = 0.4416,
#  GibbsComputedEntry | mp-1188385 | Fe4 O4 F10 (Fe2O2F5)
#  Gibbs Energy (900 K) = -20.4848,
#  GibbsComputedEntry | mp-1188678 | Fe8 O10 (Fe4O5)
#  Gibbs Energy (900 K) = 12.2520,
#  GibbsComputedEntry | mp-1190371 | Fe4 O4 F10 (Fe2O2F5)
#  Gibbs Energy (900 K) = -24.8605,
#  GibbsComputedEntry | mp-1190898 | Bi7 O5 F11 (Bi7O5F11)
#  Gibbs Energy (900 K) = -42.2368,
#  GibbsComputedEntry | mp-1194393 | Fe6 O2 F18 (Fe3OF9)
#  Gibbs Energy (900 K) = -43.9135,
#  GibbsComputedEntry | mp-1194978 | Fe25 O32 (Fe25O32)
#  Gibbs Energy (900 K) = 22.2346,
#  GibbsComputedEntry | mp-1195927 | Fe13 O19 (Fe13O19)
#  Gibbs Energy (900 K) = -28.7177,
#  GibbsComputedEntry | mp-1196085 | Fe16 Bi8 O36 (Fe4Bi2O9)
#  Gibbs Energy (900 K) = -73.0320,
#  GibbsComputedEntry | mp-1196507 | K36 Fe8 O32 (K9(FeO4)2)
#  Gibbs Energy (900 K) = -70.0861,
#  GibbsComputedEntry | mp-1199147 | K36 Fe8 O28 (K9Fe2O7)
#  Gibbs Energy (900 K) = -76.2762,
#  GibbsComputedEntry | mp-1201518 | K6 Fe10 F30 (K3Fe5F15)
#  Gibbs Energy (900 K) = -103.0198,
#  GibbsComputedEntry | mp-12040 | K40 Fe8 O32 (K5FeO4)
#  Gibbs Energy (900 K) = -88.8080,
#  GibbsComputedEntry | mp-1204916 | K8 Fe4 F20 (K2FeF5)
#  Gibbs Energy (900 K) = -70.2775,
#  GibbsComputedEntry | mp-1204955 | K12 Fe24 F76 (K3Fe6F19)
#  Gibbs Energy (900 K) = -249.3422,
#  GibbsComputedEntry | mp-1205367 | K4 Fe2 F10 (K2FeF5)
#  Gibbs Energy (900 K) = -35.0974,
#  GibbsComputedEntry | mp-1205429 | Fe8 O16 (FeO2)
#  Gibbs Energy (900 K) = -17.5385,
#  GibbsComputedEntry | mp-1205955 | K5 Bi4 (K5Bi4)
#  Gibbs Energy (900 K) = -1.4546,
#  GibbsComputedEntry | mp-1206573 | K6 Bi4 (K3Bi2)
#  Gibbs Energy (900 K) = -1.3563,
#  GibbsComputedEntry | mp-1211670 | K2 Bi6 F20 (KBi3F10)
#  Gibbs Energy (900 K) = -63.5834,
#  GibbsComputedEntry | mp-1211781 | K8 Bi2 (K4Bi)
#  Gibbs Energy (900 K) = 1.5227,
#  GibbsComputedEntry | mp-1211882 | K8 O32 F8 (KO4F)
#  Gibbs Energy (900 K) = -5.5041,
#  GibbsComputedEntry | mp-1213097 | Fe4 O16 F8 (Fe(O2F)2)
#  Gibbs Energy (900 K) = -9.4828,
#  GibbsComputedEntry | mp-1223730 | K5 Fe10 F30 (KFe2F6)
#  Gibbs Energy (900 K) = -99.3275,
#  GibbsComputedEntry | mp-1223773 | K5 Bi4 (K5Bi4)
#  Gibbs Energy (900 K) = -1.4570,
#  GibbsComputedEntry | mp-1224086 | K3 Fe4 O8 (K3(FeO2)4)
#  Gibbs Energy (900 K) = -17.2152,
#  GibbsComputedEntry | mp-1224134 | K6 Bi6 O19 (K6Bi6O19)
#  Gibbs Energy (900 K) = -28.3884,
#  GibbsComputedEntry | mp-1224855 | Fe1 O2 (FeO2)
#  Gibbs Energy (900 K) = -1.9167,
#  GibbsComputedEntry | mp-1224936 | Fe15 O16 (Fe15O16)
#  Gibbs Energy (900 K) = -31.1553,
#  GibbsComputedEntry | mp-1225001 | Fe5 O8 (Fe5O8)
#  Gibbs Energy (900 K) = -9.2285,
#  GibbsComputedEntry | mp-1225007 | Fe5 O8 (Fe5O8)
#  Gibbs Energy (900 K) = -12.6993,
#  GibbsComputedEntry | mp-1225422 | Fe20 Bi16 O52 F4 (Fe5Bi4O13F)
#  Gibbs Energy (900 K) = -114.2201,
#  GibbsComputedEntry | mp-1227527 | Bi8 O14 (Bi4O7)
#  Gibbs Energy (900 K) = -18.5754,
#  GibbsComputedEntry | mp-1227568 | Bi8 O10 (Bi4O5)
#  Gibbs Energy (900 K) = -15.2699,
#  GibbsComputedEntry | mp-1239395 | Bi8 O16 (BiO2)
#  Gibbs Energy (900 K) = -18.3440,
#  GibbsComputedEntry | mp-1282721 | Fe4 O2 F6 (Fe2OF3)
#  Gibbs Energy (900 K) = -21.3919,
#  GibbsComputedEntry | mp-12957 | O8 (O2)
#  Gibbs Energy (900 K) = 0.0000,
#  GibbsComputedEntry | mp-13 | Fe1 (Fe)
#  Gibbs Energy (900 K) = 0.0000,
#  GibbsComputedEntry | mp-14679 | K28 Fe8 O26 (K14Fe4O13)
#  Gibbs Energy (900 K) = -55.8971,
#  GibbsComputedEntry | mp-1568829 | Fe8 O2 F12 (Fe4OF6)
#  Gibbs Energy (900 K) = -36.3503,
#  GibbsComputedEntry | mp-1569012 | Fe8 O2 F12 (Fe4OF6)
#  Gibbs Energy (900 K) = -40.0184,
#  GibbsComputedEntry | mp-1652491 | Fe8 O2 F12 (Fe4OF6)
#  Gibbs Energy (900 K) = -40.6584,
#  GibbsComputedEntry | mp-1726 | K4 O12 (KO3)
#  Gibbs Energy (900 K) = -0.6880,
#  GibbsComputedEntry | mp-18865 | K6 Fe4 O8 (K3(FeO2)2)
#  Gibbs Energy (900 K) = -20.4023,
#  GibbsComputedEntry | mp-19320 | K8 Fe4 O16 (K2FeO4)
#  Gibbs Energy (900 K) = -26.1494,
#  GibbsComputedEntry | mp-21676 | K6 Fe10 F30 (K3Fe5F15)
#  Gibbs Energy (900 K) = -81.2388,
#  GibbsComputedEntry | mp-22949 | Fe2 Bi2 O6 (FeBiO3)
#  Gibbs Energy (900 K) = -11.6093,
#  GibbsComputedEntry | mp-23074 | Bi2 O2 F2 (BiOF)
#  Gibbs Energy (900 K) = -9.6782,
#  GibbsComputedEntry | mp-23152 | Bi2 (Bi)
#  Gibbs Energy (900 K) = 0.0000,
#  GibbsComputedEntry | mp-23279 | K2 Bi4 (KBi2)
#  Gibbs Energy (900 K) = -0.7734,
#  GibbsComputedEntry | mp-23501 | Fe2 Bi2 O6 (FeBiO3)
#  Gibbs Energy (900 K) = -11.8862,
#  GibbsComputedEntry | mp-25208 | Bi4 O8 (BiO2)
#  Gibbs Energy (900 K) = -5.8417,
#  GibbsComputedEntry | mp-25236 | Fe1 O2 (FeO2)
#  Gibbs Energy (900 K) = -0.9034,
#  GibbsComputedEntry | mp-25332 | Fe2 O4 (FeO2)
#  Gibbs Energy (900 K) = -2.5403,
#  GibbsComputedEntry | mp-25333 | Bi4 O8 (BiO2)
#  Gibbs Energy (900 K) = -5.6404,
#  GibbsComputedEntry | mp-27743 | Bi1 F5 (BiF5)
#  Gibbs Energy (900 K) = -9.2064,
#  GibbsComputedEntry | mp-28640 | K32 Fe16 F80 (K2FeF5)
#  Gibbs Energy (900 K) = -305.0585,
#  GibbsComputedEntry | mp-28696 | K12 Fe4 O16 (K3FeO4)
#  Gibbs Energy (900 K) = -33.9465,
#  GibbsComputedEntry | mp-29524 | K12 Bi4 O12 (K3BiO3)
#  Gibbs Energy (900 K) = -34.4893,
#  GibbsComputedEntry | mp-29542 | K8 Bi4 O10 (K4Bi2O5)
#  Gibbs Energy (900 K) = -27.0516,
#  GibbsComputedEntry | mp-29799 | K12 Bi12 O36 (KBiO3)
#  Gibbs Energy (900 K) = -62.3497,
#  GibbsComputedEntry | mp-30120 | K6 Bi2 O8 (K3BiO4)
#  Gibbs Energy (900 K) = -18.4280,
#  GibbsComputedEntry | mp-30303 | Bi8 O14 (Bi4O7)
#  Gibbs Energy (900 K) = -22.1389,
#  GibbsComputedEntry | mp-30988 | K2 Bi2 O4 (KBiO2)
#  Gibbs Energy (900 K) = -9.9307,
#  GibbsComputedEntry | mp-31104 | K16 Bi16 (KBi)
#  Gibbs Energy (900 K) = -5.0668,
#  GibbsComputedEntry | mp-31218 | K12 Fe4 O8 (K3FeO2)
#  Gibbs Energy (900 K) = -20.3488,
#  GibbsComputedEntry | mp-31286 | K18 Bi6 (K3Bi)
#  Gibbs Energy (900 K) = -4.2046,
#  GibbsComputedEntry | mp-32548 | Bi1 O2 (BiO2)
#  Gibbs Energy (900 K) = -2.2955,
#  GibbsComputedEntry | mp-32597 | Bi13 O20 (Bi13O20)
#  Gibbs Energy (900 K) = -34.7901,
#  GibbsComputedEntry | mp-32939 | Fe7 O8 (Fe7O8)
#  Gibbs Energy (900 K) = -15.2683,
#  GibbsComputedEntry | mp-36915 | K6 Fe2 O5 (K6Fe2O5)
#  Gibbs Energy (900 K) = -5.7075,
#  GibbsComputedEntry | mp-504570 | K6 Fe2 O6 (K3FeO3)
#  Gibbs Energy (900 K) = -11.3172,
#  GibbsComputedEntry | mp-504615 | Fe8 Bi4 O18 (Fe4Bi2O9)
#  Gibbs Energy (900 K) = -36.6824,
#  GibbsComputedEntry | mp-504669 | K4 Bi4 F24 (KBiF6)
#  Gibbs Energy (900 K) = -62.7375,
#  GibbsComputedEntry | mp-510746 | Fe20 O32 (Fe5O8)
#  Gibbs Energy (900 K) = -51.5372,
#  GibbsComputedEntry | mp-530048 | Fe21 O32 (Fe21O32)
#  Gibbs Energy (900 K) = -53.4377,
#  GibbsComputedEntry | mp-530050 | Fe43 O64 (Fe43O64)
#  Gibbs Energy (900 K) = -118.6535,
#  GibbsComputedEntry | mp-531715 | Fe20 Bi12 O48 (Fe5(BiO4)3)
#  Gibbs Energy (900 K) = -88.4485,
#  GibbsComputedEntry | mp-540003 | Fe4 O8 (FeO2)
#  Gibbs Energy (900 K) = -6.2365,
#  GibbsComputedEntry | mp-547069 | Fe2 Bi2 O6 (FeBiO3)
#  Gibbs Energy (900 K) = -9.3078,
#  GibbsComputedEntry | mp-548231 | Fe2 Bi2 O6 (FeBiO3)
#  Gibbs Energy (900 K) = -6.4053,
#  GibbsComputedEntry | mp-551451 | Fe1 Bi1 O3 (FeBiO3)
#  Gibbs Energy (900 K) = -4.2493,
#  GibbsComputedEntry | mp-553960 | K8 Fe4 O10 (K4Fe2O5)
#  Gibbs Energy (900 K) = -11.7563,
#  GibbsComputedEntry | mp-554621 | K32 Fe16 F80 (K2FeF5)
#  Gibbs Energy (900 K) = -291.6283,
#  GibbsComputedEntry | mp-555351 | Fe2 Bi2 O6 (FeBiO3)
#  Gibbs Energy (900 K) = -9.2998,
#  GibbsComputedEntry | mp-555579 | K16 Fe8 F40 (K2FeF5)
#  Gibbs Energy (900 K) = -152.5706,
#  GibbsComputedEntry | mp-555631 | K8 Fe8 F32 (KFeF4)
#  Gibbs Energy (900 K) = -111.4408,
#  GibbsComputedEntry | mp-556891 | K1 Fe1 F3 (KFeF3)
#  Gibbs Energy (900 K) = -10.0280,
#  GibbsComputedEntry | mp-557724 | K2 Bi2 F12 (KBiF6)
#  Gibbs Energy (900 K) = -31.4120,
#  GibbsComputedEntry | mp-557993 | Bi4 O8 (BiO2)
#  Gibbs Energy (900 K) = -10.5210,
#  GibbsComputedEntry | mp-558155 | K2 Fe2 F8 (KFeF4)
#  Gibbs Energy (900 K) = -27.8631,
#  GibbsComputedEntry | mp-558482 | K17 Fe5 O16 (K17Fe5O16)
#  Gibbs Energy (900 K) = -44.8875,
#  GibbsComputedEntry | mp-559464 | K16 Fe16 O32 (KFeO2)
#  Gibbs Energy (900 K) = -50.6568,
#  GibbsComputedEntry | mp-559498 | K36 Bi20 O52 (K9Bi5O13)
#  Gibbs Energy (900 K) = -130.5879,
#  GibbsComputedEntry | mp-561203 | F4 (F2)
#  Gibbs Energy (900 K) = 0.0000,
#  GibbsComputedEntry | mp-561290 | K8 Bi4 F20 (K2BiF5)
#  Gibbs Energy (900 K) = -77.0045,
#  GibbsComputedEntry | mp-568516 | K3 Bi1 (K3Bi)
#  Gibbs Energy (900 K) = -0.5341,
#  GibbsComputedEntry | mp-569940 | K6 Bi2 (K3Bi)
#  Gibbs Energy (900 K) = -1.4035,
#  GibbsComputedEntry | mp-581857 | K4 Bi4 F16 (KBiF4)
#  Gibbs Energy (900 K) = -55.2682,
#  GibbsComputedEntry | mp-645159 | Fe4 Bi4 O12 (FeBiO3)
#  Gibbs Energy (900 K) = -23.5010,
#  GibbsComputedEntry | mp-655631 | Fe1 Bi1 O3 (FeBiO3)
#  Gibbs Energy (900 K) = -4.2153,
#  GibbsComputedEntry | mp-675006 | Fe4 O4 F4 (FeOF)
#  Gibbs Energy (900 K) = -18.8651,
#  GibbsComputedEntry | mp-675250 | K2 Bi4 F14 (KBi2F7)
#  Gibbs Energy (900 K) = -44.0173,
#  GibbsComputedEntry | mp-675634 | K1 Bi2 F7 (KBi2F7)
#  Gibbs Energy (900 K) = -22.2587,
#  GibbsComputedEntry | mp-675978 | K2 Bi3 F11 (K2Bi3F11)
#  Gibbs Energy (900 K) = -35.4553,
#  GibbsComputedEntry | mp-676536 | K18 Bi18 O54 (KBiO3)
#  Gibbs Energy (900 K) = -90.8059,
#  GibbsComputedEntry | mp-676778 | K2 Bi2 F8 (KBiF4)
#  Gibbs Energy (900 K) = -26.4972,
#  GibbsComputedEntry | mp-684589 | Bi8 O10 (Bi4O5)
#  Gibbs Energy (900 K) = -15.4501,
#  GibbsComputedEntry | mp-690534 | K6 Fe2 F6 (K3FeF3)
#  Gibbs Energy (900 K) = -21.7115,
#  GibbsComputedEntry | mp-694910 | Fe35 O36 (Fe35O36)
#  Gibbs Energy (900 K) = -20.3473,
#  GibbsComputedEntry | mp-698573 | Fe1 Bi25 O39 (FeBi25O39)
#  Gibbs Energy (900 K) = -71.6939,
#  GibbsComputedEntry | mp-705414 | Fe13 O14 (Fe13O14)
#  Gibbs Energy (900 K) = -27.4973,
#  GibbsComputedEntry | mp-705417 | Fe11 O12 (Fe11O12)
#  Gibbs Energy (900 K) = -24.0877,
#  GibbsComputedEntry | mp-705424 | Fe17 O18 (Fe17O18)
#  Gibbs Energy (900 K) = -36.5450,
#  GibbsComputedEntry | mp-705551 | Fe15 O16 (Fe15O16)
#  Gibbs Energy (900 K) = -31.4244,
#  GibbsComputedEntry | mp-705553 | Fe23 O25 (Fe23O25)
#  Gibbs Energy (900 K) = -50.1310,
#  GibbsComputedEntry | mp-705555 | Fe20 O22 (Fe10O11)
#  Gibbs Energy (900 K) = -44.3112,
#  GibbsComputedEntry | mp-705558 | Fe21 O27 (Fe7O9)
#  Gibbs Energy (900 K) = -46.8239,
#  GibbsComputedEntry | mp-705588 | Fe16 O18 (Fe8O9)
#  Gibbs Energy (900 K) = -36.0496,
#  GibbsComputedEntry | mp-705753 | Fe38 O39 (Fe38O39)
#  Gibbs Energy (900 K) = -76.8993,
#  GibbsComputedEntry | mp-706875 | Fe21 O23 (Fe21O23)
#  Gibbs Energy (900 K) = -45.9290,
#  GibbsComputedEntry | mp-714904 | Fe4 O8 (FeO2)
#  Gibbs Energy (900 K) = -6.3373,
#  GibbsComputedEntry | mp-715333 | Fe14 O16 (Fe7O8)
#  Gibbs Energy (900 K) = -31.6529,
#  GibbsComputedEntry | mp-752456 | Fe4 O2 F6 (Fe2OF3)
#  Gibbs Energy (900 K) = -13.1616,
#  GibbsComputedEntry | mp-752470 | Fe8 O4 F12 (Fe2OF3)
#  Gibbs Energy (900 K) = -42.2652,
#  GibbsComputedEntry | mp-752486 | Fe6 O9 F3 (Fe2O3F)
#  Gibbs Energy (900 K) = -20.4141,
#  GibbsComputedEntry | mp-752493 | Fe6 O3 F9 (Fe2OF3)
#  Gibbs Energy (900 K) = -31.6994,
#  GibbsComputedEntry | mp-752495 | Fe8 O4 F12 (Fe2OF3)
#  Gibbs Energy (900 K) = -42.5607,
#  GibbsComputedEntry | mp-752563 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -26.3730,
#  GibbsComputedEntry | mp-752593 | Fe8 O8 F8 (FeOF)
#  Gibbs Energy (900 K) = -36.5413,
#  GibbsComputedEntry | mp-752594 | Fe8 O12 F4 (Fe2O3F)
#  Gibbs Energy (900 K) = -27.1981,
#  GibbsComputedEntry | mp-752614 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -38.5049,
#  GibbsComputedEntry | mp-752624 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -17.4591,
#  GibbsComputedEntry | mp-752653 | Fe8 O12 F4 (Fe2O3F)
#  Gibbs Energy (900 K) = -13.6894,
#  GibbsComputedEntry | mp-752687 | Fe4 O6 F2 (Fe2O3F)
#  Gibbs Energy (900 K) = -13.7032,
#  GibbsComputedEntry | mp-752739 | Fe6 O9 F3 (Fe2O3F)
#  Gibbs Energy (900 K) = -20.4070,
#  GibbsComputedEntry | mp-752761 | Fe4 O3 F5 (Fe4O3F5)
#  Gibbs Energy (900 K) = -19.5170,
#  GibbsComputedEntry | mp-752802 | Fe5 O4 F8 (Fe5(OF2)4)
#  Gibbs Energy (900 K) = -13.4012,
#  GibbsComputedEntry | mp-752804 | Fe8 O8 F8 (FeOF)
#  Gibbs Energy (900 K) = -22.7798,
#  GibbsComputedEntry | mp-752877 | Fe4 O5 F3 (Fe4O5F3)
#  Gibbs Energy (900 K) = -15.8523,
#  GibbsComputedEntry | mp-752880 | Fe8 O8 F8 (FeOF)
#  Gibbs Energy (900 K) = -36.4947,
#  GibbsComputedEntry | mp-752909 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -38.5336,
#  GibbsComputedEntry | mp-752939 | Fe2 O2 F2 (FeOF)
#  Gibbs Energy (900 K) = -8.9015,
#  GibbsComputedEntry | mp-752941 | Fe4 O4 F4 (FeOF)
#  Gibbs Energy (900 K) = -19.0538,
#  GibbsComputedEntry | mp-752949 | Bi2 O2 F2 (BiOF)
#  Gibbs Energy (900 K) = -9.7451,
#  GibbsComputedEntry | mp-752975 | Fe4 O4 F4 (FeOF)
#  Gibbs Energy (900 K) = -19.0578,
#  GibbsComputedEntry | mp-752987 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.7624,
#  GibbsComputedEntry | mp-752991 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -26.9766,
#  GibbsComputedEntry | mp-752992 | Fe8 O8 F8 (FeOF)
#  Gibbs Energy (900 K) = -32.3378,
#  GibbsComputedEntry | mp-752995 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -26.2246,
#  GibbsComputedEntry | mp-753003 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -17.7470,
#  GibbsComputedEntry | mp-753015 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -17.1241,
#  GibbsComputedEntry | mp-753017 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -28.1853,
#  GibbsComputedEntry | mp-753020 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -40.2815,
#  GibbsComputedEntry | mp-753033 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.7340,
#  GibbsComputedEntry | mp-753042 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -41.3647,
#  GibbsComputedEntry | mp-753057 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -31.7725,
#  GibbsComputedEntry | mp-753067 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -38.8424,
#  GibbsComputedEntry | mp-753097 | Fe6 O3 F9 (Fe2OF3)
#  Gibbs Energy (900 K) = -31.9060,
#  GibbsComputedEntry | mp-753138 | Fe4 O2 F6 (Fe2OF3)
#  Gibbs Energy (900 K) = -21.5130,
#  GibbsComputedEntry | mp-753145 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -13.5420,
#  GibbsComputedEntry | mp-753155 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -20.7338,
#  GibbsComputedEntry | mp-753160 | Bi4 O4 F4 (BiOF)
#  Gibbs Energy (900 K) = -19.2574,
#  GibbsComputedEntry | mp-753167 | Fe4 O6 F2 (Fe2O3F)
#  Gibbs Energy (900 K) = -12.7276,
#  GibbsComputedEntry | mp-753194 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -22.2866,
#  GibbsComputedEntry | mp-753196 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -9.1486,
#  GibbsComputedEntry | mp-753210 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -21.8164,
#  GibbsComputedEntry | mp-753217 | Fe4 O3 F5 (Fe4O3F5)
#  Gibbs Energy (900 K) = -20.1347,
#  GibbsComputedEntry | mp-753238 | Fe8 O8 F8 (FeOF)
#  Gibbs Energy (900 K) = -36.0793,
#  GibbsComputedEntry | mp-753256 | Fe4 O3 F5 (Fe4O3F5)
#  Gibbs Energy (900 K) = -19.6360,
#  GibbsComputedEntry | mp-753274 | Fe8 O8 F8 (FeOF)
#  Gibbs Energy (900 K) = -30.1849,
#  GibbsComputedEntry | mp-753290 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -26.7209,
#  GibbsComputedEntry | mp-753309 | Bi4 O2 F8 (Bi2OF4)
#  Gibbs Energy (900 K) = -27.1079,
#  GibbsComputedEntry | mp-753333 | Fe4 O4 F4 (FeOF)
#  Gibbs Energy (900 K) = -18.2582,
#  GibbsComputedEntry | mp-753360 | Bi4 O4 F4 (BiOF)
#  Gibbs Energy (900 K) = -19.1083,
#  GibbsComputedEntry | mp-753455 | Bi4 O4 F12 (BiOF3)
#  Gibbs Energy (900 K) = -30.5291,
#  GibbsComputedEntry | mp-753478 | Bi4 O4 F4 (BiOF)
#  Gibbs Energy (900 K) = -19.5263,
#  GibbsComputedEntry | mp-753491 | Fe6 O4 F4 (Fe3(OF)2)
#  Gibbs Energy (900 K) = -20.5468,
#  GibbsComputedEntry | mp-753594 | Bi2 O2 F2 (BiOF)
#  Gibbs Energy (900 K) = -9.8100,
#  GibbsComputedEntry | mp-753600 | Bi6 O8 F2 (Bi3O4F)
#  Gibbs Energy (900 K) = -19.9111,
#  GibbsComputedEntry | mp-753673 | Bi8 O8 F8 (BiOF)
#  Gibbs Energy (900 K) = -37.3864,
#  GibbsComputedEntry | mp-753699 | Bi8 O10 F4 (Bi4O5F2)
#  Gibbs Energy (900 K) = -29.5248,
#  GibbsComputedEntry | mp-753707 | Bi6 O10 (Bi3O5)
#  Gibbs Energy (900 K) = -15.6946,
#  GibbsComputedEntry | mp-753755 | Bi6 O8 F2 (Bi3O4F)
#  Gibbs Energy (900 K) = -20.4399,
#  GibbsComputedEntry | mp-753762 | Fe8 O2 F12 (Fe4OF6)
#  Gibbs Energy (900 K) = -40.1498,
#  GibbsComputedEntry | mp-753832 | Bi4 O3 F7 (Bi4O3F7)
#  Gibbs Energy (900 K) = -23.6485,
#  GibbsComputedEntry | mp-754053 | Fe4 O4 F4 (FeOF)
#  Gibbs Energy (900 K) = -18.9150,
#  GibbsComputedEntry | mp-754194 | Fe4 O7 F1 (Fe4O7F)
#  Gibbs Energy (900 K) = -11.0588,
#  GibbsComputedEntry | mp-754278 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -30.2770,
#  GibbsComputedEntry | mp-754305 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.4417,
#  GibbsComputedEntry | mp-754310 | Fe5 O4 F8 (Fe5(OF2)4)
#  Gibbs Energy (900 K) = -27.5165,
#  GibbsComputedEntry | mp-754389 | Fe3 O3 F3 (FeOF)
#  Gibbs Energy (900 K) = -13.5879,
#  GibbsComputedEntry | mp-754412 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -16.1787,
#  GibbsComputedEntry | mp-754413 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.3030,
#  GibbsComputedEntry | mp-754460 | Fe6 O11 F1 (Fe6O11F)
#  Gibbs Energy (900 K) = -15.5904,
#  GibbsComputedEntry | mp-754477 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.2538,
#  GibbsComputedEntry | mp-754493 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -29.9561,
#  GibbsComputedEntry | mp-754498 | Fe8 O12 F4 (Fe2O3F)
#  Gibbs Energy (900 K) = -15.5463,
#  GibbsComputedEntry | mp-754518 | Fe4 O6 F2 (Fe2O3F)
#  Gibbs Energy (900 K) = -8.5196,
#  GibbsComputedEntry | mp-754527 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -13.8244,
#  GibbsComputedEntry | mp-754536 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.3907,
#  GibbsComputedEntry | mp-754591 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -23.8143,
#  GibbsComputedEntry | mp-754593 | Fe7 O3 F13 (Fe7O3F13)
#  Gibbs Energy (900 K) = -40.7082,
#  GibbsComputedEntry | mp-754602 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -17.9084,
#  GibbsComputedEntry | mp-754606 | Fe6 O11 F1 (Fe6O11F)
#  Gibbs Energy (900 K) = -15.4861,
#  GibbsComputedEntry | mp-754616 | Fe8 O8 F8 (FeOF)
#  Gibbs Energy (900 K) = -20.5949,
#  GibbsComputedEntry | mp-754622 | Fe10 O15 F5 (Fe2O3F)
#  Gibbs Energy (900 K) = -33.9999,
#  GibbsComputedEntry | mp-754653 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -33.5715,
#  GibbsComputedEntry | mp-754705 | Fe8 O2 F16 (Fe4OF8)
#  Gibbs Energy (900 K) = -48.9906,
#  GibbsComputedEntry | mp-754726 | Fe4 O4 F4 (FeOF)
#  Gibbs Energy (900 K) = -10.0721,
#  GibbsComputedEntry | mp-754731 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -7.5168,
#  GibbsComputedEntry | mp-754764 | Fe4 O4 F4 (FeOF)
#  Gibbs Energy (900 K) = -18.0832,
#  GibbsComputedEntry | mp-754786 | Fe10 O15 F5 (Fe2O3F)
#  Gibbs Energy (900 K) = -34.0388,
#  GibbsComputedEntry | mp-754814 | Fe10 O15 F5 (Fe2O3F)
#  Gibbs Energy (900 K) = -33.8526,
#  GibbsComputedEntry | mp-754831 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -26.8452,
#  GibbsComputedEntry | mp-754847 | Fe6 O1 F11 (Fe6OF11)
#  Gibbs Energy (900 K) = -35.4386,
#  GibbsComputedEntry | mp-754859 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.9587,
#  GibbsComputedEntry | mp-754865 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.1287,
#  GibbsComputedEntry | mp-754879 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -27.0346,
#  GibbsComputedEntry | mp-754906 | Fe10 O15 F5 (Fe2O3F)
#  Gibbs Energy (900 K) = -33.8891,
#  GibbsComputedEntry | mp-754931 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -30.2407,
#  GibbsComputedEntry | mp-754938 | Fe10 O15 F5 (Fe2O3F)
#  Gibbs Energy (900 K) = -34.2046,
#  GibbsComputedEntry | mp-755039 | Fe6 O1 F11 (Fe6OF11)
#  Gibbs Energy (900 K) = -35.1417,
#  GibbsComputedEntry | mp-755097 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.5397,
#  GibbsComputedEntry | mp-755098 | Fe8 O12 F4 (Fe2O3F)
#  Gibbs Energy (900 K) = -26.5002,
#  GibbsComputedEntry | mp-755101 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -24.9513,
#  GibbsComputedEntry | mp-755114 | Fe6 O1 F11 (Fe6OF11)
#  Gibbs Energy (900 K) = -35.1576,
#  GibbsComputedEntry | mp-755131 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -24.4865,
#  GibbsComputedEntry | mp-755137 | Bi2 O4 (BiO2)
#  Gibbs Energy (900 K) = -5.2938,
#  GibbsComputedEntry | mp-755145 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -24.7758,
#  GibbsComputedEntry | mp-755170 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.7717,
#  GibbsComputedEntry | mp-755187 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.1977,
#  GibbsComputedEntry | mp-755195 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -17.6959,
#  GibbsComputedEntry | mp-755230 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -12.8539,
#  GibbsComputedEntry | mp-755262 | Fe6 O11 F1 (Fe6O11F)
#  Gibbs Energy (900 K) = -15.5076,
#  GibbsComputedEntry | mp-755274 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -29.9845,
#  GibbsComputedEntry | mp-755279 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -4.6604,
#  GibbsComputedEntry | mp-755296 | Fe6 O11 F1 (Fe6O11F)
#  Gibbs Energy (900 K) = -15.4853,
#  GibbsComputedEntry | mp-755310 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -22.6868,
#  GibbsComputedEntry | mp-755330 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -24.6711,
#  GibbsComputedEntry | mp-755341 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -33.1864,
#  GibbsComputedEntry | mp-755359 | Fe4 O4 F4 (FeOF)
#  Gibbs Energy (900 K) = -15.9150,
#  GibbsComputedEntry | mp-755377 | Fe4 O4 F6 (Fe2O2F3)
#  Gibbs Energy (900 K) = -20.1191,
#  GibbsComputedEntry | mp-755385 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -33.4971,
#  GibbsComputedEntry | mp-755406 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -22.3352,
#  GibbsComputedEntry | mp-755423 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -14.9922,
#  GibbsComputedEntry | mp-755469 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.3621,
#  GibbsComputedEntry | mp-755513 | Fe8 O12 F4 (Fe2O3F)
#  Gibbs Energy (900 K) = -12.7920,
#  GibbsComputedEntry | mp-755516 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -19.6510,
#  GibbsComputedEntry | mp-755518 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -24.9375,
#  GibbsComputedEntry | mp-755567 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -6.6714,
#  GibbsComputedEntry | mp-755601 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -16.2801,
#  GibbsComputedEntry | mp-755670 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -8.6329,
#  GibbsComputedEntry | mp-755677 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -20.1191,
#  GibbsComputedEntry | mp-755700 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -12.6696,
#  GibbsComputedEntry | mp-755729 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -24.5965,
#  GibbsComputedEntry | mp-755758 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -21.4334,
#  GibbsComputedEntry | mp-755761 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.3515,
#  GibbsComputedEntry | mp-755763 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -33.4496,
#  GibbsComputedEntry | mp-755765 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -32.0583,
#  GibbsComputedEntry | mp-755772 | Fe8 O8 F8 (FeOF)
#  Gibbs Energy (900 K) = -23.3758,
#  GibbsComputedEntry | mp-755823 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -17.7632,
#  GibbsComputedEntry | mp-755833 | Fe6 O11 F1 (Fe6O11F)
#  Gibbs Energy (900 K) = -15.5103,
#  GibbsComputedEntry | mp-755836 | Fe6 O1 F11 (Fe6OF11)
#  Gibbs Energy (900 K) = -35.4476,
#  GibbsComputedEntry | mp-755846 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -22.3967,
#  GibbsComputedEntry | mp-755850 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.1687,
#  GibbsComputedEntry | mp-755857 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -22.2461,
#  GibbsComputedEntry | mp-755863 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -22.2318,
#  GibbsComputedEntry | mp-755879 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.2713,
#  GibbsComputedEntry | mp-755885 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -15.4030,
#  GibbsComputedEntry | mp-755890 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -18.1342,
#  GibbsComputedEntry | mp-755912 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -23.5677,
#  GibbsComputedEntry | mp-755914 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.8070,
#  GibbsComputedEntry | mp-755917 | Fe10 O15 F5 (Fe2O3F)
#  Gibbs Energy (900 K) = -33.2648,
#  GibbsComputedEntry | mp-755923 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -25.0748,
#  GibbsComputedEntry | mp-755929 | Fe10 O6 F14 (Fe5O3F7)
#  Gibbs Energy (900 K) = -51.1113,
#  GibbsComputedEntry | mp-755945 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -15.7094,
#  GibbsComputedEntry | mp-755958 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -17.9482,
#  GibbsComputedEntry | mp-755963 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -24.7103,
#  GibbsComputedEntry | mp-755966 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.3718,
#  GibbsComputedEntry | mp-755992 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -22.6684,
#  GibbsComputedEntry | mp-755997 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -24.7932,
#  GibbsComputedEntry | mp-756000 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.5262,
#  GibbsComputedEntry | mp-756001 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -22.4951,
#  GibbsComputedEntry | mp-756004 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -24.6164,
#  GibbsComputedEntry | mp-756010 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -7.6283,
#  GibbsComputedEntry | mp-756011 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -31.1410,
#  GibbsComputedEntry | mp-756026 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -17.6692,
#  GibbsComputedEntry | mp-756033 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.3642,
#  GibbsComputedEntry | mp-756047 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -12.0902,
#  GibbsComputedEntry | mp-756055 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -16.1852,
#  GibbsComputedEntry | mp-756101 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -24.5603,
#  GibbsComputedEntry | mp-756114 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -39.7782,
#  GibbsComputedEntry | mp-756120 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -24.9411,
#  GibbsComputedEntry | mp-756133 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.6590,
#  GibbsComputedEntry | mp-756189 | Fe10 O11 F9 (Fe10O11F9)
#  Gibbs Energy (900 K) = -43.0371,
#  GibbsComputedEntry | mp-756208 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -24.7180,
#  GibbsComputedEntry | mp-756209 | Fe8 O4 F12 (Fe2OF3)
#  Gibbs Energy (900 K) = -37.0378,
#  GibbsComputedEntry | mp-756247 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.1308,
#  GibbsComputedEntry | mp-756283 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -44.9651,
#  GibbsComputedEntry | mp-756379 | Fe6 O1 F11 (Fe6OF11)
#  Gibbs Energy (900 K) = -35.6000,
#  GibbsComputedEntry | mp-756387 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.2386,
#  GibbsComputedEntry | mp-756396 | Fe8 O12 F4 (Fe2O3F)
#  Gibbs Energy (900 K) = -16.0646,
#  GibbsComputedEntry | mp-756453 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -17.8744,
#  GibbsComputedEntry | mp-756693 | Fe13 O15 (Fe13O15)
#  Gibbs Energy (900 K) = -14.5464,
#  GibbsComputedEntry | mp-756716 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -17.0819,
#  GibbsComputedEntry | mp-756720 | Fe10 O11 F9 (Fe10O11F9)
#  Gibbs Energy (900 K) = -43.0271,
#  GibbsComputedEntry | mp-756778 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -5.8810,
#  GibbsComputedEntry | mp-756779 | Fe8 O12 F4 (Fe2O3F)
#  Gibbs Energy (900 K) = -14.3421,
#  GibbsComputedEntry | mp-756792 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -11.7247,
#  GibbsComputedEntry | mp-756807 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -17.1285,
#  GibbsComputedEntry | mp-756820 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -12.7580,
#  GibbsComputedEntry | mp-756848 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -22.2745,
#  GibbsComputedEntry | mp-757024 | Fe6 O10 F2 (Fe3O5F)
#  Gibbs Energy (900 K) = -17.8670,
#  GibbsComputedEntry | mp-757162 | Bi6 O8 F2 (Bi3O4F)
#  Gibbs Energy (900 K) = -20.7596,
#  GibbsComputedEntry | mp-757202 | K7 Bi9 O24 (K7(Bi3O8)3)
#  Gibbs Energy (900 K) = -38.5246,
#  GibbsComputedEntry | mp-757453 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -11.9216,
#  GibbsComputedEntry | mp-757565 | Fe41 O56 (Fe41O56)
#  Gibbs Energy (900 K) = -107.2072,
#  GibbsComputedEntry | mp-757766 | Fe1 Bi25 O39 (FeBi25O39)
#  Gibbs Energy (900 K) = -71.8584,
#  GibbsComputedEntry | mp-757814 | Fe4 O1 F7 (Fe4OF7)
#  Gibbs Energy (900 K) = -22.6322,
#  GibbsComputedEntry | mp-757852 | Bi16 O25 (Bi16O25)
#  Gibbs Energy (900 K) = -42.0875,
#  GibbsComputedEntry | mp-758159 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.1174,
#  GibbsComputedEntry | mp-758352 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -50.7140,
#  GibbsComputedEntry | mp-758397 | Fe4 O2 F6 (Fe2OF3)
#  Gibbs Energy (900 K) = -21.7069,
#  GibbsComputedEntry | mp-758442 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -26.5825,
#  GibbsComputedEntry | mp-758461 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -26.5138,
#  GibbsComputedEntry | mp-758500 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -26.6571,
#  GibbsComputedEntry | mp-758560 | Fe2 O2 F2 (FeOF)
#  Gibbs Energy (900 K) = -9.5301,
#  GibbsComputedEntry | mp-758585 | Fe4 O7 F1 (Fe4O7F)
#  Gibbs Energy (900 K) = -11.0181,
#  GibbsComputedEntry | mp-758664 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -81.9205,
#  GibbsComputedEntry | mp-758710 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -81.8949,
#  GibbsComputedEntry | mp-758716 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.8666,
#  GibbsComputedEntry | mp-758735 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -32.3025,
#  GibbsComputedEntry | mp-758738 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.3816,
#  GibbsComputedEntry | mp-758773 | Fe16 O16 F16 (FeOF)
#  Gibbs Energy (900 K) = -43.7831,
#  GibbsComputedEntry | mp-758782 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.5446,
#  GibbsComputedEntry | mp-758871 | Fe4 O6 F2 (Fe2O3F)
#  Gibbs Energy (900 K) = -13.7293,
#  GibbsComputedEntry | mp-758879 | Fe2 O4 F2 (FeO2F)
#  Gibbs Energy (900 K) = -4.9523,
#  GibbsComputedEntry | mp-758902 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.4152,
#  GibbsComputedEntry | mp-758946 | Fe2 O3 F1 (Fe2O3F)
#  Gibbs Energy (900 K) = -6.7811,
#  GibbsComputedEntry | mp-759027 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.0819,
#  GibbsComputedEntry | mp-759031 | Bi38 O54 F6 (Bi19(O9F)3)
#  Gibbs Energy (900 K) = -112.0282,
#  GibbsComputedEntry | mp-759037 | Fe9 O10 (Fe9O10)
#  Gibbs Energy (900 K) = -14.3478,
#  GibbsComputedEntry | mp-759058 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -53.9473,
#  GibbsComputedEntry | mp-759080 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.8897,
#  GibbsComputedEntry | mp-759113 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -32.0050,
#  GibbsComputedEntry | mp-759130 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -82.0307,
#  GibbsComputedEntry | mp-759192 | Fe8 O8 F8 (FeOF)
#  Gibbs Energy (900 K) = -36.0455,
#  GibbsComputedEntry | mp-759193 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -36.3496,
#  GibbsComputedEntry | mp-759222 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -76.1266,
#  GibbsComputedEntry | mp-759247 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.3603,
#  GibbsComputedEntry | mp-759248 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -47.6122,
#  GibbsComputedEntry | mp-759259 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -32.1227,
#  GibbsComputedEntry | mp-759262 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -53.7487,
#  GibbsComputedEntry | mp-759268 | Fe16 O16 F16 (FeOF)
#  Gibbs Energy (900 K) = -74.4338,
#  GibbsComputedEntry | mp-759283 | Fe4 O4 F4 (FeOF)
#  Gibbs Energy (900 K) = -18.6970,
#  GibbsComputedEntry | mp-759284 | Fe16 O16 F16 (FeOF)
#  Gibbs Energy (900 K) = -40.4743,
#  GibbsComputedEntry | mp-759295 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.0934,
#  GibbsComputedEntry | mp-759331 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -51.9295,
#  GibbsComputedEntry | mp-759395 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -13.8946,
#  GibbsComputedEntry | mp-759405 | Bi12 O8 F20 (Bi3O2F5)
#  Gibbs Energy (900 K) = -74.2636,
#  GibbsComputedEntry | mp-759425 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -30.1128,
#  GibbsComputedEntry | mp-759427 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -83.1660,
#  GibbsComputedEntry | mp-759436 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -81.9419,
#  GibbsComputedEntry | mp-759467 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -53.8292,
#  GibbsComputedEntry | mp-759475 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.7540,
#  GibbsComputedEntry | mp-759478 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.0611,
#  GibbsComputedEntry | mp-759490 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -80.9477,
#  GibbsComputedEntry | mp-759497 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.6467,
#  GibbsComputedEntry | mp-759503 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -44.4120,
#  GibbsComputedEntry | mp-759504 | Fe10 O11 (Fe10O11)
#  Gibbs Energy (900 K) = -21.8825,
#  GibbsComputedEntry | mp-759531 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -24.1446,
#  GibbsComputedEntry | mp-759543 | Fe4 O4 F4 (FeOF)
#  Gibbs Energy (900 K) = -19.0514,
#  GibbsComputedEntry | mp-759546 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -51.9394,
#  GibbsComputedEntry | mp-759551 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -81.9846,
#  GibbsComputedEntry | mp-759561 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -82.0126,
#  GibbsComputedEntry | mp-759562 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -25.0387,
#  GibbsComputedEntry | mp-759563 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.6404,
#  GibbsComputedEntry | mp-759566 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -24.2058,
#  GibbsComputedEntry | mp-759590 | Fe4 O7 F1 (Fe4O7F)
#  Gibbs Energy (900 K) = -11.1056,
#  GibbsComputedEntry | mp-759592 | Fe8 O8 F8 (FeOF)
#  Gibbs Energy (900 K) = -38.1124,
#  GibbsComputedEntry | mp-759595 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -81.8333,
#  GibbsComputedEntry | mp-759659 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -49.1709,
#  GibbsComputedEntry | mp-759660 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -81.0497,
#  GibbsComputedEntry | mp-759674 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -49.4134,
#  GibbsComputedEntry | mp-759697 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -55.1826,
#  GibbsComputedEntry | mp-759730 | Fe1 Bi25 O40 (Fe(Bi5O8)5)
#  Gibbs Energy (900 K) = -71.6848,
#  GibbsComputedEntry | mp-759749 | K4 Fe4 O8 (KFeO2)
#  Gibbs Energy (900 K) = -19.9554,
#  GibbsComputedEntry | mp-759750 | Bi12 O12 F12 (BiOF)
#  Gibbs Energy (900 K) = -56.7919,
#  GibbsComputedEntry | mp-759778 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -81.3859,
#  GibbsComputedEntry | mp-759798 | Bi28 O24 F36 (Bi7(O2F3)3)
#  Gibbs Energy (900 K) = -151.3631,
#  GibbsComputedEntry | mp-759825 | Bi4 O4 F4 (BiOF)
#  Gibbs Energy (900 K) = -19.2638,
#  GibbsComputedEntry | mp-759848 | Bi16 O20 F8 (Bi4O5F2)
#  Gibbs Energy (900 K) = -58.2340,
#  GibbsComputedEntry | mp-759870 | Bi16 O16 F16 (BiOF)
#  Gibbs Energy (900 K) = -76.7133,
#  GibbsComputedEntry | mp-759880 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -29.8488,
#  GibbsComputedEntry | mp-759883 | Bi2 O2 F2 (BiOF)
#  Gibbs Energy (900 K) = -9.7640,
#  GibbsComputedEntry | mp-759894 | Bi14 O12 F18 (Bi7(O2F3)3)
#  Gibbs Energy (900 K) = -75.1852,
#  GibbsComputedEntry | mp-759914 | Fe4 O4 F4 (FeOF)
#  Gibbs Energy (900 K) = -7.4603,
#  GibbsComputedEntry | mp-759927 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -54.0910,
#  GibbsComputedEntry | mp-759961 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -51.2620,
#  GibbsComputedEntry | mp-759971 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -82.0045,
#  GibbsComputedEntry | mp-759985 | Bi12 O8 F20 (Bi3O2F5)
#  Gibbs Energy (900 K) = -73.4571,
#  GibbsComputedEntry | mp-760059 | Bi20 O28 F4 (Bi5O7F)
#  Gibbs Energy (900 K) = -61.0160,
#  GibbsComputedEntry | mp-760162 | Bi16 O16 F16 (BiOF)
#  Gibbs Energy (900 K) = -78.5394,
#  GibbsComputedEntry | mp-760230 | Bi20 O16 F28 (Bi5O4F7)
#  Gibbs Energy (900 K) = -112.0004,
#  GibbsComputedEntry | mp-760319 | Bi20 O28 F4 (Bi5O7F)
#  Gibbs Energy (900 K) = -61.5835,
#  GibbsComputedEntry | mp-760370 | Bi24 O20 F32 (Bi6O5F8)
#  Gibbs Energy (900 K) = -131.9435,
#  GibbsComputedEntry | mp-760758 | Bi6 O8 F2 (Bi3O4F)
#  Gibbs Energy (900 K) = -19.4396,
#  GibbsComputedEntry | mp-761108 | Bi4 O4 F4 (BiOF)
#  Gibbs Energy (900 K) = -18.7102,
#  GibbsComputedEntry | mp-761704 | Bi16 O20 F8 (Bi4O5F2)
#  Gibbs Energy (900 K) = -60.1263,
#  GibbsComputedEntry | mp-762304 | Bi4 O4 F4 (BiOF)
#  Gibbs Energy (900 K) = -19.7185,
#  GibbsComputedEntry | mp-762863 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -33.7531,
#  GibbsComputedEntry | mp-762996 | Fe8 O8 F8 (FeOF)
#  Gibbs Energy (900 K) = -24.5853,
#  GibbsComputedEntry | mp-763002 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -25.2417,
#  GibbsComputedEntry | mp-763013 | Fe8 O4 F12 (Fe2OF3)
#  Gibbs Energy (900 K) = -24.7679,
#  GibbsComputedEntry | mp-763017 | Fe8 O12 F4 (Fe2O3F)
#  Gibbs Energy (900 K) = -7.1563,
#  GibbsComputedEntry | mp-763020 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.8699,
#  GibbsComputedEntry | mp-763021 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -18.3652,
#  GibbsComputedEntry | mp-763022 | Fe8 O8 F8 (FeOF)
#  Gibbs Energy (900 K) = -36.4178,
#  GibbsComputedEntry | mp-763023 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -31.3977,
#  GibbsComputedEntry | mp-763029 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -16.4863,
#  GibbsComputedEntry | mp-763065 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -12.9196,
#  GibbsComputedEntry | mp-763068 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -35.2662,
#  GibbsComputedEntry | mp-763342 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -14.2245,
#  GibbsComputedEntry | mp-763353 | Fe4 O5 F3 (Fe4O5F3)
#  Gibbs Energy (900 K) = -15.8370,
#  GibbsComputedEntry | mp-763358 | Fe4 O1 F7 (Fe4OF7)
#  Gibbs Energy (900 K) = -22.8188,
#  GibbsComputedEntry | mp-763436 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -27.1755,
#  GibbsComputedEntry | mp-763484 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.8492,
#  GibbsComputedEntry | mp-763491 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -19.2442,
#  GibbsComputedEntry | mp-763787 | Fe8 O9 (Fe8O9)
#  Gibbs Energy (900 K) = -17.7929,
#  GibbsComputedEntry | mp-764326 | Fe12 O13 (Fe12O13)
#  Gibbs Energy (900 K) = -25.2474,
#  GibbsComputedEntry | mp-764417 | Fe14 O15 (Fe14O15)
#  Gibbs Energy (900 K) = -29.8036,
#  GibbsComputedEntry | mp-764510 | Fe18 O18 F18 (FeOF)
#  Gibbs Energy (900 K) = -81.9973,
#  GibbsComputedEntry | mp-764668 | Fe4 O1 F7 (Fe4OF7)
#  Gibbs Energy (900 K) = -22.6289,
#  GibbsComputedEntry | mp-764745 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.8095,
#  GibbsComputedEntry | mp-764747 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -55.0827,
#  GibbsComputedEntry | mp-764813 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -53.9350,
#  GibbsComputedEntry | mp-764882 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -31.6525,
#  GibbsComputedEntry | mp-764883 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -22.1616,
#  GibbsComputedEntry | mp-764884 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -10.5910,
#  GibbsComputedEntry | mp-764890 | Fe12 O12 F12 (FeOF)
#  Gibbs Energy (900 K) = -31.9635,
# ...
#  GibbsComputedEntry | mp-777845 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.2806,
#  GibbsComputedEntry | mp-777847 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.3937,
#  GibbsComputedEntry | mp-777876 | Fe10 O6 F14 (Fe5O3F7)
#  Gibbs Energy (900 K) = -51.9623,
#  GibbsComputedEntry | mp-777881 | Fe10 O11 F9 (Fe10O11F9)
#  Gibbs Energy (900 K) = -43.2113,
#  GibbsComputedEntry | mp-777933 | Fe6 O5 F7 (Fe6O5F7)
#  Gibbs Energy (900 K) = -28.5489,
#  GibbsComputedEntry | mp-778124 | Fe10 O6 F14 (Fe5O3F7)
#  Gibbs Energy (900 K) = 1.0110,
#  GibbsComputedEntry | mp-778157 | Fe10 O6 F14 (Fe5O3F7)
#  Gibbs Energy (900 K) = -33.6852,
#  GibbsComputedEntry | mp-778182 | Fe10 O6 F14 (Fe5O3F7)
#  Gibbs Energy (900 K) = -32.9671,
#  GibbsComputedEntry | mp-778225 | Fe10 O6 F14 (Fe5O3F7)
#  Gibbs Energy (900 K) = -51.1593,
#  GibbsComputedEntry | mp-778247 | Fe10 O6 F14 (Fe5O3F7)
#  Gibbs Energy (900 K) = -44.2472,
#  GibbsComputedEntry | mp-778248 | Fe10 O6 F14 (Fe5O3F7)
#  Gibbs Energy (900 K) = -51.3060,
#  GibbsComputedEntry | mp-778467 | Fe10 O6 F14 (Fe5O3F7)
#  Gibbs Energy (900 K) = -31.5627,
#  GibbsComputedEntry | mp-778603 | Fe10 O4 F16 (Fe5(OF4)2)
#  Gibbs Energy (900 K) = -35.6094,
#  GibbsComputedEntry | mp-778668 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -29.8615,
#  GibbsComputedEntry | mp-778791 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -45.7397,
#  GibbsComputedEntry | mp-778809 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -35.8922,
#  GibbsComputedEntry | mp-778990 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -33.7225,
#  GibbsComputedEntry | mp-779018 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -16.9296,
#  GibbsComputedEntry | mp-779047 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -35.9089,
#  GibbsComputedEntry | mp-779063 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -17.1439,
#  GibbsComputedEntry | mp-779163 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -35.9659,
#  GibbsComputedEntry | mp-779334 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -35.9574,
#  GibbsComputedEntry | mp-779339 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -18.3780,
#  GibbsComputedEntry | mp-779354 | Fe6 O1 F11 (Fe6OF11)
#  Gibbs Energy (900 K) = -35.3065,
#  GibbsComputedEntry | mp-779359 | Fe10 O19 F1 (Fe10O19F)
#  Gibbs Energy (900 K) = -24.3146,
#  GibbsComputedEntry | mp-779369 | Fe10 O4 F16 (Fe5(OF4)2)
#  Gibbs Energy (900 K) = -53.6021,
#  GibbsComputedEntry | mp-779386 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -30.6420,
#  GibbsComputedEntry | mp-779412 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -18.4858,
#  GibbsComputedEntry | mp-779451 | Fe4 O2 F6 (Fe2OF3)
#  Gibbs Energy (900 K) = -21.4845,
#  GibbsComputedEntry | mp-779526 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -14.7504,
#  GibbsComputedEntry | mp-779538 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -22.7382,
#  GibbsComputedEntry | mp-779595 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -18.6106,
#  GibbsComputedEntry | mp-779613 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -15.6889,
#  GibbsComputedEntry | mp-779614 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -35.9600,
#  GibbsComputedEntry | mp-779615 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -23.8185,
#  GibbsComputedEntry | mp-779774 | Fe10 O11 F9 (Fe10O11F9)
#  Gibbs Energy (900 K) = -43.2159,
#  GibbsComputedEntry | mp-779894 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -24.7650,
#  GibbsComputedEntry | mp-779897 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -24.9700,
#  GibbsComputedEntry | mp-779899 | Fe6 O7 F6 (Fe6O7F6)
#  Gibbs Energy (900 K) = -26.3353,
#  GibbsComputedEntry | mp-779903 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -25.1664,
#  GibbsComputedEntry | mp-779913 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -33.8601,
#  GibbsComputedEntry | mp-779987 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -33.6455,
#  GibbsComputedEntry | mp-780097 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -22.8170,
#  GibbsComputedEntry | mp-780099 | Fe8 O4 F12 (Fe2OF3)
#  Gibbs Energy (900 K) = -42.5653,
#  GibbsComputedEntry | mp-780103 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -32.2135,
#  GibbsComputedEntry | mp-780121 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -16.7102,
#  GibbsComputedEntry | mp-780128 | Fe10 O5 F15 (Fe2OF3)
#  Gibbs Energy (900 K) = -53.0549,
#  GibbsComputedEntry | mp-780129 | Fe10 O5 F15 (Fe2OF3)
#  Gibbs Energy (900 K) = -53.3052,
#  GibbsComputedEntry | mp-780146 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -19.8393,
#  GibbsComputedEntry | mp-780183 | Fe8 O4 F12 (Fe2OF3)
#  Gibbs Energy (900 K) = -28.5401,
#  GibbsComputedEntry | mp-780299 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -14.0163,
#  GibbsComputedEntry | mp-780310 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -17.9793,
#  GibbsComputedEntry | mp-780328 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -31.2129,
#  GibbsComputedEntry | mp-780434 | Fe10 O11 F9 (Fe10O11F9)
#  Gibbs Energy (900 K) = -43.4421,
#  GibbsComputedEntry | mp-780489 | Fe6 O7 F5 (Fe6O7F5)
#  Gibbs Energy (900 K) = -25.0228,
#  GibbsComputedEntry | mp-780491 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -38.9823,
#  GibbsComputedEntry | mp-780496 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -28.9684,
#  GibbsComputedEntry | mp-780508 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -32.7758,
#  GibbsComputedEntry | mp-780514 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -13.9931,
#  GibbsComputedEntry | mp-780515 | Fe10 O16 F4 (Fe5(O4F)2)
#  Gibbs Energy (900 K) = -31.1779,
#  GibbsComputedEntry | mp-780519 | Fe6 O4 F8 (Fe3(OF2)2)
#  Gibbs Energy (900 K) = -18.8077,
#  GibbsComputedEntry | mp-780581 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -24.4508,
#  GibbsComputedEntry | mp-780740 | Fe8 O2 F14 (Fe4OF7)
#  Gibbs Energy (900 K) = -28.4392,
#  GibbsComputedEntry | mp-780760 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -47.0261,
#  GibbsComputedEntry | mp-780766 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.3059,
#  GibbsComputedEntry | mp-780773 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.7492,
#  GibbsComputedEntry | mp-780793 | Fe10 O11 F9 (Fe10O11F9)
#  Gibbs Energy (900 K) = -43.0496,
#  GibbsComputedEntry | mp-780797 | Fe10 O11 F9 (Fe10O11F9)
#  Gibbs Energy (900 K) = -42.9919,
#  GibbsComputedEntry | mp-780800 | Fe10 O11 F9 (Fe10O11F9)
#  Gibbs Energy (900 K) = -42.8202,
#  GibbsComputedEntry | mp-780801 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.5331,
#  GibbsComputedEntry | mp-780854 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -10.4582,
#  GibbsComputedEntry | mp-780855 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -12.5775,
#  GibbsComputedEntry | mp-780858 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -12.3685,
#  GibbsComputedEntry | mp-780861 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -22.3200,
#  GibbsComputedEntry | mp-780868 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -22.1532,
#  GibbsComputedEntry | mp-780870 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -22.0772,
#  GibbsComputedEntry | mp-780891 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -20.3462,
#  GibbsComputedEntry | mp-780895 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -15.0293,
#  GibbsComputedEntry | mp-780974 | Fe10 O11 F9 (Fe10O11F9)
#  Gibbs Energy (900 K) = -43.1202,
#  GibbsComputedEntry | mp-780978 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -27.0615,
#  GibbsComputedEntry | mp-781010 | Fe7 O3 F9 (Fe7(OF3)3)
#  Gibbs Energy (900 K) = -32.8981,
#  GibbsComputedEntry | mp-781048 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -39.0242,
#  GibbsComputedEntry | mp-781055 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -23.4943,
#  GibbsComputedEntry | mp-781077 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -19.9738,
#  GibbsComputedEntry | mp-781080 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -28.4484,
#  GibbsComputedEntry | mp-781507 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -31.7063,
#  GibbsComputedEntry | mp-781606 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -19.0013,
#  GibbsComputedEntry | mp-781954 | Fe10 O4 F16 (Fe5(OF4)2)
#  Gibbs Energy (900 K) = -54.0847,
#  GibbsComputedEntry | mp-782635 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -11.9757,
#  GibbsComputedEntry | mp-782638 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -21.6312,
#  GibbsComputedEntry | mp-782646 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -22.1710,
#  GibbsComputedEntry | mp-849275 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.3237,
#  GibbsComputedEntry | mp-849296 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.4553,
#  GibbsComputedEntry | mp-849300 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.9913,
#  GibbsComputedEntry | mp-849306 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.3472,
#  GibbsComputedEntry | mp-849307 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.7751,
#  GibbsComputedEntry | mp-849314 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.5244,
#  GibbsComputedEntry | mp-849379 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.1691,
#  GibbsComputedEntry | mp-849381 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.9339,
#  GibbsComputedEntry | mp-849419 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.3175,
#  GibbsComputedEntry | mp-849483 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.9675,
#  GibbsComputedEntry | mp-849484 | Fe10 O9 F11 (Fe10O9F11)
#  Gibbs Energy (900 K) = -46.2994,
#  GibbsComputedEntry | mp-850222 | Fe2 O4 (FeO2)
#  Gibbs Energy (900 K) = -2.9023,
#  GibbsComputedEntry | mp-850223 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -27.3352,
#  GibbsComputedEntry | mp-850329 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -39.2023,
#  GibbsComputedEntry | mp-850340 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -24.7161,
#  GibbsComputedEntry | mp-850341 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -36.9572,
#  GibbsComputedEntry | mp-850364 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -24.9742,
#  GibbsComputedEntry | mp-850393 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -21.7417,
#  GibbsComputedEntry | mp-850409 | Fe10 O5 F15 (Fe2OF3)
#  Gibbs Energy (900 K) = -53.2072,
#  GibbsComputedEntry | mp-850422 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -22.9422,
#  GibbsComputedEntry | mp-850739 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -21.6176,
#  GibbsComputedEntry | mp-850746 | Fe8 O6 F10 (Fe4O3F5)
#  Gibbs Energy (900 K) = -36.2152,
#  GibbsComputedEntry | mp-850757 | Fe6 O2 F10 (Fe3OF5)
#  Gibbs Energy (900 K) = -33.3598,
#  GibbsComputedEntry | mp-850875 | Fe8 O4 F12 (Fe2OF3)
#  Gibbs Energy (900 K) = -42.1411,
#  GibbsComputedEntry | mp-850878 | Fe4 O5 F3 (Fe4O5F3)
#  Gibbs Energy (900 K) = -15.8715,
#  GibbsComputedEntry | mp-850880 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -15.5642,
#  GibbsComputedEntry | mp-850883 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -31.7068,
#  GibbsComputedEntry | mp-850886 | Fe8 O10 F6 (Fe4O5F3)
#  Gibbs Energy (900 K) = -26.7269,
#  GibbsComputedEntry | mp-850901 | Fe6 O8 F4 (Fe3(O2F)2)
#  Gibbs Energy (900 K) = -13.3795,
#  GibbsComputedEntry | mp-850933 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -17.5085,
#  GibbsComputedEntry | mp-850934 | Fe6 O11 F1 (Fe6O11F)
#  Gibbs Energy (900 K) = -15.4647,
#  GibbsComputedEntry | mp-850996 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -22.2001,
#  GibbsComputedEntry | mp-851089 | Fe10 O15 F5 (Fe2O3F)
#  Gibbs Energy (900 K) = -34.0587,
#  GibbsComputedEntry | mp-863316 | Fe2 O6 (FeO3)
#  Gibbs Energy (900 K) = 0.0359,
#  GibbsComputedEntry | mp-863367 | K6 Bi6 O18 (KBiO3)
#  Gibbs Energy (900 K) = -30.8964,
#  GibbsComputedEntry | mp-863766 | Fe32 O35 (Fe32O35)
#  Gibbs Energy (900 K) = 13.1600,
#  GibbsComputedEntry | mp-867793 | Fe6 O6 F6 (FeOF)
#  Gibbs Energy (900 K) = -24.4738,
#  GibbsComputedEntry | mp-867934 | K8 F24 (KF3)
#  Gibbs Energy (900 K) = -29.7241,
#  GibbsComputedEntry | mp-974002 | O2 F6 (OF3)
#  Gibbs Energy (900 K) = 5.5997,
#  GibbsComputedEntry | mp-976802 | K2 F4 (KF2)
#  Gibbs Energy (900 K) = -9.4639,
#  GibbsComputedEntry | mp-982040 | K1 Bi1 O3 (KBiO3)
#  Gibbs Energy (900 K) = -4.6455,
#  GibbsComputedEntry | mp-997552 | Fe10 O14 F6 (Fe5O7F3)
#  Gibbs Energy (900 K) = -19.6638,
#  GibbsComputedEntry | mp-997553 | Fe8 O14 F2 (Fe4O7F)
#  Gibbs Energy (900 K) = -9.2093,
#  GibbsComputedEntry | mp-998913 | K1 O3 (KO3)
#  Gibbs Energy (900 K) = -0.2587,
#  GibbsComputedEntry | mvc-10374 | Bi8 O18 (Bi4O9)
#  Gibbs Energy (900 K) = -14.5678,
#  GibbsComputedEntry | mvc-10966 | Fe2 O4 (FeO2)
#  Gibbs Energy (900 K) = 6.3264,
#  GibbsComputedEntry | mvc-11360 | Bi2 O2 F2 (BiOF)
#  Gibbs Energy (900 K) = -9.8059,
#  GibbsComputedEntry | mvc-11541 | Fe2 O4 (FeO2)
#  Gibbs Energy (900 K) = -2.0820,
#  GibbsComputedEntry | mvc-11993 | Fe4 O8 (FeO2)
#  Gibbs Energy (900 K) = -7.8460,
#  GibbsComputedEntry | mvc-11999 | Fe4 O8 (FeO2)
#  Gibbs Energy (900 K) = -2.2071,
#  GibbsComputedEntry | mvc-12039 | Fe10 O14 (Fe5O7)
#  Gibbs Energy (900 K) = -23.9244,
#  GibbsComputedEntry | mvc-12063 | Fe12 O24 (FeO2)
#  Gibbs Energy (900 K) = -2.3635,
#  GibbsComputedEntry | mvc-12125 | Fe4 O8 (FeO2)
#  Gibbs Energy (900 K) = -0.9353,
#  GibbsComputedEntry | mvc-12204 | Fe12 O24 (FeO2)
#  Gibbs Energy (900 K) = -23.1130,
#  GibbsComputedEntry | mvc-12205 | Fe9 O13 (Fe9O13)
#  Gibbs Energy (900 K) = -21.0401,
#  GibbsComputedEntry | mvc-12905 | Fe4 O8 (FeO2)
#  Gibbs Energy (900 K) = -6.7389,
#  GibbsComputedEntry | mvc-13181 | Fe16 O32 (FeO2)
#  Gibbs Energy (900 K) = -7.1710,
#  GibbsComputedEntry | mvc-13234 | Fe12 O24 (FeO2)
#  Gibbs Energy (900 K) = 3.5786,
#  GibbsComputedEntry | mvc-13490 | Bi4 O10 (Bi2O5)
#  Gibbs Energy (900 K) = -5.0223,
#  GibbsComputedEntry | mvc-13496 | Bi1 F5 (BiF5)
#  Gibbs Energy (900 K) = -7.9119,
#  GibbsComputedEntry | mvc-13960 | Fe2 F8 (FeF4)
#  Gibbs Energy (900 K) = -14.0548,
#  GibbsComputedEntry | mvc-14925 | Fe1 O2 (FeO2)
#  Gibbs Energy (900 K) = -1.1767,
#  GibbsComputedEntry | mvc-15135 | Fe12 O24 (FeO2)
#  Gibbs Energy (900 K) = -22.7337,
#  GibbsComputedEntry | mvc-15392 | Bi4 O8 (BiO2)
#  Gibbs Energy (900 K) = -10.0244,
#  GibbsComputedEntry | mvc-15798 | Bi2 F10 (BiF5)
#  Gibbs Energy (900 K) = -18.4315,
#  GibbsComputedEntry | mvc-15971 | Bi2 O4 (BiO2)
#  Gibbs Energy (900 K) = -1.9235,
#  GibbsComputedEntry | mvc-15980 | Bi2 F8 (BiF4)
#  Gibbs Energy (900 K) = -17.1605,
#  GibbsComputedEntry | mvc-3518 | Bi4 F20 (BiF5)
#  Gibbs Energy (900 K) = -36.9774,
#  GibbsComputedEntry | mvc-4274 | Bi4 O8 (BiO2)
#  Gibbs Energy (900 K) = -8.1639,
#  GibbsComputedEntry | mvc-4364 | Bi4 O8 (BiO2)
#  Gibbs Energy (900 K) = -8.8499,
#  GibbsComputedEntry | mvc-4554 | Bi4 O10 (Bi2O5)
#  Gibbs Energy (900 K) = -6.2923,
#  GibbsComputedEntry | mvc-5220 | Bi12 O24 (BiO2)
#  Gibbs Energy (900 K) = -26.9314,
#  GibbsComputedEntry | mvc-5760 | Bi8 O16 (BiO2)
#  Gibbs Energy (900 K) = -19.8839,
#  GibbsComputedEntry | mvc-5860 | Bi16 O32 (BiO2)
#  Gibbs Energy (900 K) = -38.6118,
#  GibbsComputedEntry | mvc-5967 | Fe8 O16 (FeO2)
#  Gibbs Energy (900 K) = -12.3250,
#  GibbsComputedEntry | mvc-6081 | Bi4 O8 (BiO2)
#  Gibbs Energy (900 K) = -8.8285,
#  GibbsComputedEntry | mvc-6083 | Bi2 F10 (BiF5)
#  Gibbs Energy (900 K) = -16.8054,
#  GibbsComputedEntry | mvc-6615 | Bi4 O8 (BiO2)
#  Gibbs Energy (900 K) = -10.3855,
#  GibbsComputedEntry | mvc-6945 | Bi2 O4 (BiO2)
#  Gibbs Energy (900 K) = -4.1943,
#  GibbsComputedEntry | mvc-7514 | Bi16 O40 (Bi2O5)
#  Gibbs Energy (900 K) = -27.1974,
#  GibbsComputedEntry | mvc-8471 | Bi4 O10 (Bi2O5)
#  Gibbs Energy (900 K) = -7.4102,
#  GibbsComputedEntry | mvc-8880 | Bi8 O20 (Bi2O5)
#  Gibbs Energy (900 K) = -12.9887,
#  GibbsComputedEntry | mvc-9064 | Bi12 O28 (Bi3O7)
#  Gibbs Energy (900 K) = -23.7407,
#  GibbsComputedEntry | mvc-9645 | Bi4 O8 (BiO2)
#  Gibbs Energy (900 K) = -9.6004,
#  GibbsComputedEntry | mvc-9818 | Bi12 O24 (BiO2)
#  Gibbs Energy (900 K) = -27.0932,
#  NISTReferenceEntry | Fe2O3
#  Gibbs Energy (900 K) = -6.0787,
#  NISTReferenceEntry | Fe3O4
#  Gibbs Energy (900 K) = -8.5239,
#  NISTReferenceEntry | FeF2
#  Gibbs Energy (900 K) = -6.0246,
#  NISTReferenceEntry | FeF3
#  Gibbs Energy (900 K) = -8.6977,
#  NISTReferenceEntry | FeO
#  Gibbs Energy (900 K) = -2.2088,
#  NISTReferenceEntry | K2O
#  Gibbs Energy (900 K) = -2.4604,
#  NISTReferenceEntry | K2O2
#  Gibbs Energy (900 K) = -3.0692,
#  NISTReferenceEntry | KF
#  Gibbs Energy (900 K) = -4.9420,
#  NISTReferenceEntry | KO2
#  Gibbs Energy (900 K) = -1.6296,
#  NISTReferenceEntry | OF2
#  Gibbs Energy (900 K) = 0.7952}

# %% [markdown]
# The `GibbsEntrySet` class has many helpful functions, such as the following `filter_by_stability()` function, which automatically removes entries which are a specified energy per atom above the convex hull of stability:

# %%
entry_set = entry_set.filter_by_stability(0.025)
entry_set.entries_list
# Out:
# [GibbsComputedEntry | mp-23152 | Bi2 (Bi)
#  Gibbs Energy (900 K) = 0.0000,
#  GibbsComputedEntry | mp-32597 | Bi13 O20 (Bi13O20)
#  Gibbs Energy (900 K) = -34.7901,
#  GibbsComputedEntry | mp-766354 | Bi25 O38 (Bi25O38)
#  Gibbs Energy (900 K) = -66.6518,
#  GibbsComputedEntry | mp-753309 | Bi4 O2 F8 (Bi2OF4)
#  Gibbs Energy (900 K) = -27.1079,
#  GibbsComputedEntry | mp-759405 | Bi12 O8 F20 (Bi3O2F5)
#  Gibbs Energy (900 K) = -74.2636,
#  GibbsComputedEntry | mp-757162 | Bi6 O8 F2 (Bi3O4F)
#  Gibbs Energy (900 K) = -20.7596,
#  GibbsComputedEntry | mp-30303 | Bi8 O14 (Bi4O7)
#  Gibbs Energy (900 K) = -22.1389,
#  GibbsComputedEntry | mp-1190898 | Bi7 O5 F11 (Bi7O5F11)
#  Gibbs Energy (900 K) = -42.2368,
#  FREEDReferenceEntry | BiF3
#  Gibbs Energy (900 K) = -7.2191,
#  GibbsComputedEntry | mvc-15980 | Bi2 F8 (BiF4)
#  Gibbs Energy (900 K) = -17.1605,
#  GibbsComputedEntry | mvc-3518 | Bi4 F20 (BiF5)
#  Gibbs Energy (900 K) = -36.9774,
#  GibbsComputedEntry | mp-762304 | Bi4 O4 F4 (BiOF)
#  Gibbs Energy (900 K) = -19.7185,
#  GibbsComputedEntry | mp-753455 | Bi4 O4 F12 (BiOF3)
#  Gibbs Energy (900 K) = -30.5291,
#  GibbsComputedEntry | mp-561203 | F4 (F2)
#  Gibbs Energy (900 K) = 0.0000,
#  GibbsComputedEntry | mp-13 | Fe1 (Fe)
#  Gibbs Energy (900 K) = 0.0000,
#  GibbsComputedEntry | mp-759730 | Fe1 Bi25 O40 (Fe(Bi5O8)5)
#  Gibbs Energy (900 K) = -71.6848,
#  GibbsComputedEntry | mp-1178401 | Fe10 O1 F19 (Fe10OF19)
#  Gibbs Energy (900 K) = -60.6080,
#  NISTReferenceEntry | Fe2O3
#  Gibbs Energy (900 K) = -6.0787,
#  NISTReferenceEntry | Fe3O4
#  Gibbs Energy (900 K) = -8.5239,
#  GibbsComputedEntry | mp-504615 | Fe8 Bi4 O18 (Fe4Bi2O9)
#  Gibbs Energy (900 K) = -36.6824,
#  GibbsComputedEntry | mp-757766 | Fe1 Bi25 O39 (FeBi25O39)
#  Gibbs Energy (900 K) = -71.8584,
#  GibbsComputedEntry | mp-23501 | Fe2 Bi2 O6 (FeBiO3)
#  Gibbs Energy (900 K) = -11.8862,
#  FREEDReferenceEntry | FeF2
#  Gibbs Energy (900 K) = -6.0261,
#  NISTReferenceEntry | FeF3
#  Gibbs Energy (900 K) = -8.6977,
#  FREEDReferenceEntry | FeO
#  Gibbs Energy (900 K) = -2.2090,
#  GibbsComputedEntry | mp-1184905 | K20 (K)
#  Gibbs Energy (900 K) = 0.0000,
#  GibbsComputedEntry | mp-558482 | K17 Fe5 O16 (K17Fe5O16)
#  Gibbs Energy (900 K) = -44.8875,
#  GibbsComputedEntry | mp-561290 | K8 Bi4 F20 (K2BiF5)
#  Gibbs Energy (900 K) = -77.0045,
#  GibbsComputedEntry | mp-555579 | K16 Fe8 F40 (K2FeF5)
#  Gibbs Energy (900 K) = -152.5706,
#  NISTReferenceEntry | K2O
#  Gibbs Energy (900 K) = -2.4604,
#  NISTReferenceEntry | K2O2
#  Gibbs Energy (900 K) = -3.0692,
#  GibbsComputedEntry | mp-569940 | K6 Bi2 (K3Bi)
#  Gibbs Energy (900 K) = -1.4035,
#  GibbsComputedEntry | mp-29524 | K12 Bi4 O12 (K3BiO3)
#  Gibbs Energy (900 K) = -34.4893,
#  GibbsComputedEntry | mp-30120 | K6 Bi2 O8 (K3BiO4)
#  Gibbs Energy (900 K) = -18.4280,
#  GibbsComputedEntry | mp-1201518 | K6 Fe10 F30 (K3Fe5F15)
#  Gibbs Energy (900 K) = -103.0198,
#  GibbsComputedEntry | mp-1111491 | K3 Fe1 F6 (K3FeF6)
#  Gibbs Energy (900 K) = -24.0286,
#  GibbsComputedEntry | mp-28696 | K12 Fe4 O16 (K3FeO4)
#  Gibbs Energy (900 K) = -33.9465,
#  GibbsComputedEntry | mp-29542 | K8 Bi4 O10 (K4Bi2O5)
#  Gibbs Energy (900 K) = -27.0516,
#  GibbsComputedEntry | mp-1223773 | K5 Bi4 (K5Bi4)
#  Gibbs Energy (900 K) = -1.4570,
#  GibbsComputedEntry | mp-12040 | K40 Fe8 O32 (K5FeO4)
#  Gibbs Energy (900 K) = -88.8080,
#  GibbsComputedEntry | mp-559498 | K36 Bi20 O52 (K9Bi5O13)
#  Gibbs Energy (900 K) = -130.5879,
#  GibbsComputedEntry | mp-31104 | K16 Bi16 (KBi)
#  Gibbs Energy (900 K) = -5.0668,
#  GibbsComputedEntry | mp-23279 | K2 Bi4 (KBi2)
#  Gibbs Energy (900 K) = -0.7734,
#  GibbsComputedEntry | mp-1211670 | K2 Bi6 F20 (KBi3F10)
#  Gibbs Energy (900 K) = -63.5834,
#  GibbsComputedEntry | mp-557724 | K2 Bi2 F12 (KBiF6)
#  Gibbs Energy (900 K) = -31.4120,
#  GibbsComputedEntry | mp-30988 | K2 Bi2 O4 (KBiO2)
#  Gibbs Energy (900 K) = -9.9307,
#  GibbsComputedEntry | mp-29799 | K12 Bi12 O36 (KBiO3)
#  Gibbs Energy (900 K) = -62.3497,
#  NISTReferenceEntry | KF
#  Gibbs Energy (900 K) = -4.9420,
#  GibbsComputedEntry | mp-558155 | K2 Fe2 F8 (KFeF4)
#  Gibbs Energy (900 K) = -27.8631,
#  GibbsComputedEntry | mp-759749 | K4 Fe4 O8 (KFeO2)
#  Gibbs Energy (900 K) = -19.9554,
#  NISTReferenceEntry | KO2
#  Gibbs Energy (900 K) = -1.6296,
#  GibbsComputedEntry | mp-12957 | O8 (O2)
#  Gibbs Energy (900 K) = 0.0000]

# %%
[e.composition.reduced_formula for e in entry_set.entries_list]
# Out:
# ['Bi',
#  'Bi13O20',
#  'Bi25O38',
#  'Bi2OF4',
#  'Bi3O2F5',
#  'Bi3O4F',
#  'Bi4O7',
#  'Bi7O5F11',
#  'BiF3',
#  'BiF4',
#  'BiF5',
#  'BiOF',
#  'BiOF3',
#  'F2',
#  'Fe',
#  'Fe(Bi5O8)5',
#  'Fe10OF19',
#  'Fe2O3',
#  'Fe3O4',
#  'Fe4Bi2O9',
#  'FeBi25O39',
#  'FeBiO3',
#  'FeF2',
#  'FeF3',
#  'FeO',
#  'K',
#  'K17Fe5O16',
#  'K2BiF5',
#  'K2FeF5',
#  'K2O',
#  'K2O2',
#  'K3Bi',
#  'K3BiO3',
#  'K3BiO4',
#  'K3Fe5F15',
#  'K3FeF6',
#  'K3FeO4',
#  'K4Bi2O5',
#  'K5Bi4',
#  'K5FeO4',
#  'K9Bi5O13',
#  'KBi',
#  'KBi2',
#  'KBi3F10',
#  'KBiF6',
#  'KBiO2',
#  'KBiO3',
#  'KF',
#  'KFeF4',
#  'KFeO2',
#  'KO2',
#  'O2']

# %% [markdown]
# In this case, we remove all non-stable entries from the entry set, which greatly reduces the combinatorial complexity of the system:

# %% [markdown]
# ## Building the reaction network
#
# The reaction network can be initialized by providing 3 arguments to the `ReactionNetwork` class:
#
# 1. **entries:** iterable of entry-like objects (e.g., `GibbsComputedEntry`)
# 2. **enumerators:** iterable of enumerators which will be called during the build of the network
# 3. **cost_function:** the function used to calculate the cost of each reaction edge
#
# We will use a BasicEnumerator (see the **Enumerators Demo Notebook** for more information on the type of enumerators available):

# %%
be = BasicEnumerator()

# %% [markdown]
# The cost function is a monotonic function used to assign weights to edges in the network. In this case, we will use the softplus function, assigned a temperature scaling of $T=900$ K, and use the default arguments which automatically determine the softplus weighting based on the energy per atom of the reaction:

# %%
cf = Softplus(900)

# %% [markdown]
# Finally, we provide these as arugments to the `ReactionNetwork` initialization:

# %%
rn = ReactionNetwork(entry_set, [be], cf)

# %% [markdown]
# This simply initializes a `ReactionNetwork` object but does not build the network graph. To do so, we call the `.build()` function:

# %%
rn.build()
# Out:
# Ray is not initialized. Trying with environment variables!
# Could not identify existing Ray instance. Creating a new one...
# 2022-03-14 17:00:36,919	INFO services.py:1374 -- View the Ray dashboard at http://127.0.0.1:8265
# [{'NodeID': '8b7888ecf9b3bf9fe5fdf2b1374afccd0091b0180d649a69979c5d26', 'Alive': True, 'NodeManagerAddress': '127.0.0.1', 'NodeManagerHostname': 'MacBook-Pro-3.dhcp.lbl.gov.dhcp.lbl.gov', 'NodeManagerPort': 56338, 'ObjectManagerPort': 56337, 'ObjectStoreSocketName': '/tmp/ray/session_2022-03-14_17-00-33_089231_74555/sockets/plasma_store', 'RayletSocketName': '/tmp/ray/session_2022-03-14_17-00-33_089231_74555/sockets/raylet', 'MetricsExportPort': 57898, 'alive': True, 'Resources': {'object_store_memory': 4807687372.0, 'memory': 9615374747.0, 'node:127.0.0.1': 1.0, 'CPU': 12.0}}]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [01:08<00:00,  2.64s/it]
# INFO:ReactionNetwork:Building graph from reactions...

# %% [markdown]
# This should have completed within a few seconds. You'll notice that two things happened:
#
# 1. The enumerator(s) were run and a list of reactions was generated
# 2. The weighted graph object was built with these reactions and stored under the `graph` attribute of the reaction network object
#
# We can access this graph object, which is a graph-tool object, by using the `graph` attribute:

# %%
rn.graph
# Out:
# <Graph object, directed, with 2002 vertices and 12305 edges, 2 internal vertex properties, 3 internal edge properties, at 0x1496b41f0>

# %% [markdown]
# There are a couple provided ways to plot reaction networks. The first is to use the built in drawing features in graph-tool, which have been provided in a wrapper function:

# %%
plot_network(rn.graph);
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 plot_network(rn.graph)
#
# File ~/PycharmProjects/reaction-network/src/rxn_network/network/visualize.py:39, in plot_network(graph, vertex_cmap_name, edge_cmap_name, output, cost_pos_scale_factor)
#      34 edge_weights = gt.prop_to_size(
#      35     g.new_edge_property("float", cost_pos_scale_factor * costs), mi=0.1, ma=35
#      36 )
#      38 deg = gt.prop_to_size(g.degree_property_map("total"), mi=0.5, ma=22)
# ---> 39 layout = gt.sfdp_layout(g, vweight=deg, eweight=edge_weights)
#      41 chemsys_names = [g.vp["entry"][v].chemsys for v in g.vertices()]
#      43 edge_width = [1.4 if g.ep["cost"][e] != 0 else 0.1 for e in g.edges()]
#
# File ~/opt/miniconda3/envs/rn_dev/lib/python3.9/site-packages/graph_tool/draw/__init__.py:680, in sfdp_layout(g, vweight, eweight, pin, groups, C, K, p, theta, max_level, r, gamma, mu, kappa, init_step, cooling_step, adaptive_cooling, epsilon, max_iter, pos, multilevel, coarse_method, mivs_thres, ec_thres, weighted_coarse, verbose)
#     678         print("with K =", K, "...")
#     679         count += 1
# --> 680     pos = sfdp_layout(u, pos=pos,
#     681                       vweight=vcount if weighted_coarse else None,
#     682                       eweight=ecount if weighted_coarse else None,
#     683                       groups=groups,
#     684                       C=C, K=K, p=p,
#     685                       theta=theta, gamma=gamma, mu=mu,
#     686                       epsilon=epsilon,
#     687                       max_iter=max_iter,
#     688                       cooling_step=cooling_step,
#     689                       adaptive_cooling=False,
#     690                       # init_step=max(2 * K,
#     691                       #               _avg_edge_distance(u, pos)),
#     692                       multilevel=False,
#     693                       verbose=False)
#     694 pos = g_.own_property(pos)
#     695 return pos
#
# File ~/opt/miniconda3/envs/rn_dev/lib/python3.9/site-packages/graph_tool/draw/__init__.py:713, in sfdp_layout(g, vweight, eweight, pin, groups, C, K, p, theta, max_level, r, gamma, mu, kappa, init_step, cooling_step, adaptive_cooling, epsilon, max_iter, pos, multilevel, coarse_method, mivs_thres, ec_thres, weighted_coarse, verbose)
#     710 c = label_components(g)[0]
#     712 libgraph_tool_layout.sanitize_pos(g._Graph__graph, _prop("v", g, pos))
# --> 713 libgraph_tool_layout.sfdp_layout(g._Graph__graph, _prop("v", g, pos),
#     714                                  _prop("v", g, vweight),
#     715                                  _prop("e", g, eweight),
#     716                                  _prop("v", g, pin),
#     717                                  (C, K, p, gamma, mu, kappa, groups, r,
#     718                                   _prop("v", g, c)),
#     719                                  theta, init_step, cooling_step, max_level,
#     720                                  epsilon, max_iter, not adaptive_cooling,
#     721                                  verbose, _get_rng())
#     722 pos = g_.own_property(pos)
#     723 return pos
#
# KeyboardInterrupt:

# %% [markdown]
# You'll notice that at this stage, the reaction network graph is a collection of "sub"-networks, i.e. a collection of smaller reaction networks for smaller chemical subsystems. This configuration will change once we set up for pathfinding in the next section.

# %% [markdown]
# The second way to plot graphs is to use graphistry, which requires setting up an account on Graphistry Hub: https://hub.graphistry.com/

# %%
plot_network_on_graphistry(rn.graph)
# Out:
# Must install optional dependencies: pygraphistry, networkx, and pyintergraph!

# %% [markdown]
# ### Solving for reaction pathways
#
# To solve for reaction pathways, we must set precursor phases, as well as a target phase. This will automatically build all the required "zero-cost" edges which connect the different chemical subsystems. Please see the original manuscript for more detail with regards to how this works. In short, zero-cost edges are drawn between and product node to any reactant node that contains a subset of the set consisting of the {precursors + products} phases.

# %%
rn.set_precursors([entry_set.get_min_entry_by_formula("BiOF"), 
                   entry_set.get_min_entry_by_formula("KFeO2")])

# %%
rn.set_target("BiFeO3")

# %% [markdown]
# We can see how this changes the network by re-drawing it:

# %%
plot_network(rn.graph, output="Bi-Fe-O-K-F.png");

# %% [markdown]
# You should now see that the chemical subsystems have come together -- this is due to the zero-cost edges that were just described. We can now perform pathfinding to extract reaction pathways.
#
# To get reaction pathways, we simply call the `find_pathways()` method. This automatically handles finding pathways to multiple targets, by calling the internal shortest paths method. The _k_ parameter specifies the number of shortest paths to find to each target.

# %%
paths = rn.find_pathways(["BiFeO3","KF"], k=3)
# Out:
# PATHS to FeBiO3
#
# ---------------------------------------
#
# BiOF + KFeO2 -> KF + FeBiO3 (dG = -0.138 eV/atom)
# Total Cost: 0.234
#
# 6 BiOF -> Bi3O4F + Bi3O2F5 (dG = 0.035 eV/atom)
# 2 KFeO2 + Bi3O2F5 -> K2BiF5 + 2 FeBiO3 (dG = -0.144 eV/atom)
# Total Cost: 0.506
#
# 4 BiOF -> Bi3O4F + BiF3 (dG = 0.177 eV/atom)
# KFeO2 + 0.6667 BiF3 -> 0.3333 K3FeF6 + 0.6667 FeBiO3 (dG = -0.326 eV/atom)
# Total Cost: 0.507
#
# PATHS to KF
#
# ---------------------------------------
#
# BiOF + KFeO2 -> KF + FeBiO3 (dG = -0.138 eV/atom)
# Total Cost: 0.234
#
# 2 KFeO2 -> Fe2O3 + K2O (dG = 0.18 eV/atom)
# BiOF + K2O -> KBiO2 + KF (dG = -0.42 eV/atom)
# Total Cost: 0.492
#
# BiOF + 0.1667 KFeO2 -> 0.1667 KFeF4 + 0.3333 Bi3O4F (dG = -0.006 eV/atom)
# 1.5 KFeO2 + 0.5 KFeF4 -> Fe2O3 + 2 KF (dG = -0.168 eV/atom)
# Total Cost: 0.492

# %% [markdown]
# The output of this method is a list of `BasicPathway` objects. Note that these objects contain a list of reactions and associated costs, but the actual pathway is typically not balanced:

# %%
print(paths[5])
# Out:
# BiOF + 0.1667 KFeO2 -> 0.1667 KFeF4 + 0.3333 Bi3O4F (dG = -0.006 eV/atom)
# 1.5 KFeO2 + 0.5 KFeF4 -> Fe2O3 + 2 KF (dG = -0.168 eV/atom)
# Total Cost: 0.492

# %% [markdown]
# This means that the reactions you see above do not necessarily include all reactants, nor do they include form all desired products. They are simply a series of reactions extracted from the reaction network that maybe encountered as the system attempts to get from starter phases to target phases.
#
# To actually get balanced reactions, we can use the `PathwaySolver` class. This class takes a set of entries, a list of `BasicPathway` objects, as well as a cost function, and can be used to solve for balanced pathways given a net reaction. First we initialize the class:

# %%
rn.entries.entries_list
# Out:
# [GibbsComputedEntry | mp-23152 | Bi2 (Bi)
#  Gibbs Energy (900 K) = 0.0000,
#  GibbsComputedEntry | mp-32597 | Bi13 O20 (Bi13O20)
#  Gibbs Energy (900 K) = -34.7901,
#  GibbsComputedEntry | mp-766354 | Bi25 O38 (Bi25O38)
#  Gibbs Energy (900 K) = -66.6518,
#  GibbsComputedEntry | mp-753309 | Bi4 O2 F8 (Bi2OF4)
#  Gibbs Energy (900 K) = -27.1079,
#  GibbsComputedEntry | mp-759405 | Bi12 O8 F20 (Bi3O2F5)
#  Gibbs Energy (900 K) = -74.2636,
#  GibbsComputedEntry | mp-757162 | Bi6 O8 F2 (Bi3O4F)
#  Gibbs Energy (900 K) = -20.7596,
#  GibbsComputedEntry | mp-30303 | Bi8 O14 (Bi4O7)
#  Gibbs Energy (900 K) = -22.1389,
#  GibbsComputedEntry | mp-1190898 | Bi7 O5 F11 (Bi7O5F11)
#  Gibbs Energy (900 K) = -42.2368,
#  FREEDReferenceEntry | BiF3
#  Gibbs Energy (900 K) = -7.2191,
#  GibbsComputedEntry | mvc-15980 | Bi2 F8 (BiF4)
#  Gibbs Energy (900 K) = -17.1605,
#  GibbsComputedEntry | mvc-3518 | Bi4 F20 (BiF5)
#  Gibbs Energy (900 K) = -36.9774,
#  GibbsComputedEntry | mp-762304 | Bi4 O4 F4 (BiOF)
#  Gibbs Energy (900 K) = -19.7185,
#  GibbsComputedEntry | mp-753455 | Bi4 O4 F12 (BiOF3)
#  Gibbs Energy (900 K) = -30.5291,
#  GibbsComputedEntry | mp-561203 | F4 (F2)
#  Gibbs Energy (900 K) = 0.0000,
#  GibbsComputedEntry | mp-13 | Fe1 (Fe)
#  Gibbs Energy (900 K) = 0.0000,
#  GibbsComputedEntry | mp-759730 | Fe1 Bi25 O40 (Fe(Bi5O8)5)
#  Gibbs Energy (900 K) = -71.6848,
#  GibbsComputedEntry | mp-1178401 | Fe10 O1 F19 (Fe10OF19)
#  Gibbs Energy (900 K) = -60.6080,
#  NISTReferenceEntry | Fe2O3
#  Gibbs Energy (900 K) = -6.0787,
#  NISTReferenceEntry | Fe3O4
#  Gibbs Energy (900 K) = -8.5239,
#  GibbsComputedEntry | mp-504615 | Fe8 Bi4 O18 (Fe4Bi2O9)
#  Gibbs Energy (900 K) = -36.6824,
#  GibbsComputedEntry | mp-757766 | Fe1 Bi25 O39 (FeBi25O39)
#  Gibbs Energy (900 K) = -71.8584,
#  GibbsComputedEntry | mp-23501 | Fe2 Bi2 O6 (FeBiO3)
#  Gibbs Energy (900 K) = -11.8862,
#  FREEDReferenceEntry | FeF2
#  Gibbs Energy (900 K) = -6.0261,
#  NISTReferenceEntry | FeF3
#  Gibbs Energy (900 K) = -8.6977,
#  FREEDReferenceEntry | FeO
#  Gibbs Energy (900 K) = -2.2090,
#  GibbsComputedEntry | mp-1184905 | K20 (K)
#  Gibbs Energy (900 K) = 0.0000,
#  GibbsComputedEntry | mp-558482 | K17 Fe5 O16 (K17Fe5O16)
#  Gibbs Energy (900 K) = -44.8875,
#  GibbsComputedEntry | mp-561290 | K8 Bi4 F20 (K2BiF5)
#  Gibbs Energy (900 K) = -77.0045,
#  GibbsComputedEntry | mp-555579 | K16 Fe8 F40 (K2FeF5)
#  Gibbs Energy (900 K) = -152.5706,
#  NISTReferenceEntry | K2O
#  Gibbs Energy (900 K) = -2.4604,
#  NISTReferenceEntry | K2O2
#  Gibbs Energy (900 K) = -3.0692,
#  GibbsComputedEntry | mp-569940 | K6 Bi2 (K3Bi)
#  Gibbs Energy (900 K) = -1.4035,
#  GibbsComputedEntry | mp-29524 | K12 Bi4 O12 (K3BiO3)
#  Gibbs Energy (900 K) = -34.4893,
#  GibbsComputedEntry | mp-30120 | K6 Bi2 O8 (K3BiO4)
#  Gibbs Energy (900 K) = -18.4280,
#  GibbsComputedEntry | mp-1201518 | K6 Fe10 F30 (K3Fe5F15)
#  Gibbs Energy (900 K) = -103.0198,
#  GibbsComputedEntry | mp-1111491 | K3 Fe1 F6 (K3FeF6)
#  Gibbs Energy (900 K) = -24.0286,
#  GibbsComputedEntry | mp-28696 | K12 Fe4 O16 (K3FeO4)
#  Gibbs Energy (900 K) = -33.9465,
#  GibbsComputedEntry | mp-29542 | K8 Bi4 O10 (K4Bi2O5)
#  Gibbs Energy (900 K) = -27.0516,
#  GibbsComputedEntry | mp-1223773 | K5 Bi4 (K5Bi4)
#  Gibbs Energy (900 K) = -1.4570,
#  GibbsComputedEntry | mp-12040 | K40 Fe8 O32 (K5FeO4)
#  Gibbs Energy (900 K) = -88.8080,
#  GibbsComputedEntry | mp-559498 | K36 Bi20 O52 (K9Bi5O13)
#  Gibbs Energy (900 K) = -130.5879,
#  GibbsComputedEntry | mp-31104 | K16 Bi16 (KBi)
#  Gibbs Energy (900 K) = -5.0668,
#  GibbsComputedEntry | mp-23279 | K2 Bi4 (KBi2)
#  Gibbs Energy (900 K) = -0.7734,
#  GibbsComputedEntry | mp-1211670 | K2 Bi6 F20 (KBi3F10)
#  Gibbs Energy (900 K) = -63.5834,
#  GibbsComputedEntry | mp-557724 | K2 Bi2 F12 (KBiF6)
#  Gibbs Energy (900 K) = -31.4120,
#  GibbsComputedEntry | mp-30988 | K2 Bi2 O4 (KBiO2)
#  Gibbs Energy (900 K) = -9.9307,
#  GibbsComputedEntry | mp-29799 | K12 Bi12 O36 (KBiO3)
#  Gibbs Energy (900 K) = -62.3497,
#  NISTReferenceEntry | KF
#  Gibbs Energy (900 K) = -4.9420,
#  GibbsComputedEntry | mp-558155 | K2 Fe2 F8 (KFeF4)
#  Gibbs Energy (900 K) = -27.8631,
#  GibbsComputedEntry | mp-759749 | K4 Fe4 O8 (KFeO2)
#  Gibbs Energy (900 K) = -19.9554,
#  NISTReferenceEntry | KO2
#  Gibbs Energy (900 K) = -1.6296,
#  GibbsComputedEntry | mp-12957 | O8 (O2)
#  Gibbs Energy (900 K) = 0.0000]

# %%
ps = PathwaySolver(rn.entries, paths, Softplus(900)) # open_elem="O", chempot=0

# %% [markdown]
# To balance the pathways, we must provide a net reaction representing the total conversion of precursors to final products. This corresponds to the assisted metathesis reaction we defined in the beginning. We can automatically make this reaction by initializing a `ComputedReaction` object from the corresponding entries:

# %%
product_entries = []
for i in ["BiFeO3","KF"]:
    product_entries.append(entry_set.get_min_entry_by_formula(i))
    
net_rxn = ComputedReaction.balance(rn.precursors,product_entries)
net_rxn
# Out:
# BiOF + KFeO2 -> FeBiO3 + KF

# %% [markdown]
# Finally, we provide the net reaction to the `PathwaySolver` object. Note that the _intermediate_rxn_energy_cutoff_ helps to limit which intermediate reactions are considered (this can substantially decrease the combinatorial complexity), and the _filter_interdependent_ flag verifies that suggested pathways do not contain interdependnet reactions (i.e. where both the reactants of reaction A depend on the products of the reaction B, and the reactants of reaction B depend on the products of reaction A).
#
# **Note: Even though this step is compiled/parallelized using Numba, this is often the most time-intensive step in the reaction network analysis. Consider limiting the value of the maximum number of combos, as well as the value of the intermediate reaction energy cutoff.**

# %%
balanced_paths = ps.solve(net_rxn, max_num_combos=5, 
                          intermediate_rxn_energy_cutoff=-0.01, 
                          use_minimize_enumerator=True,
                          filter_interdependent=True)
# Out:
# INFO:PathwaySolver:NET RXN: BiOF + KFeO2 -> FeBiO3 + KF
#
# INFO:PathwaySolver:Identifying reactions between intermediates...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 112.70it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 25.60it/s]
# INFO:PathwaySolver:Found 76 intermediate reactions!
# INFO:PathwaySolver:Solving for balanced pathways of size 4 ...
# 0/500000: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:14<00:00, 14.18s/it]
# INFO:PathwaySolver:Solving for balanced pathways of size 5 ...
# 4000000/4500000: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [03:01<00:00, 20.22s/it]

# %% [markdown]
# We can now print the suggested, balanced reaction pathways:

# %%
for idx, path in enumerate(balanced_paths):
    print(f"Path {idx+1}", "\n")
    print(path)
    print("\n")

# %%
from rxn_network.pathways.pathway_set import PathwaySet

# %%
path_set = PathwaySet.from_paths(balanced_paths)
path_set.get_paths()

# %% [markdown]
# We note that **Pathway 12 most closely matches the experimentally observed reaction pathway** (ordering subject to change in the future).
#
# However, many of the pathways include hypothetical (never-before-synthesized) materials (e.g., Li3MnO3), so the top-ranked pathway does not necessarily match what is experimentally observed.

# %% [markdown]
# ### Running networks with Fireworks
#
# The `NetworkFW` class allows you to easily run the reaction network construction and pathfinding analysis via fireworks. Simply create a network firework, add it to the LaunchPad, and launch it on your computing resource. See the documentation for more information about each of the parameters.

# %%
from fireworks import LaunchPad, Workflow
from rxn_network.fireworks.core import NetworkFW

# %%
lpad = LaunchPad.auto_load()

# %%
fw = NetworkFW([BasicEnumerator()], Softplus(900), chemsys="Y-Mn-O-Li-Cl-C", entry_set_params={"e_above_hull":0.020}, 
               pathway_params={"precursors":["YCl3","Mn2O3","Li2CO3"], "targets":["YMnO3","LiCl","CO2"], "k":5},
              solver_params={"max_num_combos":5, "intermediate_rxn_energy_cutoff":0.0, "use_minimize_enumerator": True})

# %%
lpad.add_wf(Workflow([fw]))
# Out:
# 2021-12-15 10:35:24,318 INFO Added a workflow. id_map: {-6: 3873}
# INFO:launchpad:Added a workflow. id_map: {-6: 3873}
# {-6: 3873}

# %%
# !rlaunch singleshot
# Out:
# 2021-12-15 10:35:28,591 INFO Hostname/IP lookup (this will take a few seconds)
# 2021-12-15 10:35:28,618 INFO Launching Rocket
# 2021-12-15 10:35:32,880 INFO RUNNING fw_id: 3873 in directory: /Users/mcdermott/PycharmProjects/reaction-network/notebooks
# 2021-12-15 10:35:33,031 INFO Task started: {{rxn_network.firetasks.build_inputs.EntriesFromDb}}.
# 2021-12-15 10:35:45,587 INFO Task completed: {{rxn_network.firetasks.build_inputs.EntriesFromDb}}
# 2021-12-15 10:35:45,727 INFO Task started: {{rxn_network.firetasks.run_calc.BuildNetwork}}.
# Li-Mn: 100%|████████████████████████████████████| 57/57 [10:02<00:00, 10.57s/it]
# PATHS to YMnO3
#
# ---------------------------------------
#
# 0.6667 Mn2O3 + Li2CO3 -> LiMnCO4 + 0.3333 Li3MnO3 (dG = 0.1 eV/atom)
# YCl3 + Li3MnO3 -> 3 LiCl + YMnO3 (dG = -0.215 eV/atom)
# Total Cost: 0.508
#
# Mn2O3 + 2 Li2CO3 -> LiMn(CO3)2 + Li3MnO3 (dG = 0.148 eV/atom)
# YCl3 + Li3MnO3 -> 3 LiCl + YMnO3 (dG = -0.215 eV/atom)
# Total Cost: 0.52
#
# 0.3333 Mn2O3 + Li2CO3 -> CO2 + 0.6667 Li3MnO3 (dG = 0.214 eV/atom)
# YCl3 + Li3MnO3 -> 3 LiCl + YMnO3 (dG = -0.215 eV/atom)
# Total Cost: 0.538
#
# 0.5 Mn2O3 + Li2CO3 -> LiMnCO4 + 0.5 Li2O (dG = 0.127 eV/atom)
# YCl3 + 1.5 Li2O -> 3 LiCl + 0.5 Y2O3 (dG = -0.3 eV/atom)
# Mn2O3 + Y2O3 -> 2 YMnO3 (dG = -0.052 eV/atom)
# Total Cost: 0.752
#
# 0.5 Mn2O3 + Li2CO3 -> LiMnCO4 + 0.5 Li2O (dG = 0.127 eV/atom)
# YCl3 + 2 Li2O -> LiYO2 + 3 LiCl (dG = -0.257 eV/atom)
# LiYO2 + Mn2O3 -> LiMnO2 + YMnO3 (dG = -0.081 eV/atom)
# Total Cost: 0.753
#
# PATHS to LiCl
#
# ---------------------------------------
#
# 0.5 Mn2O3 + Li2CO3 -> LiMnCO4 + 0.5 Li2O (dG = 0.127 eV/atom)
# YCl3 + 1.5 Li2O -> 3 LiCl + 0.5 Y2O3 (dG = -0.3 eV/atom)
# Total Cost: 0.499
#
# 0.5 Mn2O3 + Li2CO3 -> LiMnCO4 + 0.5 Li2O (dG = 0.127 eV/atom)
# YCl3 + Li2O -> 2 LiCl + YClO (dG = -0.281 eV/atom)
# Total Cost: 0.502
#
# 0.5 Mn2O3 + Li2CO3 -> LiMnCO4 + 0.5 Li2O (dG = 0.127 eV/atom)
# YCl3 + 2 Li2O -> LiYO2 + 3 LiCl (dG = -0.257 eV/atom)
# Total Cost: 0.507
#
# 0.6667 Mn2O3 + Li2CO3 -> LiMnCO4 + 0.3333 Li3MnO3 (dG = 0.1 eV/atom)
# YCl3 + Li3MnO3 -> 3 LiCl + YMnO3 (dG = -0.215 eV/atom)
# Total Cost: 0.508
#
# 0.5 Mn2O3 + 2 Li2CO3 -> LiMn(CO3)2 + 1.5 Li2O (dG = 0.204 eV/atom)
# YCl3 + 1.5 Li2O -> 3 LiCl + 0.5 Y2O3 (dG = -0.3 eV/atom)
# Total Cost: 0.519
#
# PATHS to CO2
#
# ---------------------------------------
#
# 0.5 Mn2O3 + 0.5 Li2CO3 -> LiMnO2 + 0.5 CO2 (dG = 0.087 eV/atom)
# Total Cost: 0.286
#
# 0.3333 Mn2O3 + Li2CO3 -> CO2 + 0.6667 Li3MnO3 (dG = 0.214 eV/atom)
# Total Cost: 0.319
#
# Li2CO3 -> Li2O + CO2 (dG = 0.323 eV/atom)
# Total Cost: 0.35
#
# 2 Mn2O3 -> Mn3O4 + MnO2 (dG = 0.033 eV/atom)
# Li2CO3 + 2.5 MnO2 -> CO2 + 0.5 Li4Mn5O12 (dG = 0.016 eV/atom)
# Total Cost: 0.541
#
# 2 Mn2O3 -> Mn3O4 + MnO2 (dG = 0.033 eV/atom)
# Li2CO3 + 3 MnO2 -> Li2Mn3O7 + CO2 (dG = 0.024 eV/atom)
# Total Cost: 0.543
#
# 2021-12-15 10:49:21,460 INFO Task completed: {{rxn_network.firetasks.run_calc.BuildNetwork}}
# 2021-12-15 10:49:21,793 INFO Task started: {{rxn_network.firetasks.run_calc.RunSolver}}.
# C-O-Y: 100%|████████████████████████████████████| 29/29 [00:00<00:00, 52.39it/s]
# C-Cl: 100%|█████████████████████████████████████| 44/44 [00:05<00:00,  8.09it/s]
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# PathwaySolver:   0%|          | 0/1 [00:00<?, ?it/s]
# PathwaySolver:   0%|          | 0/2 [00:00<?, ?it/s]
# 2021-12-15 10:51:09,544 INFO Task completed: {{rxn_network.firetasks.run_calc.RunSolver}}
# 2021-12-15 10:51:09,859 INFO Task started: {{rxn_network.firetasks.parse_outputs.NetworkToDb}}.
# 2021-12-15 10:51:10,252 INFO rxn_network.utils.database Updating /Users/mcdermott/PycharmProjects/reaction-network/notebooks with taskid = 82
# 2021-12-15 10:51:10,423 INFO Task completed: {{rxn_network.firetasks.parse_outputs.NetworkToDb}}
# 2021-12-15 10:51:11,881 INFO Rocket finished

# %% [markdown]
# ### Thank you!
#
# If any errors with the reaction-network code are encountered, please raise an Issue here: https://github.com/GENESIS-EFRC/reaction-network/issues

# %%
from maggma.stores import MongoStore
from rxn_network.pathways.pathway_set import PathwaySet

# %%
ms = MongoStore.from_db_file("/Users/mcdermott/db_rn.json")
ms.connect()

# %%
d = ms.query_one({"task_id":82}, ["balanced_pathways"])

# %%
pset = PathwaySet.from_dict(d["balanced_pathways"])
