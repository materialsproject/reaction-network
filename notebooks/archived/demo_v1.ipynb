# %% [markdown]
# # ARCHIVED: reaction-network (Demo Notebook)
# ### Author: Matthew McDermott
# ### Updated: April 12,  2021
#
# This notebook serves as a walkthrough for the basic use of the V1 *reaction-network* code, which is imported as *rxn_network*.
#
# In the following examples, we also recreate the results/analysis originally presented in the manuscript:
#
# **NOTE: The reaction-network code underwent a major refactor which makes this current demo notebook obsolete. However, it is being preserved/archived for reference, as it contains the examples used in the original paper.**

# %% [markdown]
# ## Imports
# The following imports are required to access the Materials Project database and construct/analyze the networks.

# %%
import logging
import pickle
import json
import numpy as np
import itertools
from datetime import date

from monty.json import MontyDecoder

import graph_tool.all as gt

from rxn_network.core import ReactionNetwork
from pymatgen.entries.computed_entries import GibbsComputedStructureEntry
from rxn_network.helpers import find_interdependent_rxns
from rxn_network.reaction import Reaction, ComputedReaction

from pymatgen import MPRester, Structure, Element, Composition
from pymatgen.analysis.phase_diagram import PhaseDiagram

logging.info("Logging initialized")
# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-69285a80b3bf> in <module>
#      10 import graph_tool.all as gt
#      11
# ---> 12 from rxn_network.core import ReactionNetwork
#      13 from pymatgen.entries.computed_entries import GibbsComputedStructureEntry
#      14 from rxn_network.helpers import find_interdependent_rxns
#
# ImportError: cannot import name 'ReactionNetwork' from 'rxn_network.core' (/Users/mcdermott/PycharmProjects/reaction-network/src/rxn_network/core/__init__.py)

# %% [markdown]
# This code uses Dask to parallelize the building of the reaction network graph.
#
# The client is initialized below, and the Dask web GUI can be accessed via a local HTTP server (see Dask documentation for further details).

# %%
from dask.distributed import Client
client = Client()
print("Dask client initialized...")
# Out:
# Dask client initialized...

# %% [markdown]
# The following updated method is for backwards compatability with pymatgen's updated GibbsComputedStructureEntry class.

# %%
@classmethod
def new_entry_from_dict(cls, d): 
    """
    Backwards compatability for loading old GibbsComputedStructureEntry objects.
    
    :param d: Dict representation.
    :return: GibbsComputedStructureEntry
    """
    dec = MontyDecoder()
    if "formation_enthalpy" in d:
        formation_enthalpy_per_atom = d["formation_enthalpy"] / Composition(d["composition"]).num_atoms
    else:
        formation_enthalpy_per_atom = d["formation_enthalpy_per_atom"]
        
    return cls(
        dec.process_decoded(d["structure"]),
        formation_enthalpy_per_atom,
        d["temp"],
        d["gibbs_model"],
        composition=d.get("composition", None),
        correction=d["correction"],
        energy_adjustments=[dec.process_decoded(e) for e in d.get("energy_adjustments", {})],
        parameters={k: dec.process_decoded(v) for k, v in d.get("parameters", {}).items()},
        data={k: dec.process_decoded(v) for k, v in d.get("data", {}).items()},
        entry_id=d.get("entry_id", None),
    )

GibbsComputedStructureEntry.from_dict = new_entry_from_dict

# %% [markdown]
# ## Main script
# The following function's code can be run as a standalone script to generate the reaction network and perform pathfinding. In the first example that follows, we will break down each of these steps so it is clear what each section of the script is doing. In the following sections, we will only povide the input parameters and refer you to running the main script yourself.

# %%
def run_reaction_network_analysis(entries, precursors, targets, temp, include_metastable, k, chempots, max_num_combos, interpolate_comps=[]):
    '''
    Args:
        entries ([ComputedStructureEntry]): list of ComputedStructureEntry-
                like objects to consider in network. These can be acquired
                from Materials Project (using MPRester) or created manually in
                pymatgen. Entries should have same compatability (e.g.
                MPCompability) for phase diagram generation.
        precursors ([str]): formulas for all phases which serve as the precursor reactants
        targets ([str]): formulas for all phases which are the final products
        temp (float):  Temperature (in Kelvin) used for estimating Gibbs
                free energy of formation, as well as scaling the cost function
                later during network generation. Must select from [300, 400,
                500, ... 2000] K.
        include_metastable (float): either a) the specified cutoff
                for energy per atom (eV/atom) above hull, or b) True/False
                if considering only stable vs. all entries. An energy cutoff of
                0.1 eV/atom is a reasonable starting threshold for thermodynamic
                stability. Defaults to False.
        k (int): Number of shortest paths to calculate to each target (i.e. if
                there are 3 targets and k=15, then 3x15 = 45 paths will be generated
                and the reactions from these will be combined.
        chempots (dict): Optional dictionary of elemental chemical potentials for calculating 
                predicted reactions from the grand potential phase diagram
        max_num_combos (int):  upper limit on how many reactions to consider at a
                time when combining possible reactions to form a total pathway. (default 4) 
        interpolate_comps ([str]): Optional lst of formulas of compositions which do not have 
                associated entries but should be included in the network construction with an 
                interpolated (hull) energy.

    Returns (tuple): ReactionNetwork object and resulting paths
    '''
            
    rn = ReactionNetwork(entries, temp=temp, interpolate_comps=interpolate_comps, 
                         include_metastable=include_metastable)

    precursors_comps = [Composition(s) for s in precursors]
    targets_comps = [Composition(t) for t in targets]

    precursor_entries = []
    target_entries = []

    for entry in rn._filtered_entries:
        if entry.composition.reduced_composition in precursors_comps:
            precursor_entries.append(entry)
        elif entry.composition.reduced_composition in targets_comps:
            target_entries.append(entry)

    rn.generate_rxn_network(precursor_entries,target_entries)
    paths = rn.find_all_rxn_pathways(k=k, precursors=precursor_entries, consider_crossover_rxns=True, 
                                         max_num_combos=max_num_combos, filter_interdependent=False,
                                        chempots=chempots)
    return rn, paths

# %% [markdown]
# # Example 1: YMnO$_3$ assisted metathesis

# %% [markdown]
# ## Building the phase diagram entries

# %% [markdown]
# First, we acquire Materials Project entries for the C-Cl-Li-Mn-O-Y chemical system via the MPRester API; please see materialsproject.org to create an account and get an API key.
#
# Note: *You may also use your own thermodynamic database entries, but they must be initialized as ComputedStructureEntry objects in pymatgen*.
#
# #### NOTE:  The Materials Project (MP) database is constantly improving, and so it is very likely that the results/predictions here will slightly change with updated data. The original manuscript results were created with MP database version V2020.09.08.

# %%
chemsys = "C-Cl-Li-Mn-O-Y"
with MPRester() as mpr:  # requires API key from Materials Project
    all_entries = mpr.get_entries_in_chemsys(chemsys, inc_structure="final")
# Out:
#   0%|          | 0/898 [00:00<?, ?it/s]
# /Users/mcdermott/miniconda3/envs/rn_submit/lib/python3.8/site-packages/pymatgen/ext/matproj.py:559: FutureWarning: __init__ is deprecated
# MaterialsProjectCompatibility will be updated with new correction classes as well as new values of corrections and uncertainties in 2020
#   entries = MaterialsProjectCompatibility().process_entries(entries)

# %% [markdown]
# Let's first see how many of these entries are stable at T = 0 K by constructing a compositional phase diagram:

# %%
pd_mp = PhaseDiagram(all_entries)
print(pd_mp)
# Out:
# Li-Y-Mn-C-Cl-O phase diagram
# 51 stable phases:
# YCCl, Y2O3, Li2O, LiYO2, YMn12, LiClO4, LiC12, Y2Cl3, Y2Mn2O7, LiO8, LiMnO2, CCl4, MnCO3, MnCl2, LiMn(CO3)2, Li2O2, Mn23C6, O2, Y4C7, Cl2O7, LiCl, Y3C4, Li, Y2C, ClO2, Y, YCl3, Mn2O3, C, YClO, Y4C5, YMnO3, Cl2, Mn3O4, Li2CO3, MnO2, MnO, Li6MnO4, Y12(MnC3)5, LiMn2O4, ClO3, Cl2O, Y(ClO4)3, Li2MnO3, Mn, YMn2O5, Li5Mn7O16, CO2, Mn8Cl3O10, Li4Mn5O12, Y10Mn13C18

# %% [markdown]
# When we initialize the network in the next section, it will attempt to estimate the finite temperature phase diagram via a Gibbs estimation model, such as the SISSO model from Bartel et al. Let's see what that does to the phase diagram at T = 900 K:

# %%
gibbs_entries = GibbsComputedStructureEntry.from_pd(pd_mp, temp=900)
pd_gibbs = PhaseDiagram(gibbs_entries)
print(pd_gibbs)
# Out:
# Li-Y-Mn-C-Cl-O phase diagram
# 41 stable phases:
# MnCO3, Li2MnO3, O2, YMnO3, Y2C, Y2Mn2O7, YClO, Li2CO3, LiMn2O4, LiYO2, MnO, CCl3, LiC12, Y2MnC4, MnO2, Mn8Cl3O10, YMn2O5, Li3MnO3, Y12(MnC3)5, Li6MnO4, LiMnO2, Mn, Y2O3, Mn2O3, Li, Y4C5, YMn12, MnCl2, C, Cl2, Y10Mn13C18, LiCl, Li5Mn7O16, Mn3O4, Li2O, CCl2O, CO2, Y, YCl3, YCCl, Y4C7

# %% [markdown]
# It appears that many structures are destabilized at high temperature according to the Gibbs SISSO descriptor. This will affect how we filter entries to include in the network.

# %% [markdown]
# ## Creating the reaction network

# %% [markdown]
# To create the reaction network, we must first initialize a ReactionNetwork object with a list of ComputedStructureEntry objects (at T = 0 K). This performs necessary preprocessing steps on the list of entries, such as converting them to *GibbsComputedStructureEntry* objects and filtering for thermodynamic stability. Please see the code documentation for more description on the input parameters. In the example below, we will be using a thermodynamic stability cutoff of +20 meV/atom above hull **(this is a tighter cutoff than the one in the manuscript, 30 meV/atom, to lessen the compute time)**

# %%
rn = ReactionNetwork(all_entries, n=2, temp=900, include_metastable=0.020) # include entries <= 20 meV/atom above hull
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f67023e3f699> in <module>
# ----> 1 rn = ReactionNetwork(all_entries, n=2, temp=900, include_metastable=0.020) # include entries <= 20 meV/atom above hull
#
# NameError: name 'ReactionNetwork' is not defined

# %% [markdown]
# To actually create the reaction network graph, we must specify both a list of precursor entries and list of target entries. Either (or both) of these can also be empty; if so, the network will treat these precursor/target nodes as "dummy" nodes, meaning that they will link into/out of every node in the network.
#
# The assisted metathesis reaction reported by Todd & Neilson (2019) we would like to study is the following:
#
# $$ Mn_2O_3 + 2 YCl_3 + 3Li_2CO_3 \to 2YMnO_3 + 6LiCl + 3CO_2 $$

# %% [markdown]
# We first identify the compositions of this reaction and verify that it is correct by having it automatically balanced:

# %%
precursors = ["Mn2O3", "YCl3","Li2CO3"]
targets = ["YMnO3","CO2","LiCl"]

precursors = [Composition(s) for s in precursors]
targets = [Composition(t) for t in targets]

net_rxn = Reaction(precursors,targets)
print(f"Net RXN: {net_rxn}")
# Out:
# Net RXN: 0.5 Mn2O3 + YCl3 + 1.5 Li2CO3 -> YMnO3 + 1.5 CO2 + 3 LiCl

# %% [markdown]
# We then need to select which entries correspond to the precursors and targets. If we only know the compositions we want, we need to iterate through all of the entries to find them:

# %%
precursor_entries = []
target_entries = []

for entry in rn._filtered_entries:
    if entry.composition.reduced_composition in precursors:
        precursor_entries.append(entry)
    elif entry.composition.reduced_composition in targets:
        target_entries.append(entry)

# %% [markdown]
# Finally, we generate the reaction network itself. This process iterates through all possible chemical reactions and creates weighted edges using the designated cost function.
#
# **IMPORTANT NOTE: this particular graph will likely take 3-5 minutes to generate, depending on your CPU specs.** The progress of the calculation can be checked via the Dask web GUI. We strongly recommend you use computing resources for performing these calculations if available to you.

# %%
rn.generate_rxn_network(precursor_entries,target_entries,"softplus")
# Out:
# INFO:ReactionNetwork:Generating reactions by chemical subsystem...
# INFO:ReactionNetwork:Graph creation took 149.8 seconds.
# INFO:ReactionNetwork:Created graph with 3309 nodes and 31302 edges.

# %% [markdown]
# ## Finding shortest pathways

# %% [markdown]
# Now that the graph is  constructed, we can look for shortest paths on the graph to a specific target. For example, we can look at the shortest paths from the precursors to YMnO$_3$ alone.

# %%
ymno3_entry = [t for t in target_entries if t.composition.reduced_formula == "YMnO3"][0]
rn.set_target(ymno3_entry)

paths = rn.find_k_shortest_paths(10)
# Out:
# 2 YCl3 + 9 Mn2O3 -> Y2Mn2O7 + 2 Mn8Cl3O10 (dG = -0.015 eV/atom)
# 0.5 Y2Mn2O7 + 0.5 Mn2O3 -> MnO2 + YMnO3 (dG = 0.005 eV/atom)
# Total Cost: 0.528
#
# 1.5 Li2CO3 + 0.5 Mn2O3 -> Li3MnO3 + 1.5 CO2 (dG = 0.193 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.531
#
# YCl3 + 5 Mn2O3 -> YMn2O5 + Mn8Cl3O10 (dG = -0.025 eV/atom)
# YMn2O5 -> MnO2 + YMnO3 (dG = 0.048 eV/atom)
# Total Cost: 0.535
#
# 2 YCl3 + 9 Mn2O3 -> Y2Mn2O7 + 2 Mn8Cl3O10 (dG = -0.015 eV/atom)
# 2 Y2Mn2O7 -> O2 + 4 YMnO3 (dG = 0.039 eV/atom)
# Total Cost: 0.536
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# MnCO3 + YCl3 -> YMnO3 + CCl3 (dG = 0.393 eV/atom)
# Total Cost: 0.649
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 3.429 Li2MnO3 + 3.286 Mn2O3 -> Li3MnO3 + 0.4286 Li9Mn21O40 (dG = 0.029 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.764
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 3 Li2MnO3 + 2 Mn2O3 -> Li3MnO3 + 3 LiMn2O4 (dG = 0.035 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.765
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 3.6 Li2MnO3 + 3.8 Mn2O3 -> Li3MnO3 + 0.6 Li7Mn17O32 (dG = 0.039 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.766
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# 3.429 Li2MnO3 + 3.286 Mn2O3 -> Li3MnO3 + 0.4286 Li9Mn21O40 (dG = 0.029 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.767
#
# YCl3 + 5 Mn2O3 -> YMn2O5 + Mn8Cl3O10 (dG = -0.025 eV/atom)
# 0.625 Mn2O3 + 0.025 YMn2O5 -> MnO2 + 0.025 YMn12 (dG = 0.363 eV/atom)
# 0.56 MnO2 + 0.04 YMn12 -> MnO + 0.04 YMnO3 (dG = -0.652 eV/atom)
# Total Cost: 0.768

# %% [markdown]
# While this is nice for understanding which reaction(s) lead to YMnO$_3$, this pathway identification contains no enformcent of conservation of mass. Since we know the stoichiometric coefficients of the **net** reaction, we need to combine these shortest paths in a logical way.
#
# Thus net reaction pathways are identified by finding the k shortest paths to each target, and then attempting to combine identified reactions to form a set that satisifies the stoichiometry of the net reaction.
#
# You will see in the output below: 1) the k-shortest paths to each target, 2) a step showing the progress of identification of crossover reactions, and 3) a printed list of all reactions being considered during postprocessing.
#
# **IMPORTANT NOTE: the k-shortest paths algorithm (Yen's algorithm) typically performs very quickly, but the postprocessing of combinations can take some time to generate and balance combinations. Even though it is parallelized, this step may take 5-10 mins depending on your computing specs.** We again strongly recommend the use of computing resources for this task.

# %%
k = 20
max_num_combos = 5
chempots = {Element("O"):0}

paths = rn.find_all_rxn_pathways(k=k, precursors=precursor_entries, targets=target_entries,
                                 consider_crossover_rxns=True, max_num_combos=max_num_combos, 
                                 filter_interdependent=False, chempots=chempots)
# Out:
# INFO:ReactionNetwork:NET RXN: 0.5 Li2CO3 + 0.1667 Mn2O3 + 0.3333 YCl3 -> LiCl + 0.5 CO2 + 0.3333 YMnO3
# PATHS to LiCl
#
# ---------------------------------------
#
# 1.5 Li2CO3 + 0.5 Mn2O3 -> Li3MnO3 + 1.5 CO2 (dG = 0.193 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.531
#
# Li2CO3 -> Li2O + CO2 (dG = 0.308 eV/atom)
# 2 YCl3 + 3 Li2O -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# Total Cost: 0.546
#
# Li2CO3 -> Li2O + CO2 (dG = 0.308 eV/atom)
# YCl3 + Li2O -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# Total Cost: 0.551
#
# Li2CO3 -> Li2O + CO2 (dG = 0.308 eV/atom)
# YCl3 + 2 Li2O -> LiYO2 + 3 LiCl (dG = -0.271 eV/atom)
# Total Cost: 0.554
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 2.286 Li2MnO3 + 1.857 Mn2O3 -> Li2O + 0.2857 Li9Mn21O40 (dG = 0.047 eV/atom)
# 2 YCl3 + 3 Li2O -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# Total Cost: 0.751
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 2.4 Li2MnO3 + 2.2 Mn2O3 -> Li2O + 0.4 Li7Mn17O32 (dG = 0.056 eV/atom)
# 2 YCl3 + 3 Li2O -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# Total Cost: 0.753
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# 2.286 Li2MnO3 + 1.857 Mn2O3 -> Li2O + 0.2857 Li9Mn21O40 (dG = 0.047 eV/atom)
# 2 YCl3 + 3 Li2O -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# Total Cost: 0.754
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 2 Li2MnO3 + Mn2O3 -> Li2O + 2 LiMn2O4 (dG = 0.06 eV/atom)
# 2 YCl3 + 3 Li2O -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# Total Cost: 0.754
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 2.286 Li2MnO3 + 1.857 Mn2O3 -> Li2O + 0.2857 Li9Mn21O40 (dG = 0.047 eV/atom)
# YCl3 + Li2O -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# Total Cost: 0.756
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# 2.4 Li2MnO3 + 2.2 Mn2O3 -> Li2O + 0.4 Li7Mn17O32 (dG = 0.056 eV/atom)
# 2 YCl3 + 3 Li2O -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# Total Cost: 0.756
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# 2 Li2MnO3 + Mn2O3 -> Li2O + 2 LiMn2O4 (dG = 0.06 eV/atom)
# 2 YCl3 + 3 Li2O -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# Total Cost: 0.757
#
# Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2 (dG = 0.086 eV/atom)
# 0.8333 Mn2O3 + 0.3333 LiMnO2 -> 0.1667 Li2O + Mn2O3 (dG = 0.027 eV/atom)
# 2 YCl3 + 3 Li2O -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# Total Cost: 0.757
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 2.4 Li2MnO3 + 2.2 Mn2O3 -> Li2O + 0.4 Li7Mn17O32 (dG = 0.056 eV/atom)
# YCl3 + Li2O -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# Total Cost: 0.758
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# 2.286 Li2MnO3 + 1.857 Mn2O3 -> Li2O + 0.2857 Li9Mn21O40 (dG = 0.047 eV/atom)
# YCl3 + Li2O -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# Total Cost: 0.759
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 2.286 Li2MnO3 + 1.857 Mn2O3 -> Li2O + 0.2857 Li9Mn21O40 (dG = 0.047 eV/atom)
# YCl3 + 2 Li2O -> LiYO2 + 3 LiCl (dG = -0.271 eV/atom)
# Total Cost: 0.759
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 2 Li2MnO3 + Mn2O3 -> Li2O + 2 LiMn2O4 (dG = 0.06 eV/atom)
# YCl3 + Li2O -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# Total Cost: 0.759
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 10 Li2MnO3 + 2.5 Mn2O3 -> Li9Mn15O32 + 5.5 Li2O (dG = 0.083 eV/atom)
# 2 YCl3 + 3 Li2O -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# Total Cost: 0.76
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 11 Li2MnO3 + 4.5 Mn2O3 -> Li9Mn20O40 + 6.5 Li2O (dG = 0.083 eV/atom)
# 2 YCl3 + 3 Li2O -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# Total Cost: 0.76
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# 2.4 Li2MnO3 + 2.2 Mn2O3 -> Li2O + 0.4 Li7Mn17O32 (dG = 0.056 eV/atom)
# YCl3 + Li2O -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# Total Cost: 0.761
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 2.4 Li2MnO3 + 2.2 Mn2O3 -> Li2O + 0.4 Li7Mn17O32 (dG = 0.056 eV/atom)
# YCl3 + 2 Li2O -> LiYO2 + 3 LiCl (dG = -0.271 eV/atom)
# Total Cost: 0.761
#
# PATHS to CO2
#
# ---------------------------------------
#
# Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2 (dG = 0.086 eV/atom)
# Total Cost: 0.286
#
# 1.5 Li2CO3 + 0.5 Mn2O3 -> Li3MnO3 + 1.5 CO2 (dG = 0.193 eV/atom)
# Total Cost: 0.313
#
# Li2CO3 -> Li2O + CO2 (dG = 0.308 eV/atom)
# Total Cost: 0.345
#
# 2 Mn2O3 -> MnO2 + Mn3O4 (dG = 0.015 eV/atom)
# 2 Li2CO3 + 5 MnO2 -> Li4Mn5O12 + 2 CO2 (dG = 0.043 eV/atom)
# Total Cost: 0.544
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# MnCO3 + Mn2O3 -> CO2 + Mn3O4 (dG = 0.022 eV/atom)
# Total Cost: 0.548
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# 1.5 MnCO3 + 3.5 Li2MnO3 -> Li7Mn5O12 + 1.5 CO2 (dG = 0.03 eV/atom)
# Total Cost: 0.55
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# MnCO3 + Li2MnO3 -> CO2 + 2 LiMnO2 (dG = 0.033 eV/atom)
# Total Cost: 0.55
#
# 2 Mn2O3 -> MnO2 + Mn3O4 (dG = 0.015 eV/atom)
# Li2CO3 + MnO2 -> Li2MnO3 + CO2 (dG = 0.072 eV/atom)
# Total Cost: 0.551
#
# Mn2O3 -> MnO + MnO2 (dG = 0.097 eV/atom)
# 2 Li2CO3 + 5 MnO2 -> Li4Mn5O12 + 2 CO2 (dG = 0.043 eV/atom)
# Total Cost: 0.563
#
# Li2CO3 -> Li2O + CO2 (dG = 0.308 eV/atom)
# Li2O + 2 CO2 -> Li2CO3 + CO2 (dG = -0.205 eV/atom)
# Total Cost: 0.566
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# MnCO3 -> MnO + CO2 (dG = 0.11 eV/atom)
# Total Cost: 0.569
#
# Mn2O3 -> MnO + MnO2 (dG = 0.097 eV/atom)
# Li2CO3 + MnO2 -> Li2MnO3 + CO2 (dG = 0.072 eV/atom)
# Total Cost: 0.57
#
# Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2 (dG = 0.086 eV/atom)
# 0.3333 Li2CO3 + 0.6667 CO2 -> 0.3333 Li2O + CO2 (dG = 0.154 eV/atom)
# Total Cost: 0.588
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 2 Li2CO3 + Li2Mn(CO3)2 -> Li6MnO4 + 4 CO2 (dG = 0.249 eV/atom)
# Total Cost: 0.603
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# MnCO3 + 3 Li2CO3 -> Li6MnO4 + 4 CO2 (dG = 0.254 eV/atom)
# Total Cost: 0.608
#
# 1.5 Li2CO3 + 0.5 Mn2O3 -> Li3MnO3 + 1.5 CO2 (dG = 0.193 eV/atom)
# 0.3333 Li2CO3 + 0.6667 CO2 -> 0.3333 Li2O + CO2 (dG = 0.154 eV/atom)
# Total Cost: 0.616
#
# Mn2O3 -> MnO + MnO2 (dG = 0.097 eV/atom)
# 3 Li2CO3 + MnO -> Li6MnO4 + 3 CO2 (dG = 0.265 eV/atom)
# Total Cost: 0.621
#
# 2 Mn2O3 -> Mn + 3 MnO2 (dG = 0.329 eV/atom)
# 2 Li2CO3 + 5 MnO2 -> Li4Mn5O12 + 2 CO2 (dG = 0.043 eV/atom)
# Total Cost: 0.627
#
# 2 Mn2O3 -> Mn + 3 MnO2 (dG = 0.329 eV/atom)
# Li2CO3 + MnO2 -> Li2MnO3 + CO2 (dG = 0.072 eV/atom)
# Total Cost: 0.634
#
# 0.5 Mn2O3 -> MnO + 0.25 O2 (dG = 0.264 eV/atom)
# 3 Li2CO3 + MnO -> Li6MnO4 + 3 CO2 (dG = 0.265 eV/atom)
# Total Cost: 0.666
#
# PATHS to YMnO3
#
# ---------------------------------------
#   0%|          | 0/561 [00:00<?, ?it/s]
#   1%|          | 7/561 [00:00<00:09, 55.67it/s]
# 2 YCl3 + 9 Mn2O3 -> Y2Mn2O7 + 2 Mn8Cl3O10 (dG = -0.015 eV/atom)
# 0.5 Y2Mn2O7 + 0.5 Mn2O3 -> MnO2 + YMnO3 (dG = 0.005 eV/atom)
# Total Cost: 0.528
#
# 1.5 Li2CO3 + 0.5 Mn2O3 -> Li3MnO3 + 1.5 CO2 (dG = 0.193 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.531
#
# YCl3 + 5 Mn2O3 -> YMn2O5 + Mn8Cl3O10 (dG = -0.025 eV/atom)
# YMn2O5 -> MnO2 + YMnO3 (dG = 0.048 eV/atom)
# Total Cost: 0.535
#
# 2 YCl3 + 9 Mn2O3 -> Y2Mn2O7 + 2 Mn8Cl3O10 (dG = -0.015 eV/atom)
# 2 Y2Mn2O7 -> O2 + 4 YMnO3 (dG = 0.039 eV/atom)
# Total Cost: 0.536
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# MnCO3 + YCl3 -> YMnO3 + CCl3 (dG = 0.393 eV/atom)
# Total Cost: 0.649
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 3.429 Li2MnO3 + 3.286 Mn2O3 -> Li3MnO3 + 0.4286 Li9Mn21O40 (dG = 0.029 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.764
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 3 Li2MnO3 + 2 Mn2O3 -> Li3MnO3 + 3 LiMn2O4 (dG = 0.035 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.765
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 3.6 Li2MnO3 + 3.8 Mn2O3 -> Li3MnO3 + 0.6 Li7Mn17O32 (dG = 0.039 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.766
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# 3.429 Li2MnO3 + 3.286 Mn2O3 -> Li3MnO3 + 0.4286 Li9Mn21O40 (dG = 0.029 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.767
#
# YCl3 + 5 Mn2O3 -> YMn2O5 + Mn8Cl3O10 (dG = -0.025 eV/atom)
# 0.625 Mn2O3 + 0.025 YMn2O5 -> MnO2 + 0.025 YMn12 (dG = 0.363 eV/atom)
# 0.56 MnO2 + 0.04 YMn12 -> MnO + 0.04 YMnO3 (dG = -0.652 eV/atom)
# Total Cost: 0.768
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# 3 Li2MnO3 + 2 Mn2O3 -> Li3MnO3 + 3 LiMn2O4 (dG = 0.035 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.768
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 10 Li2MnO3 + 4.333 Mn2O3 -> Li9Mn15O32 + 3.667 Li3MnO3 (dG = 0.049 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.769
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 11 Li2MnO3 + 6.667 Mn2O3 -> Li9Mn20O40 + 4.333 Li3MnO3 (dG = 0.05 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.769
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# 3.6 Li2MnO3 + 3.8 Mn2O3 -> Li3MnO3 + 0.6 Li7Mn17O32 (dG = 0.039 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.769
#
# 2 YCl3 + 9 Mn2O3 -> Y2Mn2O7 + 2 Mn8Cl3O10 (dG = -0.015 eV/atom)
# 0.0125 Y2Mn2O7 + 0.6375 Mn2O3 -> MnO2 + 0.025 YMn12 (dG = 0.361 eV/atom)
# 0.56 MnO2 + 0.04 YMn12 -> MnO + 0.04 YMnO3 (dG = -0.652 eV/atom)
# Total Cost: 0.769
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 2.571 Li2MnO3 + 0.7143 Mn2O3 -> Li3MnO3 + 0.4286 Li5Mn7O16 (dG = 0.053 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.77
#
# Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2 (dG = 0.086 eV/atom)
# 0.9091 Mn2O3 + 0.2727 LiMnO2 -> 0.09091 Li3MnO3 + Mn2O3 (dG = 0.013 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.771
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 2.455 Li2MnO3 + 1.455 Mn2O3 -> Li3MnO3 + 0.2727 Li7Mn16O32 (dG = 0.06 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.771
#
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# 10 Li2MnO3 + 4.333 Mn2O3 -> Li9Mn15O32 + 3.667 Li3MnO3 (dG = 0.049 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.771
#
# 2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2 (dG = 0.042 eV/atom)
# 2.625 Li2MnO3 + 0.875 Mn2O3 -> Li3MnO3 + 0.375 Li6Mn9O20 (dG = 0.06 eV/atom)
# YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Total Cost: 0.771
#
# Finding crossover reactions paths...
#   2%|▏         | 13/561 [00:00<00:09, 54.98it/s]
#   3%|▎         | 19/561 [00:00<00:10, 49.32it/s]
#   4%|▍         | 25/561 [00:00<00:10, 48.90it/s]
#   5%|▌         | 30/561 [00:00<00:11, 48.12it/s]
#   6%|▌         | 35/561 [00:00<00:11, 47.75it/s]
#   7%|▋         | 40/561 [00:00<00:16, 32.05it/s]
#   8%|▊         | 44/561 [00:01<00:19, 27.00it/s]
#   9%|▊         | 49/561 [00:01<00:18, 28.07it/s]
#   9%|▉         | 53/561 [00:01<00:20, 24.81it/s]
#  10%|▉         | 56/561 [00:01<00:19, 25.56it/s]
#  11%|█         | 59/561 [00:01<00:21, 23.85it/s]
#  11%|█         | 62/561 [00:01<00:20, 23.80it/s]
#  12%|█▏        | 65/561 [00:02<00:23, 21.31it/s]
#  12%|█▏        | 69/561 [00:02<00:20, 24.20it/s]
#  13%|█▎        | 72/561 [00:02<00:19, 24.51it/s]
#  13%|█▎        | 75/561 [00:02<00:19, 25.48it/s]
#  14%|█▍        | 78/561 [00:02<00:20, 23.23it/s]
#  15%|█▍        | 82/561 [00:02<00:17, 26.64it/s]
#  15%|█▌        | 85/561 [00:02<00:18, 25.63it/s]
#  16%|█▌        | 88/561 [00:02<00:17, 26.64it/s]
#  16%|█▌        | 91/561 [00:03<00:17, 26.98it/s]
#  17%|█▋        | 94/561 [00:03<00:18, 25.12it/s]
#  17%|█▋        | 97/561 [00:03<00:18, 24.90it/s]
#  23%|██▎       | 128/561 [00:03<00:04, 90.38it/s]
#  24%|██▍       | 137/561 [00:03<00:08, 48.27it/s]
#  26%|██▌       | 144/561 [00:04<00:10, 40.09it/s]
#  27%|██▋       | 150/561 [00:04<00:11, 35.61it/s]
#  28%|██▊       | 155/561 [00:04<00:12, 31.47it/s]
#  28%|██▊       | 159/561 [00:04<00:14, 28.31it/s]
#  29%|██▉       | 163/561 [00:05<00:14, 26.93it/s]
#  30%|██▉       | 167/561 [00:05<00:15, 25.40it/s]
#  30%|███       | 170/561 [00:05<00:17, 22.19it/s]
#  31%|███       | 173/561 [00:05<00:19, 19.78it/s]
#  31%|███▏      | 176/561 [00:05<00:19, 19.44it/s]
#  32%|███▏      | 179/561 [00:06<00:23, 16.46it/s]
#  33%|███▎      | 183/561 [00:06<00:20, 18.32it/s]
#  33%|███▎      | 185/561 [00:06<00:20, 18.08it/s]
#  33%|███▎      | 187/561 [00:06<00:20, 18.36it/s]
#  34%|███▍      | 190/561 [00:06<00:19, 19.14it/s]
#  35%|███▍      | 194/561 [00:06<00:16, 22.13it/s]
#  35%|███▌      | 197/561 [00:06<00:16, 22.52it/s]
#  36%|███▌      | 200/561 [00:07<00:16, 21.77it/s]
#  36%|███▌      | 203/561 [00:07<00:15, 22.97it/s]
#  37%|███▋      | 206/561 [00:07<00:16, 21.73it/s]
#  37%|███▋      | 209/561 [00:07<00:14, 23.49it/s]
#  38%|███▊      | 212/561 [00:07<00:14, 23.33it/s]
#  38%|███▊      | 215/561 [00:07<00:15, 22.86it/s]
#  39%|███▉      | 218/561 [00:07<00:15, 21.76it/s]
#  39%|███▉      | 221/561 [00:07<00:15, 22.58it/s]
#  40%|███▉      | 224/561 [00:08<00:13, 24.22it/s]
#  40%|████      | 227/561 [00:08<00:14, 22.69it/s]
#  41%|████      | 230/561 [00:08<00:13, 24.20it/s]
#  42%|████▏     | 234/561 [00:08<00:12, 25.84it/s]
#  42%|████▏     | 237/561 [00:08<00:13, 24.65it/s]
#  43%|████▎     | 241/561 [00:08<00:11, 27.67it/s]
#  43%|████▎     | 244/561 [00:08<00:12, 24.91it/s]
#  44%|████▍     | 247/561 [00:08<00:12, 25.23it/s]
#  45%|████▍     | 250/561 [00:09<00:12, 25.40it/s]
#  45%|████▌     | 254/561 [00:09<00:11, 26.08it/s]
#  46%|████▌     | 257/561 [00:09<00:11, 26.73it/s]
#  47%|████▋     | 261/561 [00:09<00:10, 28.04it/s]
#  47%|████▋     | 264/561 [00:09<00:11, 26.37it/s]
#  48%|████▊     | 267/561 [00:09<00:12, 24.45it/s]
#  48%|████▊     | 270/561 [00:09<00:11, 24.91it/s]
#  49%|████▊     | 273/561 [00:09<00:11, 25.99it/s]
#  49%|████▉     | 276/561 [00:10<00:11, 24.78it/s]
#  50%|████▉     | 279/561 [00:10<00:10, 25.86it/s]
#  50%|█████     | 282/561 [00:10<00:10, 26.94it/s]
#  51%|█████     | 285/561 [00:10<00:12, 22.61it/s]
#  51%|█████▏    | 288/561 [00:10<00:14, 19.36it/s]
#  52%|█████▏    | 291/561 [00:10<00:15, 17.38it/s]
#  52%|█████▏    | 294/561 [00:11<00:14, 18.86it/s]
#  53%|█████▎    | 297/561 [00:11<00:17, 15.48it/s]
#  53%|█████▎    | 300/561 [00:11<00:16, 16.13it/s]
#  54%|█████▍    | 302/561 [00:11<00:17, 14.79it/s]
#  54%|█████▍    | 304/561 [00:11<00:17, 14.45it/s]
#  55%|█████▍    | 307/561 [00:11<00:14, 17.07it/s]
#  55%|█████▌    | 309/561 [00:11<00:14, 17.63it/s]
#  56%|█████▌    | 314/561 [00:12<00:09, 25.18it/s]
#  57%|█████▋    | 318/561 [00:12<00:08, 27.83it/s]
#  57%|█████▋    | 322/561 [00:12<00:07, 30.77it/s]
#  58%|█████▊    | 326/561 [00:12<00:07, 32.30it/s]
#  59%|█████▉    | 330/561 [00:12<00:06, 34.00it/s]
#  60%|█████▉    | 334/561 [00:12<00:08, 28.33it/s]
#  60%|██████    | 338/561 [00:12<00:08, 26.66it/s]
#  61%|██████    | 341/561 [00:13<00:08, 25.19it/s]
#  61%|██████▏   | 345/561 [00:13<00:08, 26.54it/s]
#  62%|██████▏   | 349/561 [00:13<00:07, 27.87it/s]
#  63%|██████▎   | 352/561 [00:13<00:07, 26.88it/s]
#  63%|██████▎   | 355/561 [00:13<00:08, 23.69it/s]
#  64%|██████▍   | 358/561 [00:13<00:10, 19.61it/s]
#  64%|██████▍   | 361/561 [00:13<00:10, 18.70it/s]
#  65%|██████▍   | 364/561 [00:14<00:10, 19.23it/s]
#  65%|██████▌   | 367/561 [00:14<00:12, 15.83it/s]
#  66%|██████▌   | 371/561 [00:14<00:10, 18.46it/s]
#  67%|██████▋   | 375/561 [00:14<00:08, 22.25it/s]
#  68%|██████▊   | 379/561 [00:14<00:07, 24.75it/s]
#  68%|██████▊   | 384/561 [00:14<00:06, 29.18it/s]
#  69%|██████▉   | 388/561 [00:15<00:05, 31.45it/s]
#  70%|██████▉   | 392/561 [00:15<00:05, 29.75it/s]
#  71%|███████   | 396/561 [00:15<00:06, 25.82it/s]
#  71%|███████   | 399/561 [00:15<00:06, 24.90it/s]
#  72%|███████▏  | 402/561 [00:15<00:06, 24.17it/s]
#  72%|███████▏  | 405/561 [00:15<00:06, 24.77it/s]
#  73%|███████▎  | 408/561 [00:15<00:07, 20.83it/s]
#  73%|███████▎  | 411/561 [00:16<00:07, 19.80it/s]
#  74%|███████▍  | 414/561 [00:16<00:06, 21.65it/s]
#  75%|███████▍  | 419/561 [00:16<00:05, 26.57it/s]
#  75%|███████▌  | 423/561 [00:16<00:05, 26.79it/s]
#  76%|███████▌  | 427/561 [00:16<00:04, 28.66it/s]
#  77%|███████▋  | 430/561 [00:16<00:05, 25.71it/s]
#  77%|███████▋  | 433/561 [00:16<00:05, 24.73it/s]
#  78%|███████▊  | 436/561 [00:17<00:05, 22.96it/s]
#  78%|███████▊  | 439/561 [00:17<00:05, 24.11it/s]
#  79%|███████▉  | 442/561 [00:17<00:05, 21.21it/s]
#  79%|███████▉  | 445/561 [00:17<00:05, 21.50it/s]
#  80%|███████▉  | 448/561 [00:17<00:05, 22.15it/s]
#  80%|████████  | 451/561 [00:17<00:04, 23.41it/s]
#  81%|████████  | 454/561 [00:17<00:04, 24.80it/s]
#  81%|████████▏ | 457/561 [00:18<00:04, 21.00it/s]
#  82%|████████▏ | 460/561 [00:18<00:05, 19.76it/s]
#  83%|████████▎ | 463/561 [00:18<00:05, 18.24it/s]
#  83%|████████▎ | 466/561 [00:18<00:04, 19.63it/s]
#  84%|████████▎ | 469/561 [00:18<00:04, 18.77it/s]
#  84%|████████▍ | 472/561 [00:18<00:04, 20.77it/s]
#  85%|████████▌ | 477/561 [00:18<00:03, 26.47it/s]
#  86%|████████▌ | 481/561 [00:19<00:02, 29.57it/s]
#  86%|████████▋ | 485/561 [00:19<00:02, 27.58it/s]
#  87%|████████▋ | 489/561 [00:19<00:02, 28.73it/s]
#  88%|████████▊ | 493/561 [00:19<00:02, 29.59it/s]
#  89%|████████▊ | 497/561 [00:19<00:02, 24.23it/s]
#  89%|████████▉ | 500/561 [00:19<00:02, 21.88it/s]
#  90%|████████▉ | 503/561 [00:19<00:02, 21.94it/s]
#  90%|█████████ | 506/561 [00:20<00:02, 18.79it/s]
#  91%|█████████ | 509/561 [00:20<00:02, 20.11it/s]
#  91%|█████████▏| 512/561 [00:20<00:02, 18.76it/s]
#  92%|█████████▏| 516/561 [00:20<00:02, 21.88it/s]
#  93%|█████████▎| 520/561 [00:20<00:01, 25.46it/s]
#  93%|█████████▎| 524/561 [00:20<00:01, 28.17it/s]
#  94%|█████████▍| 528/561 [00:21<00:01, 28.01it/s]
#  95%|█████████▍| 531/561 [00:21<00:01, 28.47it/s]
#  95%|█████████▌| 534/561 [00:21<00:01, 25.79it/s]
#  96%|█████████▌| 538/561 [00:21<00:00, 24.92it/s]
#  96%|█████████▋| 541/561 [00:21<00:00, 23.84it/s]
#  97%|█████████▋| 544/561 [00:21<00:00, 24.99it/s]
#  98%|█████████▊| 547/561 [00:21<00:00, 23.52it/s]
#  98%|█████████▊| 550/561 [00:21<00:00, 22.78it/s]
#  99%|█████████▉| 554/561 [00:22<00:00, 23.39it/s]
#  99%|█████████▉| 558/561 [00:22<00:00, 25.96it/s]
# 100%|██████████| 561/561 [00:22<00:00, 25.05it/s]
# INFO:ReactionNetwork:Considering 89 reactions...
#
# 0it [00:00, ?it/s]
# [1.5 Li2CO3 + 0.5 Mn2O3 -> Li3MnO3 + 1.5 CO2,
#  YCl3 + Li3MnO3 -> YMnO3 + 3 LiCl,
#  Li2CO3 -> Li2O + CO2,
#  2 YCl3 + 3 Li2O -> Y2O3 + 6 LiCl,
#  YCl3 + Li2O -> YClO + 2 LiCl,
#  YCl3 + 2 Li2O -> LiYO2 + 3 LiCl,
#  2 Li2CO3 + Mn2O3 -> Li2MnO3 + Li2Mn(CO3)2,
#  2.286 Li2MnO3 + 1.857 Mn2O3 -> Li2O + 0.2857 Li9Mn21O40,
#  2.4 Li2MnO3 + 2.2 Mn2O3 -> Li2O + 0.4 Li7Mn17O32,
#  Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3,
#  2 Li2MnO3 + Mn2O3 -> Li2O + 2 LiMn2O4,
#  Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2,
#  10 Li2MnO3 + 2.5 Mn2O3 -> Li9Mn15O32 + 5.5 Li2O,
#  11 Li2MnO3 + 4.5 Mn2O3 -> Li9Mn20O40 + 6.5 Li2O,
#  2 Mn2O3 -> MnO2 + Mn3O4,
#  2 Li2CO3 + 5 MnO2 -> Li4Mn5O12 + 2 CO2,
#  MnCO3 + Mn2O3 -> CO2 + Mn3O4,
#  1.5 MnCO3 + 3.5 Li2MnO3 -> Li7Mn5O12 + 1.5 CO2,
#  MnCO3 + Li2MnO3 -> CO2 + 2 LiMnO2,
#  Li2CO3 + MnO2 -> Li2MnO3 + CO2,
#  Mn2O3 -> MnO + MnO2,
#  MnCO3 -> MnO + CO2,
#  2 Li2CO3 + Li2Mn(CO3)2 -> Li6MnO4 + 4 CO2,
#  MnCO3 + 3 Li2CO3 -> Li6MnO4 + 4 CO2,
#  3 Li2CO3 + MnO -> Li6MnO4 + 3 CO2,
#  2 Mn2O3 -> Mn + 3 MnO2,
#  0.5 Mn2O3 -> MnO + 0.25 O2,
#  2 YCl3 + 9 Mn2O3 -> Y2Mn2O7 + 2 Mn8Cl3O10,
#  0.5 Y2Mn2O7 + 0.5 Mn2O3 -> MnO2 + YMnO3,
#  YCl3 + 5 Mn2O3 -> YMn2O5 + Mn8Cl3O10,
#  YMn2O5 -> MnO2 + YMnO3,
#  2 Y2Mn2O7 -> O2 + 4 YMnO3,
#  MnCO3 + YCl3 -> YMnO3 + CCl3,
#  3.429 Li2MnO3 + 3.286 Mn2O3 -> Li3MnO3 + 0.4286 Li9Mn21O40,
#  3 Li2MnO3 + 2 Mn2O3 -> Li3MnO3 + 3 LiMn2O4,
#  3.6 Li2MnO3 + 3.8 Mn2O3 -> Li3MnO3 + 0.6 Li7Mn17O32,
#  0.625 Mn2O3 + 0.025 YMn2O5 -> MnO2 + 0.025 YMn12,
#  0.56 MnO2 + 0.04 YMn12 -> MnO + 0.04 YMnO3,
#  10 Li2MnO3 + 4.333 Mn2O3 -> Li9Mn15O32 + 3.667 Li3MnO3,
#  11 Li2MnO3 + 6.667 Mn2O3 -> Li9Mn20O40 + 4.333 Li3MnO3,
#  0.0125 Y2Mn2O7 + 0.6375 Mn2O3 -> MnO2 + 0.025 YMn12,
#  2.571 Li2MnO3 + 0.7143 Mn2O3 -> Li3MnO3 + 0.4286 Li5Mn7O16,
#  2.455 Li2MnO3 + 1.455 Mn2O3 -> Li3MnO3 + 0.2727 Li7Mn16O32,
#  2.625 Li2MnO3 + 0.875 Mn2O3 -> Li3MnO3 + 0.375 Li6Mn9O20,
#  0.1667 Li6MnO4 + 0.3333 CCl3 + 0.1667 O2 -> LiCl + 0.1667 MnO2 + 0.3333 CO2,
#  0.5 Li2O + 0.3333 CCl3 + 0.08333 O2 -> LiCl + 0.3333 CO2,
#  0.03704 Mn8Cl3O10 + 0.7037 Li3MnO3 + 0.2593 O2 -> Li2MnO3 + 0.1111 LiCl,
#  0.1818 Mn8Cl3O10 + 5.545 LiMnO2 + 1.545 O2 -> Li5Mn7O16 + 0.5455 LiCl,
#  0.07843 Mn8Cl3O10 + 0.3725 Li6MnO4 + 0.3627 O2 -> Li2MnO3 + 0.2353 LiCl,
#  0.3333 Mn8Cl3O10 + 0.1111 Li9Mn15O32 + 0.8889 O2 -> LiCl + 4.333 MnO2,
#  0.3333 Mn8Cl3O10 + 0.5 Li2Mn(CO3)2 + O2 -> LiCl + 3.167 MnO2 + CO2,
#  YClO + 0.1429 Li7Mn16O32 -> YMn2O5 + LiCl + 0.2857 MnO2,
#  YClO + LiMn2O4 -> YMn2O5 + LiCl,
#  CCl3 + O2 -> CO2 + 1.5 Cl2,
#  MnCO3 + 0.5 O2 -> CO2 + MnO2,
#  0.5 Y2O3 + 2 MnCO3 + 0.75 O2 -> YMn2O5 + 2 CO2,
#  0.3333 Mn8Cl3O10 + 0.5 Li2MnO3 + 0.75 O2 -> LiCl + 3.167 MnO2,
#  LiYO2 + 0.2632 Mn8Cl3O10 + 0.3421 O2 -> YMn2O5 + 0.7895 LiCl + 0.1053 Li2MnO3,
#  0.3333 YCl3 + 0.1667 Li6MnO4 + 0.08333 O2 -> LiCl + 0.08333 Y2Mn2O7 + 0.08333 Y2O3,
#  0.3333 Mn8Cl3O10 + 0.1429 Li7Mn17O32 + 1.143 O2 -> LiCl + 5.095 MnO2,
#  0.3333 YCl3 + 0.3333 Li3MnO3 + 0.08333 O2 -> LiCl + 0.1667 Y2Mn2O7,
#  2 YCl3 + 11 LiMnO2 + 2 O2 -> Li5Mn7O16 + 2 YMn2O5 + 6 LiCl,
#  0.3333 Mn8Cl3O10 + 0.1111 Li9Mn20O40 + O2 -> LiCl + 4.889 MnO2,
#  0.3333 Mn8Cl3O10 + 0.1429 Li7Mn5O12 + 0.8571 O2 -> LiCl + 3.381 MnO2,
#  0.3333 Mn8Cl3O10 + 0.1667 Li6Mn9O20 + 0.8333 O2 -> LiCl + 4.167 MnO2,
#  0.3333 Mn8Cl3O10 + 0.2 Li5Mn7O16 + 0.8 O2 -> LiCl + 4.067 MnO2,
#  0.125 Mn8Cl3O10 + 1.187 Li2O + 0.2813 O2 -> Li2MnO3 + 0.375 LiCl,
#  0.3333 Mn8Cl3O10 + 0.25 Li4Mn5O12 + 0.75 O2 -> LiCl + 3.917 MnO2,
#  YClO + 0.1111 Li9Mn21O40 + 0.1111 O2 -> YMn2O5 + LiCl + 0.3333 MnO2,
#  0.6667 CCl3 + 0.6667 O2 -> Cl2 + 0.6667 CO2,
#  YClO + Li3MnO3 + 0.25 O2 -> LiCl + Li2MnO3 + 0.5 Y2O3,
#  YClO + LiMnO2 + 0.25 O2 -> LiCl + 0.5 Y2Mn2O7,
#  YClO + 0.25 Li6MnO4 + 0.125 O2 -> LiCl + 0.25 Li2MnO3 + 0.5 Y2O3,
#  0.3333 YCl3 + LiYO2 -> LiCl + 0.6667 Y2O3,
#  0.3333 Mn8Cl3O10 + 0.1111 Li9Mn21O40 + 1.111 O2 -> LiCl + 5 MnO2,
#  YClO + 0.1111 Li9Mn20O40 -> YMn2O5 + LiCl + 0.2222 MnO2,
#  YClO + 0.1429 Li7Mn5O12 + 0.1071 O2 -> LiCl + 0.3571 Y2Mn2O7 + 0.1429 Y2O3,
#  YClO + 0.5 Li2O -> LiCl + 0.5 Y2O3,
#  YClO + 0.1429 Li7Mn17O32 + 0.1429 O2 -> YMn2O5 + LiCl + 0.4286 MnO2,
#  0.3333 Mn8Cl3O10 + 0.1429 Li7Mn16O32 + O2 -> LiCl + 4.952 MnO2,
#  0.5 Li2CO3 + 0.3333 Mn8Cl3O10 + 0.75 O2 -> LiCl + 2.667 MnO2 + 0.5 CO2,
#  0.5 YCl3 + 0.5 Li2CO3 -> LiCl + 0.5 CO2 + 0.5 YClO,
#  0.3333 Mn8Cl3O10 + LiMn2O4 + O2 -> LiCl + 4.667 MnO2,
#  24 YCl3 + 11 Li7Mn5O12 + 2 O2 -> Li5Mn7O16 + 24 YMn2O5 + 72 LiCl,
#  0.3333 YCl3 + 0.5 Li2O -> LiCl + 0.1667 Y2O3,
#  YCl3 + 0.4286 Li7Mn17O32 + 0.9286 O2 -> YMn2O5 + 3 LiCl + 5.286 MnO2,
#  YClO + LiMnO2 -> LiCl + YMnO3,
#  0.3333 Li3MnO3 + 0.3333 YCl3 -> LiCl + 0.3333 YMnO3,
#  0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3]
# 1it [00:05,  5.36s/it]
#
# 1it [00:00, 15.78it/s]
#
# 0it [00:00, ?it/s]
# 1it [00:01,  1.04s/it]
# INFO:ReactionNetwork:Generating and filtering size 4 pathways...
#
#   0%|          | 0/4 [00:00<?, ?it/s]
#  25%|██▌       | 1/4 [00:05<00:17,  5.97s/it]
#  50%|█████     | 2/4 [00:12<00:12,  6.09s/it]
#  75%|███████▌  | 3/4 [00:17<00:05,  5.97s/it]
# 100%|██████████| 4/4 [00:23<00:00,  5.98s/it]
# 5it [00:29,  5.88s/it]
# INFO:ReactionNetwork:Generating and filtering size 5 pathways...
#
#   0%|          | 0/83 [00:00<?, ?it/s]
#   1%|          | 1/83 [00:07<10:45,  7.87s/it]
#   2%|▏         | 2/83 [00:15<10:08,  7.52s/it]
#   4%|▎         | 3/83 [00:22<09:45,  7.31s/it]
#   5%|▍         | 4/83 [00:30<10:03,  7.64s/it]
#   6%|▌         | 5/83 [00:39<10:44,  8.26s/it]
#   7%|▋         | 6/83 [00:49<11:12,  8.73s/it]
#   8%|▊         | 7/83 [00:58<11:23,  9.00s/it]
#  10%|▉         | 8/83 [01:07<11:06,  8.89s/it]
#  11%|█         | 9/83 [01:15<10:31,  8.53s/it]
#  12%|█▏        | 10/83 [01:23<10:10,  8.36s/it]
#  13%|█▎        | 11/83 [01:31<09:48,  8.18s/it]
#  14%|█▍        | 12/83 [01:39<09:48,  8.29s/it]
#  16%|█▌        | 13/83 [01:48<10:01,  8.59s/it]
#  17%|█▋        | 14/83 [01:58<10:14,  8.90s/it]
#  18%|█▊        | 15/83 [02:07<09:59,  8.82s/it]
#  19%|█▉        | 16/83 [02:14<09:29,  8.51s/it]
#  20%|██        | 17/83 [02:22<09:02,  8.22s/it]
#  22%|██▏       | 18/83 [02:29<08:39,  7.99s/it]
#  23%|██▎       | 19/83 [02:37<08:21,  7.83s/it]
#  24%|██▍       | 20/83 [02:44<07:57,  7.59s/it]
#  25%|██▌       | 21/83 [02:51<07:32,  7.30s/it]
#  27%|██▋       | 22/83 [02:57<07:14,  7.12s/it]
#  28%|██▊       | 23/83 [03:04<07:01,  7.02s/it]
#  29%|██▉       | 24/83 [03:11<06:49,  6.93s/it]
#  30%|███       | 25/83 [03:17<06:36,  6.84s/it]
#  31%|███▏      | 26/83 [03:24<06:27,  6.80s/it]
#  33%|███▎      | 27/83 [03:31<06:19,  6.78s/it]
#  34%|███▎      | 28/83 [03:38<06:21,  6.94s/it]
#  35%|███▍      | 29/83 [03:46<06:23,  7.11s/it]
#  36%|███▌      | 30/83 [03:53<06:28,  7.33s/it]
#  37%|███▋      | 31/83 [04:01<06:30,  7.50s/it]
#  39%|███▊      | 32/83 [04:09<06:26,  7.58s/it]
#  40%|███▉      | 33/83 [04:17<06:17,  7.56s/it]
#  41%|████      | 34/83 [04:24<06:10,  7.57s/it]
#  42%|████▏     | 35/83 [04:32<06:07,  7.67s/it]
#  43%|████▎     | 36/83 [04:40<06:08,  7.85s/it]
#  45%|████▍     | 37/83 [04:48<06:01,  7.86s/it]
#  46%|████▌     | 38/83 [04:56<05:49,  7.77s/it]
#  47%|████▋     | 39/83 [05:03<05:33,  7.58s/it]
#  48%|████▊     | 40/83 [05:10<05:18,  7.40s/it]
#  49%|████▉     | 41/83 [05:17<05:03,  7.23s/it]
#  51%|█████     | 42/83 [05:24<04:55,  7.20s/it]
#  52%|█████▏    | 43/83 [05:31<04:50,  7.27s/it]
#  53%|█████▎    | 44/83 [05:39<04:49,  7.42s/it]
#  54%|█████▍    | 45/83 [05:47<04:44,  7.48s/it]
#  55%|█████▌    | 46/83 [05:54<04:37,  7.51s/it]
#  57%|█████▋    | 47/83 [06:02<04:27,  7.44s/it]
#  58%|█████▊    | 48/83 [06:08<04:14,  7.27s/it]
#  59%|█████▉    | 49/83 [06:15<04:02,  7.13s/it]
#  60%|██████    | 50/83 [06:22<03:54,  7.10s/it]
#  61%|██████▏   | 51/83 [06:30<03:51,  7.24s/it]
#  63%|██████▎   | 52/83 [06:40<04:07,  7.99s/it]
#  64%|██████▍   | 53/83 [06:50<04:17,  8.60s/it]
#  65%|██████▌   | 54/83 [06:59<04:17,  8.88s/it]
#  66%|██████▋   | 55/83 [07:08<04:08,  8.88s/it]
#  67%|██████▋   | 56/83 [07:17<03:56,  8.77s/it]
#  69%|██████▊   | 57/83 [07:25<03:43,  8.61s/it]
#  70%|██████▉   | 58/83 [07:33<03:34,  8.58s/it]
#  71%|███████   | 59/83 [07:42<03:27,  8.66s/it]
#  72%|███████▏  | 60/83 [07:51<03:17,  8.58s/it]
#  73%|███████▎  | 61/83 [07:58<03:02,  8.31s/it]
#  75%|███████▍  | 62/83 [08:06<02:49,  8.05s/it]
#  76%|███████▌  | 63/83 [08:13<02:36,  7.80s/it]
#  77%|███████▋  | 64/83 [08:20<02:24,  7.60s/it]
#  78%|███████▊  | 65/83 [08:28<02:16,  7.58s/it]
#  80%|███████▉  | 66/83 [08:36<02:12,  7.82s/it]
#  81%|████████  | 67/83 [08:45<02:10,  8.13s/it]
#  82%|████████▏ | 68/83 [08:53<02:03,  8.24s/it]
#  83%|████████▎ | 69/83 [09:01<01:54,  8.21s/it]
#  84%|████████▍ | 70/83 [09:10<01:46,  8.18s/it]
#  86%|████████▌ | 71/83 [09:17<01:37,  8.11s/it]
#  87%|████████▋ | 72/83 [09:25<01:27,  7.98s/it]
#  88%|████████▊ | 73/83 [09:33<01:18,  7.86s/it]
#  89%|████████▉ | 74/83 [09:41<01:10,  7.86s/it]
#  90%|█████████ | 75/83 [09:48<01:02,  7.83s/it]
#  92%|█████████▏| 76/83 [09:56<00:54,  7.73s/it]
#  93%|█████████▎| 77/83 [10:03<00:45,  7.65s/it]
#  94%|█████████▍| 78/83 [10:11<00:38,  7.63s/it]
#  95%|█████████▌| 79/83 [10:18<00:29,  7.46s/it]
#  96%|█████████▋| 80/83 [10:25<00:22,  7.36s/it]
#  98%|█████████▊| 81/83 [10:32<00:14,  7.34s/it]
#  99%|█████████▉| 82/83 [10:40<00:07,  7.49s/it]
# 100%|██████████| 83/83 [10:48<00:00,  7.59s/it]
# 84it [10:48,  7.72s/it]

# %% [markdown]
# Let's check out the results. We should see several balanced pathways stored in the **paths** list object.

# %%
for num, path in enumerate(paths):
    print(f"Path {num+1}:")
    print(path)
# Out:
# Path 1:
# Li2CO3 + 0.3333 MnO -> CO2 + 0.3333 Li6MnO4 (dG = 0.265 eV/atom)
# 2 Mn2O3 -> O2 + 4 MnO (dG = 0.264 eV/atom)
# 2 Y2Mn2O7 -> O2 + 4 YMnO3 (dG = 0.039 eV/atom)
# O2 + 2 Li6MnO4 + 4 YCl3 -> Y2Mn2O7 + Y2O3 + 12 LiCl (dG = -0.314 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.236 | Average Cost: 0.047
#
#
# Path 2:
# Li2CO3 + 0.3333 Mn2O3 -> CO2 + 0.6667 Li3MnO3 (dG = 0.193 eV/atom)
# Li3MnO3 + YCl3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
#
# Total Cost: 0.241 | Average Cost: 0.121
#
#
# Path 3:
# Li2CO3 + 0.3333 Mn2O3 -> CO2 + 0.6667 Li3MnO3 (dG = 0.193 eV/atom)
# 2 Y2Mn2O7 -> O2 + 4 YMnO3 (dG = 0.039 eV/atom)
# 0.5 O2 + 2 Li3MnO3 + 2 YCl3 -> Y2Mn2O7 + 6 LiCl (dG = -0.232 eV/atom)
# Li3MnO3 + YCl3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
#
# Total Cost: 0.242 | Average Cost: 0.06
#
#
# Path 4:
# Li2CO3 + 0.3333 Mn2O3 -> CO2 + 0.6667 Li3MnO3 (dG = 0.193 eV/atom)
# 2 Y2Mn2O7 -> O2 + 4 YMnO3 (dG = 0.039 eV/atom)
# 0.5 O2 + 2 Li3MnO3 + 2 YCl3 -> Y2Mn2O7 + 6 LiCl (dG = -0.232 eV/atom)
#
# Total Cost: 0.242 | Average Cost: 0.081
#
#
# Path 5:
# Li2CO3 + 0.3333 Mn2O3 -> CO2 + 0.6667 Li3MnO3 (dG = 0.193 eV/atom)
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# Li3MnO3 + YCl3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.245 | Average Cost: 0.049
#
#
# Path 6:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.249 | Average Cost: 0.083
#
#
# Path 7:
# Li2CO3 + 0.3333 Mn2O3 -> CO2 + 0.6667 Li3MnO3 (dG = 0.193 eV/atom)
# Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2 (dG = 0.086 eV/atom)
# Li2CO3 + YCl3 -> YClO + CO2 + 2 LiCl (dG = -0.016 eV/atom)
# YClO + LiMnO2 -> YMnO3 + LiCl (dG = -0.078 eV/atom)
# Li3MnO3 + YCl3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
#
# Total Cost: 0.253 | Average Cost: 0.051
#
#
# Path 8:
# Li2CO3 + 0.3333 Mn2O3 -> CO2 + 0.6667 Li3MnO3 (dG = 0.193 eV/atom)
# Li3MnO3 + YCl3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.26 | Average Cost: 0.052
#
#
# Path 9:
# Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2 (dG = 0.086 eV/atom)
# 2 Y2Mn2O7 -> O2 + 4 YMnO3 (dG = 0.039 eV/atom)
# 0.5 O2 + 2 YClO + 2 LiMnO2 -> Y2Mn2O7 + 2 LiCl (dG = -0.102 eV/atom)
# Li2CO3 + YCl3 -> YClO + CO2 + 2 LiCl (dG = -0.016 eV/atom)
#
# Total Cost: 0.26 | Average Cost: 0.065
#
#
# Path 10:
# Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2 (dG = 0.086 eV/atom)
# 2 Y2Mn2O7 -> O2 + 4 YMnO3 (dG = 0.039 eV/atom)
# 0.5 O2 + 2 YClO + 2 LiMnO2 -> Y2Mn2O7 + 2 LiCl (dG = -0.102 eV/atom)
# Li2CO3 + YCl3 -> YClO + CO2 + 2 LiCl (dG = -0.016 eV/atom)
# YClO + LiMnO2 -> YMnO3 + LiCl (dG = -0.078 eV/atom)
#
# Total Cost: 0.261 | Average Cost: 0.052
#
#
# Path 11:
# Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2 (dG = 0.086 eV/atom)
# Li2CO3 + YCl3 -> YClO + CO2 + 2 LiCl (dG = -0.016 eV/atom)
# YClO + LiMnO2 -> YMnO3 + LiCl (dG = -0.078 eV/atom)
#
# Total Cost: 0.261 | Average Cost: 0.087
#
#
# Path 12:
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# MnCO3 + Li2MnO3 -> CO2 + 2 LiMnO2 (dG = 0.033 eV/atom)
# 2 Y2Mn2O7 -> O2 + 4 YMnO3 (dG = 0.039 eV/atom)
# 0.5 O2 + 2 YClO + 2 LiMnO2 -> Y2Mn2O7 + 2 LiCl (dG = -0.102 eV/atom)
# Li2CO3 + YCl3 -> YClO + CO2 + 2 LiCl (dG = -0.016 eV/atom)
#
# Total Cost: 0.261 | Average Cost: 0.052
#
#
# Path 13:
# Li2CO3 + 0.3333 Mn2O3 -> CO2 + 0.6667 Li3MnO3 (dG = 0.193 eV/atom)
# Li3MnO3 + YCl3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# 2 Y2Mn2O7 -> O2 + 4 YMnO3 (dG = 0.039 eV/atom)
# 0.5 O2 + 2 Li3MnO3 + 2 YCl3 -> Y2Mn2O7 + 6 LiCl (dG = -0.232 eV/atom)
#
# Total Cost: 0.261 | Average Cost: 0.065
#
#
# Path 14:
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2 (dG = 0.086 eV/atom)
# MnCO3 + Li2MnO3 -> CO2 + 2 LiMnO2 (dG = 0.033 eV/atom)
# Li2CO3 + YCl3 -> YClO + CO2 + 2 LiCl (dG = -0.016 eV/atom)
# YClO + LiMnO2 -> YMnO3 + LiCl (dG = -0.078 eV/atom)
#
# Total Cost: 0.261 | Average Cost: 0.052
#
#
# Path 15:
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# MnCO3 + Li2MnO3 -> CO2 + 2 LiMnO2 (dG = 0.033 eV/atom)
# Li2CO3 + YCl3 -> YClO + CO2 + 2 LiCl (dG = -0.016 eV/atom)
# YClO + LiMnO2 -> YMnO3 + LiCl (dG = -0.078 eV/atom)
#
# Total Cost: 0.261 | Average Cost: 0.065
#
#
# Path 16:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 2 YClO + Li2O -> Y2O3 + 2 LiCl (dG = -0.146 eV/atom)
# Li2CO3 + YCl3 -> YClO + CO2 + 2 LiCl (dG = -0.016 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.262 | Average Cost: 0.065
#
#
# Path 17:
# Li2CO3 + 0.3333 Mn2O3 -> CO2 + 0.6667 Li3MnO3 (dG = 0.193 eV/atom)
# Li3MnO3 + YCl3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# 2 Y2Mn2O7 -> O2 + 4 YMnO3 (dG = 0.039 eV/atom)
# 0.5 O2 + 2 Li3MnO3 + 2 YCl3 -> Y2Mn2O7 + 6 LiCl (dG = -0.232 eV/atom)
#
# Total Cost: 0.263 | Average Cost: 0.066
#
#
# Path 18:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# Li2O + YCl3 -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# 2 YClO + Li2O -> Y2O3 + 2 LiCl (dG = -0.146 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.264 | Average Cost: 0.053
#
#
# Path 19:
# Li2CO3 + 0.3333 Mn2O3 -> CO2 + 0.6667 Li3MnO3 (dG = 0.193 eV/atom)
# Li3MnO3 + YCl3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
#
# Total Cost: 0.265 | Average Cost: 0.133
#
#
# Path 20:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# Li2O + YCl3 -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2 (dG = 0.086 eV/atom)
# 2 Y2Mn2O7 -> O2 + 4 YMnO3 (dG = 0.039 eV/atom)
# 0.5 O2 + 2 YClO + 2 LiMnO2 -> Y2Mn2O7 + 2 LiCl (dG = -0.102 eV/atom)
#
# Total Cost: 0.268 | Average Cost: 0.054
#
#
# Path 21:
# Li2CO3 + 0.3333 Mn2O3 -> CO2 + 0.6667 Li3MnO3 (dG = 0.193 eV/atom)
# Li3MnO3 + YCl3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
#
# Total Cost: 0.268 | Average Cost: 0.134
#
#
# Path 22:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# Li2O + YCl3 -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# 2 YClO + Li2O -> Y2O3 + 2 LiCl (dG = -0.146 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.268 | Average Cost: 0.067
#
#
# Path 23:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# Li2O + YCl3 -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# MnCO3 + Li2MnO3 -> CO2 + 2 LiMnO2 (dG = 0.033 eV/atom)
# YClO + LiMnO2 -> YMnO3 + LiCl (dG = -0.078 eV/atom)
#
# Total Cost: 0.268 | Average Cost: 0.054
#
#
# Path 24:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# Li2O + YCl3 -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2 (dG = 0.086 eV/atom)
# YClO + LiMnO2 -> YMnO3 + LiCl (dG = -0.078 eV/atom)
#
# Total Cost: 0.269 | Average Cost: 0.067
#
#
# Path 25:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 2 Li2O + YCl3 -> LiYO2 + 3 LiCl (dG = -0.271 eV/atom)
# 1.5 LiYO2 + 0.5 YCl3 -> Y2O3 + 1.5 LiCl (dG = -0.157 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.27 | Average Cost: 0.054
#
#
# Path 26:
# Li2CO3 + 0.3333 Mn2O3 -> CO2 + 0.6667 Li3MnO3 (dG = 0.193 eV/atom)
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# Li3MnO3 + YCl3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.274 | Average Cost: 0.055
#
#
# Path 27:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 2 Li2O + YCl3 -> LiYO2 + 3 LiCl (dG = -0.271 eV/atom)
# 1.5 LiYO2 + 0.5 YCl3 -> Y2O3 + 1.5 LiCl (dG = -0.157 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.274 | Average Cost: 0.069
#
#
# Path 28:
# Li2CO3 + 0.3333 Mn2O3 -> CO2 + 0.6667 Li3MnO3 (dG = 0.193 eV/atom)
# Li3MnO3 + YCl3 -> YMnO3 + 3 LiCl (dG = -0.223 eV/atom)
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.276 | Average Cost: 0.055
#
#
# Path 29:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# 2 YClO + Li2O -> Y2O3 + 2 LiCl (dG = -0.146 eV/atom)
# Li2CO3 + YCl3 -> YClO + CO2 + 2 LiCl (dG = -0.016 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.279 | Average Cost: 0.056
#
#
# Path 30:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# 2 Li2O + YCl3 -> LiYO2 + 3 LiCl (dG = -0.271 eV/atom)
# 1.5 LiYO2 + 0.5 YCl3 -> Y2O3 + 1.5 LiCl (dG = -0.157 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.286 | Average Cost: 0.057
#
#
# Path 31:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# Li2O + YCl3 -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# 2 YClO + Li2O -> Y2O3 + 2 LiCl (dG = -0.146 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.286 | Average Cost: 0.057
#
#
# Path 32:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.289 | Average Cost: 0.096
#
#
# Path 33:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.308 | Average Cost: 0.103

# %% [markdown]
# In case this didn't work (or was taking too long), feel free to load the pre-computed path results from the paper, which also used a larger energy cutoff):

# %%
# with open("results/ymno3_paths.json") as f:
#     paths = json.load(f, cls=MontyDecoder)

# %% [markdown]
# ### Filtering/ranking the candidates

# %% [markdown]
# As discussed in the paper, several of these reaction pathways either involve interdependent steps or form hypothetical compounds that are like unsynthesizable. Hence it becomes advantageous to construct some filters to reduce the set of pathways down to the most reasonable candidates. We do that here:

# %%
cleaned_paths = set()
for idx, p in enumerate(paths):
    interdependent, consolidated_rxn = find_interdependent_rxns(p, precursors, verbose=False)
    if interdependent:
        print(f"Path {idx+1} removed")
        continue
    cleaned_paths.add(p)
# Out:
# Path 1 removed
# Path 3 removed
# Path 4 removed
# Path 9 removed
# Path 10 removed
# Path 12 removed
# Path 13 removed
# Path 17 removed
# Path 20 removed

# %%
hypothetical_phases = ["Li3MnO3","Li2MnCO5","Li2MnCO4"]
hypothetical_phases = {Composition(c) for c in hypothetical_phases}

for idx, p in enumerate(cleaned_paths.copy()):
    if set(p.all_comp) & hypothetical_phases:
        cleaned_paths.remove(p)
        
cleaned_paths = sorted(list(cleaned_paths), key=lambda x: x.total_cost)

# %% [markdown]
# The final, filtered set of candidate reaction pathways is below:

# %%
for num, path in enumerate(cleaned_paths):
    print(f"Path {num+1}:")
    print(path)
# Out:
# Path 1:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.249 | Average Cost: 0.083
#
#
# Path 2:
# Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2 (dG = 0.086 eV/atom)
# Li2CO3 + YCl3 -> YClO + CO2 + 2 LiCl (dG = -0.016 eV/atom)
# YClO + LiMnO2 -> YMnO3 + LiCl (dG = -0.078 eV/atom)
#
# Total Cost: 0.261 | Average Cost: 0.087
#
#
# Path 3:
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2 (dG = 0.086 eV/atom)
# MnCO3 + Li2MnO3 -> CO2 + 2 LiMnO2 (dG = 0.033 eV/atom)
# Li2CO3 + YCl3 -> YClO + CO2 + 2 LiCl (dG = -0.016 eV/atom)
# YClO + LiMnO2 -> YMnO3 + LiCl (dG = -0.078 eV/atom)
#
# Total Cost: 0.261 | Average Cost: 0.052
#
#
# Path 4:
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# MnCO3 + Li2MnO3 -> CO2 + 2 LiMnO2 (dG = 0.033 eV/atom)
# Li2CO3 + YCl3 -> YClO + CO2 + 2 LiCl (dG = -0.016 eV/atom)
# YClO + LiMnO2 -> YMnO3 + LiCl (dG = -0.078 eV/atom)
#
# Total Cost: 0.261 | Average Cost: 0.065
#
#
# Path 5:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 2 YClO + Li2O -> Y2O3 + 2 LiCl (dG = -0.146 eV/atom)
# Li2CO3 + YCl3 -> YClO + CO2 + 2 LiCl (dG = -0.016 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.262 | Average Cost: 0.065
#
#
# Path 6:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# Li2O + YCl3 -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# 2 YClO + Li2O -> Y2O3 + 2 LiCl (dG = -0.146 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.264 | Average Cost: 0.053
#
#
# Path 7:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# Li2O + YCl3 -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# 2 YClO + Li2O -> Y2O3 + 2 LiCl (dG = -0.146 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.268 | Average Cost: 0.067
#
#
# Path 8:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# Li2O + YCl3 -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# Li2CO3 + Mn2O3 -> MnCO3 + Li2MnO3 (dG = 0.053 eV/atom)
# MnCO3 + Li2MnO3 -> CO2 + 2 LiMnO2 (dG = 0.033 eV/atom)
# YClO + LiMnO2 -> YMnO3 + LiCl (dG = -0.078 eV/atom)
#
# Total Cost: 0.268 | Average Cost: 0.054
#
#
# Path 9:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# Li2O + YCl3 -> YClO + 2 LiCl (dG = -0.286 eV/atom)
# Li2CO3 + Mn2O3 -> CO2 + 2 LiMnO2 (dG = 0.086 eV/atom)
# YClO + LiMnO2 -> YMnO3 + LiCl (dG = -0.078 eV/atom)
#
# Total Cost: 0.269 | Average Cost: 0.067
#
#
# Path 10:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 2 Li2O + YCl3 -> LiYO2 + 3 LiCl (dG = -0.271 eV/atom)
# 1.5 LiYO2 + 0.5 YCl3 -> Y2O3 + 1.5 LiCl (dG = -0.157 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.27 | Average Cost: 0.054
#
#
# Path 11:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 2 Li2O + YCl3 -> LiYO2 + 3 LiCl (dG = -0.271 eV/atom)
# 1.5 LiYO2 + 0.5 YCl3 -> Y2O3 + 1.5 LiCl (dG = -0.157 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.274 | Average Cost: 0.069
#
#
# Path 12:
# Li2CO3 -> CO2 + Li2O (dG = 0.308 eV/atom)
# 3 Li2O + 2 YCl3 -> Y2O3 + 6 LiCl (dG = -0.313 eV/atom)
# 2 YClO + Li2O -> Y2O3 + 2 LiCl (dG = -0.146 eV/atom)
# Li2CO3 + YCl3 -> YClO + CO2 + 2 LiCl (dG = -0.016 eV/atom)
# 0.5 Y2O3 + 0.5 Mn2O3 -> YMnO3 (dG = -0.069 eV/atom)
#
# Total Cost: 0.279 | Average Cost: 0.056

# %% [markdown]
# ## Plotting the network
#
# There are many, many tools for plotting large graphs. One of the more useful approaches is to use an interactive interface such as the one provided by **Graphistry Hub**, which was also used to create the illustations in the paper.
#
# If you wish to use Graphistry Hub, you may sign up for an account and use their Python API (pygraphistry).

# %% [markdown]
# Another option is to use the built-in drawing in graph-tool, atlhough it often requires more wrangling to get insightful results. For example, this might look like the following, where we generate and then draw a filtered graph where zero-weight edges have been removed. This essentially just shows the "sub-networks" of chemical reactions broken down by smaller systems within the bigger chemical system. These sub-networks are connceted to each other via the zero-weight edges.

# %%
rn.g.ep["zero_cost"] = rn.g.new_edge_property("bool")
for s,t,weight in rn.g.iter_edges(eprops=[rn.g.ep["weight"]]):
    rn.g.ep["zero_cost"][rn.g.edge(s,t)] = (weight!=0)
    
filtered_graph = gt.GraphView(rn.g, efilt=rn.g.ep.zero_cost)

# %%
gt.graph_draw(filtered_graph);

# %% [markdown]
# There are many more insightful plots (e.g. histograms) you can make simply by using the built-in property maps of the graph-tool object. For example, you can plot the relative counts of the different sub-chemical systems represented in the graph (requires seaborn):

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(5,12))
sns.countplot(y=sorted(list(rn.g.vp["chemsys"])),orient="v");

# %% [markdown]
# # Example 2: Y$_2$Mn$_2$O$_7$ assisted metathesis
#
# Now that we have shown step-by-step how the process works for the YMnO$_3$ system, we will no longer walk through each step of the process for the other examples. Instead, see below for how to recreate the results presented in the manuscript.

# %%
chemsys = "C-Cl-Mn-Na-O-Y"

precursors = ["Mn2O3", "YCl3","Na2CO3", "O2"]
targets = ["Y2Mn2O7","CO2","NaCl"]

hypothetical_phases = ["Na3MnO3", "Mn8Cl3O10", "Na2MnO3"]

temp = 900
include_metastable = 0.03
k=20
chempots={Element("O"):0}
max_num_combos=5

# %%
with MPRester() as mpr:  # requires API key from Materials Project
    all_entries = mpr.get_entries_in_chemsys(chemsys, inc_structure="final")

# %%
rn, paths = run_reaction_network_analysis(all_entries, precursors, targets, temp, include_metastable, k,  chempots, max_num_combos)

# %% [markdown]
# This analysis -- particularly path postprocessing -- can take a considerable amount of time to complete (3-4 hours depending on your setup). Instead, you can load the pre-computed results from the paper and process them:

# %%
with open("results/y2mn2o7_paths.json") as f:
    paths = json.load(f, cls=MontyDecoder)

# %%
cleaned_paths = set()
for idx, p in enumerate(paths):
    interdependent, consolidated_rxn = find_interdependent_rxns(p, precursors, verbose=False)
    if interdependent:
        print(f"Path {idx+1} removed")
        continue
    cleaned_paths.add(p)
# Out:
# Path 4 removed
# Path 10 removed
# Path 18 removed
# Path 19 removed
# Path 20 removed
# Path 32 removed
# Path 34 removed
# Path 36 removed
# Path 37 removed

# %%
hypothetical_phases = {Composition(c) for c in hypothetical_phases}

for idx, p in enumerate(cleaned_paths.copy()):
    if set(p.all_comp) & hypothetical_phases:
        cleaned_paths.remove(p)
        
cleaned_paths = sorted(list(cleaned_paths), key=lambda x: x.total_cost)

# %%
for num, path in enumerate(cleaned_paths):
    print(f"Path {num+1}:")
    print(path)
# Out:
# Path 1:
# Mn2O3 + Na2CO3 -> CO2 + 2 NaMnO2 (dG = 0.069 eV/atom)
# 0.5 O2 + 2 YClO + 2 NaMnO2 -> Y2Mn2O7 + 2 NaCl (dG = -0.101 eV/atom)
# Na2CO3 + YCl3 -> CO2 + YClO + 2 NaCl (dG = -0.034 eV/atom)
#
# Total Cost: 0.238 | Average Cost: 0.079
#
#
# Path 2:
# 0.5 Mn2O3 + Na2CO3 -> CO2 + 0.5 Na4Mn2O5 (dG = 0.178 eV/atom)
# 1.308 Mn2O3 + 1.026 Y2O3 -> Y2Mn2O7 + 0.05128 YMn12 (dG = 0.144 eV/atom)
# 0.5 O2 + Na4Mn2O5 + 4 YClO -> Y2Mn2O7 + Y2O3 + 4 NaCl (dG = -0.143 eV/atom)
# 2.125 O2 + 0.1667 YMn12 + 0.9167 Y2O3 -> Y2Mn2O7 (dG = -0.926 eV/atom)
# Na2CO3 + YCl3 -> CO2 + YClO + 2 NaCl (dG = -0.034 eV/atom)
#
# Total Cost: 0.246 | Average Cost: 0.049
#
#
# Path 3:
# 0.5 Mn2O3 + Na2CO3 -> CO2 + 0.5 Na4Mn2O5 (dG = 0.178 eV/atom)
# 0.25 O2 + 0.5 Mn2O3 -> MnO2 (dG = -0.058 eV/atom)
# 0.5 O2 + Na4Mn2O5 + 4 YClO -> Y2Mn2O7 + Y2O3 + 4 NaCl (dG = -0.143 eV/atom)
# Na2CO3 + YCl3 -> CO2 + YClO + 2 NaCl (dG = -0.034 eV/atom)
# 2 MnO2 + Y2O3 -> Y2Mn2O7 (dG = -0.07 eV/atom)
#
# Total Cost: 0.246 | Average Cost: 0.049
#
#
# Path 4:
# Mn2O3 + Na2CO3 -> CO2 + 2 NaMnO2 (dG = 0.069 eV/atom)
# 4 Na2CO3 + YCl3 -> Na5Y(CO3)4 + 3 NaCl (dG = -0.072 eV/atom)
# 0.25 Na5Y(CO3)4 + 0.75 YCl3 -> CO2 + YClO + 1.25 NaCl (dG = 0.02 eV/atom)
# 0.5 O2 + 2 YClO + 2 NaMnO2 -> Y2Mn2O7 + 2 NaCl (dG = -0.101 eV/atom)
#
# Total Cost: 0.248 | Average Cost: 0.062
#
#
# Path 5:
# Mn2O3 + Na2CO3 -> CO2 + 2 NaMnO2 (dG = 0.069 eV/atom)
# 3 Na2CO3 + YCl3 -> Na3Y(CO3)3 + 3 NaCl (dG = -0.074 eV/atom)
# 0.3333 Na3Y(CO3)3 + 0.6667 YCl3 -> CO2 + YClO + NaCl (dG = 0.026 eV/atom)
# 0.5 O2 + 2 YClO + 2 NaMnO2 -> Y2Mn2O7 + 2 NaCl (dG = -0.101 eV/atom)
#
# Total Cost: 0.249 | Average Cost: 0.062
#
#
# Path 6:
# Na2CO3 -> CO2 + Na2O (dG = 0.454 eV/atom)
# 0.25 O2 + 0.5 Mn2O3 -> MnO2 (dG = -0.058 eV/atom)
# 2 YClO + Na2O -> Y2O3 + 2 NaCl (dG = -0.264 eV/atom)
# Na2CO3 + YCl3 -> CO2 + YClO + 2 NaCl (dG = -0.034 eV/atom)
# 2 MnO2 + Y2O3 -> Y2Mn2O7 (dG = -0.07 eV/atom)
#
# Total Cost: 0.25 | Average Cost: 0.05
#
#
# Path 7:
# Na2CO3 -> CO2 + Na2O (dG = 0.454 eV/atom)
# 1.308 Mn2O3 + 1.026 Y2O3 -> Y2Mn2O7 + 0.05128 YMn12 (dG = 0.144 eV/atom)
# 2 YClO + Na2O -> Y2O3 + 2 NaCl (dG = -0.264 eV/atom)
# 2.125 O2 + 0.1667 YMn12 + 0.9167 Y2O3 -> Y2Mn2O7 (dG = -0.926 eV/atom)
# Na2CO3 + YCl3 -> CO2 + YClO + 2 NaCl (dG = -0.034 eV/atom)
#
# Total Cost: 0.251 | Average Cost: 0.05
#
#
# Path 8:
# 0.2 Mn2O3 + Na2CO3 -> CO2 + 0.4 Na5MnO4 (dG = 0.304 eV/atom)
# 0.25 O2 + 0.5 Mn2O3 -> MnO2 (dG = -0.058 eV/atom)
# 0.5 O2 + 2 Na5MnO4 + 10 YClO -> Y2Mn2O7 + 4 Y2O3 + 10 NaCl (dG = -0.196 eV/atom)
# Na2CO3 + YCl3 -> CO2 + YClO + 2 NaCl (dG = -0.034 eV/atom)
# 2 MnO2 + Y2O3 -> Y2Mn2O7 (dG = -0.07 eV/atom)
#
# Total Cost: 0.254 | Average Cost: 0.051
#
#
# Path 9:
# Mn2O3 + Na2CO3 -> CO2 + 2 NaMnO2 (dG = 0.069 eV/atom)
# Na2CO3 -> CO2 + Na2O (dG = 0.454 eV/atom)
# Na2O + YCl3 -> YClO + 2 NaCl (dG = -0.438 eV/atom)
# 0.5 O2 + 2 YClO + 2 NaMnO2 -> Y2Mn2O7 + 2 NaCl (dG = -0.101 eV/atom)
#
# Total Cost: 0.255 | Average Cost: 0.064
#
#
# Path 10:
# 0.2 Mn2O3 + Na2CO3 -> CO2 + 0.4 Na5MnO4 (dG = 0.304 eV/atom)
# 1.308 Mn2O3 + 1.026 Y2O3 -> Y2Mn2O7 + 0.05128 YMn12 (dG = 0.144 eV/atom)
# 0.5 O2 + 2 Na5MnO4 + 10 YClO -> Y2Mn2O7 + 4 Y2O3 + 10 NaCl (dG = -0.196 eV/atom)
# 2.125 O2 + 0.1667 YMn12 + 0.9167 Y2O3 -> Y2Mn2O7 (dG = -0.926 eV/atom)
# Na2CO3 + YCl3 -> CO2 + YClO + 2 NaCl (dG = -0.034 eV/atom)
#
# Total Cost: 0.256 | Average Cost: 0.051
#
#
# Path 11:
# Na2CO3 -> CO2 + Na2O (dG = 0.454 eV/atom)
# 0.25 O2 + 0.5 Mn2O3 -> MnO2 (dG = -0.058 eV/atom)
# Na2O + YCl3 -> YClO + 2 NaCl (dG = -0.438 eV/atom)
# 2 YClO + Na2O -> Y2O3 + 2 NaCl (dG = -0.264 eV/atom)
# 2 MnO2 + Y2O3 -> Y2Mn2O7 (dG = -0.07 eV/atom)
#
# Total Cost: 0.259 | Average Cost: 0.052
#
#
# Path 12:
# 0.5 Mn2O3 + Na2CO3 -> CO2 + 0.5 Na4Mn2O5 (dG = 0.178 eV/atom)
# 0.5 O2 + Na4Mn2O5 + 4 YClO -> Y2Mn2O7 + Y2O3 + 4 NaCl (dG = -0.143 eV/atom)
# O2 + 3 Na4Mn2O5 + 4 YCl3 -> Y2Mn2O7 + 2 YMn2O5 + 12 NaCl (dG = -0.248 eV/atom)
# 0.25 O2 + YMn2O5 + 0.5 Y2O3 -> Y2Mn2O7 (dG = -0.019 eV/atom)
# Na2CO3 + YCl3 -> CO2 + YClO + 2 NaCl (dG = -0.034 eV/atom)
#
# Total Cost: 0.262 | Average Cost: 0.052
#
#
# Path 13:
# Na2CO3 -> CO2 + Na2O (dG = 0.454 eV/atom)
# 1.308 Mn2O3 + 1.026 Y2O3 -> Y2Mn2O7 + 0.05128 YMn12 (dG = 0.144 eV/atom)
# Na2O + YCl3 -> YClO + 2 NaCl (dG = -0.438 eV/atom)
# 2 YClO + Na2O -> Y2O3 + 2 NaCl (dG = -0.264 eV/atom)
# 2.125 O2 + 0.1667 YMn12 + 0.9167 Y2O3 -> Y2Mn2O7 (dG = -0.926 eV/atom)
#
# Total Cost: 0.262 | Average Cost: 0.052
#
#
# Path 14:
# Na2CO3 -> CO2 + Na2O (dG = 0.454 eV/atom)
# 0.25 O2 + 0.5 Mn2O3 -> MnO2 (dG = -0.058 eV/atom)
# 2 Na2O + YCl3 -> NaYO2 + 3 NaCl (dG = -0.477 eV/atom)
# 1.5 NaYO2 + 0.5 YCl3 -> Y2O3 + 1.5 NaCl (dG = -0.169 eV/atom)
# 2 MnO2 + Y2O3 -> Y2Mn2O7 (dG = -0.07 eV/atom)
#
# Total Cost: 0.265 | Average Cost: 0.053
#
#
# Path 15:
# Na2CO3 -> CO2 + Na2O (dG = 0.454 eV/atom)
# 1.308 Mn2O3 + 1.026 Y2O3 -> Y2Mn2O7 + 0.05128 YMn12 (dG = 0.144 eV/atom)
# 2 Na2O + YCl3 -> NaYO2 + 3 NaCl (dG = -0.477 eV/atom)
# 1.5 NaYO2 + 0.5 YCl3 -> Y2O3 + 1.5 NaCl (dG = -0.169 eV/atom)
# 2.125 O2 + 0.1667 YMn12 + 0.9167 Y2O3 -> Y2Mn2O7 (dG = -0.926 eV/atom)
#
# Total Cost: 0.271 | Average Cost: 0.054
#
#
# Path 16:
# Na2CO3 -> CO2 + Na2O (dG = 0.454 eV/atom)
# 0.25 O2 + 0.5 Mn2O3 -> MnO2 (dG = -0.058 eV/atom)
# 3 Na2O + 2 YCl3 -> Y2O3 + 6 NaCl (dG = -0.5 eV/atom)
# 2 MnO2 + Y2O3 -> Y2Mn2O7 (dG = -0.07 eV/atom)
#
# Total Cost: 0.28 | Average Cost: 0.07
#
#
# Path 17:
# 0.5 Mn2O3 + Na2CO3 -> CO2 + 0.5 Na4Mn2O5 (dG = 0.178 eV/atom)
# Na2CO3 -> CO2 + Na2O (dG = 0.454 eV/atom)
# 3 Na2O + 2 YCl3 -> Y2O3 + 6 NaCl (dG = -0.5 eV/atom)
# O2 + 3 Na4Mn2O5 + 4 YCl3 -> Y2Mn2O7 + 2 YMn2O5 + 12 NaCl (dG = -0.248 eV/atom)
# 0.25 O2 + YMn2O5 + 0.5 Y2O3 -> Y2Mn2O7 (dG = -0.019 eV/atom)
#
# Total Cost: 0.283 | Average Cost: 0.057
#
#
# Path 18:
# 0.2 Mn2O3 + Na2CO3 -> CO2 + 0.4 Na5MnO4 (dG = 0.304 eV/atom)
# 0.25 O2 + 0.5 Mn2O3 -> MnO2 (dG = -0.058 eV/atom)
# 0.5 O2 + 2 Na5MnO4 + 3.333 YCl3 -> Y2Mn2O7 + 0.6667 Y2O3 + 10 NaCl (dG = -0.358 eV/atom)
# 2 MnO2 + Y2O3 -> Y2Mn2O7 (dG = -0.07 eV/atom)
#
# Total Cost: 0.287 | Average Cost: 0.072
#
#
# Path 19:
# 0.5 Mn2O3 + Na2CO3 -> CO2 + 0.5 Na4Mn2O5 (dG = 0.178 eV/atom)
# 0.2 Mn2O3 + Na2CO3 -> CO2 + 0.4 Na5MnO4 (dG = 0.304 eV/atom)
# O2 + 3 Na4Mn2O5 + 4 YCl3 -> Y2Mn2O7 + 2 YMn2O5 + 12 NaCl (dG = -0.248 eV/atom)
# 0.25 O2 + YMn2O5 + 0.5 Y2O3 -> Y2Mn2O7 (dG = -0.019 eV/atom)
# 0.5 O2 + 2 Na5MnO4 + 3.333 YCl3 -> Y2Mn2O7 + 0.6667 Y2O3 + 10 NaCl (dG = -0.358 eV/atom)
#
# Total Cost: 0.287 | Average Cost: 0.057
#
#
# Path 20:
# Na2CO3 -> CO2 + Na2O (dG = 0.454 eV/atom)
# 1.154 Mn2O3 + 0.5128 Y2O3 -> YMn2O5 + 0.02564 YMn12 (dG = 0.059 eV/atom)
# 3 Na2O + 2 YCl3 -> Y2O3 + 6 NaCl (dG = -0.5 eV/atom)
# 0.25 O2 + YMn2O5 + 0.5 Y2O3 -> Y2Mn2O7 (dG = -0.019 eV/atom)
# 2.125 O2 + 0.1667 YMn12 + 0.9167 Y2O3 -> Y2Mn2O7 (dG = -0.926 eV/atom)
#
# Total Cost: 0.288 | Average Cost: 0.058
#
#
# Path 21:
# 0.2 Mn2O3 + Na2CO3 -> CO2 + 0.4 Na5MnO4 (dG = 0.304 eV/atom)
# 1.154 Mn2O3 + 0.5128 Y2O3 -> YMn2O5 + 0.02564 YMn12 (dG = 0.059 eV/atom)
# 0.25 O2 + YMn2O5 + 0.5 Y2O3 -> Y2Mn2O7 (dG = -0.019 eV/atom)
# 0.5 O2 + 2 Na5MnO4 + 3.333 YCl3 -> Y2Mn2O7 + 0.6667 Y2O3 + 10 NaCl (dG = -0.358 eV/atom)
# 2.125 O2 + 0.1667 YMn12 + 0.9167 Y2O3 -> Y2Mn2O7 (dG = -0.926 eV/atom)
#
# Total Cost: 0.292 | Average Cost: 0.058
#
#
# Path 22:
# Na2CO3 -> CO2 + Na2O (dG = 0.454 eV/atom)
# 1.308 Mn2O3 + 1.026 Y2O3 -> Y2Mn2O7 + 0.05128 YMn12 (dG = 0.144 eV/atom)
# 3 Na2O + 2 YCl3 -> Y2O3 + 6 NaCl (dG = -0.5 eV/atom)
# 2.125 O2 + 0.1667 YMn12 + 0.9167 Y2O3 -> Y2Mn2O7 (dG = -0.926 eV/atom)
#
# Total Cost: 0.292 | Average Cost: 0.073
#
#
# Path 23:
# Mn2O3 + Na2CO3 -> CO2 + 2 NaMnO2 (dG = 0.069 eV/atom)
# Na2CO3 -> CO2 + Na2O (dG = 0.454 eV/atom)
# 4 Na2O + 3 YCl3 -> Y3ClO4 + 8 NaCl (dG = -0.48 eV/atom)
# 0.5 O2 + Mn2O3 + Y3ClO4 -> Y2Mn2O7 + YClO (dG = -0.083 eV/atom)
# 0.5 O2 + 2 YClO + 2 NaMnO2 -> Y2Mn2O7 + 2 NaCl (dG = -0.101 eV/atom)
#
# Total Cost: 0.294 | Average Cost: 0.059
#
#
# Path 24:
# 0.2 Mn2O3 + Na2CO3 -> CO2 + 0.4 Na5MnO4 (dG = 0.304 eV/atom)
# 1.308 Mn2O3 + 1.026 Y2O3 -> Y2Mn2O7 + 0.05128 YMn12 (dG = 0.144 eV/atom)
# 0.5 O2 + 2 Na5MnO4 + 3.333 YCl3 -> Y2Mn2O7 + 0.6667 Y2O3 + 10 NaCl (dG = -0.358 eV/atom)
# 2.125 O2 + 0.1667 YMn12 + 0.9167 Y2O3 -> Y2Mn2O7 (dG = -0.926 eV/atom)
#
# Total Cost: 0.294 | Average Cost: 0.074

# %% [markdown]
# ### Pandas view
#
# The function below (*create_total_path_df*), is useful for transforming the pathway results to a Pandas DataFrame for convenience.

# %%
import pandas 

def create_total_path_df(paths, latex=False):
    path_dict = []
    for idx,p in enumerate(paths):
        rxn_dict_items = sorted(list(p.rxn_dict.items()), key=lambda x: x[1])
        for rxn,cost in rxn_dict_items:
            dG = rxn.calculated_reaction_energy / sum(
                [rxn.get_el_amount(elem) for elem in rxn.elements])
            if latex:
                path_dict.append({"Path":idx+1, r"Reactions":rf"\ce{{{str(rxn)}}}",
                                  r"$\Delta$G$_{rxn}$ (eV/atom)":dG,"Cost":cost,"Total Cost":round(p.total_cost,3)})
            else:
                path_dict.append({"path":idx+1,"rxn":rxn,"dG":round(dG,4),"cost":round(cost,4), "total_cost":round(p.total_cost,3)})
            
    df = pandas.DataFrame(path_dict)
    
    if latex:
        df = df.set_index(["Path","Total Cost","Reactions"])
    else:
        df = df.set_index(["path","total_cost","rxn"])
                     
    return df

# %%
df = create_total_path_df(cleaned_paths)
df
# Out:
#                                                                         dG  \
# path total_cost rxn
# 1    0.238      Na2CO3 + YCl3 -> CO2 + YClO + 2 NaCl               -0.0338
#                 0.5 O2 + 2 YClO + 2 NaMnO2 -> Y2Mn2O7 + 2 NaCl     -0.1013
#                 Mn2O3 + Na2CO3 -> CO2 + 2 NaMnO2                    0.0686
# 2    0.246      2.125 O2 + 0.1667 YMn12 + 0.9167 Y2O3 -> Y2Mn2O7   -0.9265
#                 0.5 O2 + Na4Mn2O5 + 4 YClO -> Y2Mn2O7 + Y2O3 + ... -0.1431
# ...                                                                    ...
# 23   0.294      Na2CO3 -> CO2 + Na2O                                0.4544
# 24   0.294      2.125 O2 + 0.1667 YMn12 + 0.9167 Y2O3 -> Y2Mn2O7   -0.9265
#                 0.5 O2 + 2 Na5MnO4 + 3.333 YCl3 -> Y2Mn2O7 + 0.... -0.3580
#                 1.308 Mn2O3 + 1.026 Y2O3 -> Y2Mn2O7 + 0.05128 Y...  0.1436
#                 0.2 Mn2O3 + Na2CO3 -> CO2 + 0.4 Na5MnO4             0.3039
#
#                                                                       cost
# path total_cost rxn
# 1    0.238      Na2CO3 + YCl3 -> CO2 + YClO + 2 NaCl                0.2263
#                 0.5 O2 + 2 YClO + 2 NaMnO2 -> Y2Mn2O7 + 2 NaCl      0.2290
#                 Mn2O3 + Na2CO3 -> CO2 + 2 NaMnO2                    0.2706
# 2    0.246      2.125 O2 + 0.1667 YMn12 + 0.9167 Y2O3 -> Y2Mn2O7    0.1134
#                 0.5 O2 + Na4Mn2O5 + 4 YClO -> Y2Mn2O7 + Y2O3 + ...  0.2175
# ...                                                                    ...
# 23   0.294      Na2CO3 -> CO2 + Na2O                                0.3514
# 24   0.294      2.125 O2 + 0.1667 YMn12 + 0.9167 Y2O3 -> Y2Mn2O7    0.1134
#                 0.5 O2 + 2 Na5MnO4 + 3.333 YCl3 -> Y2Mn2O7 + 0....  0.1695
#                 1.308 Mn2O3 + 1.026 Y2O3 -> Y2Mn2O7 + 0.05128 Y...  0.3002
#                 0.2 Mn2O3 + Na2CO3 -> CO2 + 0.4 Na5MnO4             0.3244
#
# [111 rows x 2 columns]

# %% [markdown]
# # Example 3: Fe$_2$SiS$_4$ synthesis from iron silicide precursors

# %%
chemsys = "Fe-S-Si"

precursors = ["Fe3Si", "Fe5Si3", "S"]
targets = ["Fe2SiS4"]

hypothetical_phases = ["SiS","SiS4"]

temp = 900
include_metastable = 0.5
k=75
max_num_combos=6
chempots=None

# %%
with MPRester() as mpr:  # requires API key from Materials Project
    all_entries = mpr.get_entries_in_chemsys(chemsys, inc_structure="final")

# %%
rn, paths = run_reaction_network_analysis(all_entries, precursors, targets, temp, include_metastable, k,  chempots, max_num_combos)

# %%
with open("results/fe2sis4_paths.json") as f:
    paths = json.load(f, cls=MontyDecoder)

# %%
cleaned_paths = set()
for idx, p in enumerate(paths):
    interdependent, consolidated_rxn = find_interdependent_rxns(p, precursors, verbose=False)
    if interdependent:
        print(f"Path {idx+1} removed")
        continue
    cleaned_paths.add(p)

# %%
hypothetical_phases = {Composition(c) for c in hypothetical_phases}

for idx, p in enumerate(cleaned_paths.copy()):
    if set(p.all_comp) & hypothetical_phases:
        cleaned_paths.remove(p)
        
cleaned_paths = sorted(list(cleaned_paths), key=lambda x: x.total_cost)

# %%
for num, path in enumerate(cleaned_paths):
    print(f"Path {num+1}:")
    print(path)
# Out:
# Path 1:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.4286 Fe5Si3 + 4 S -> Fe2SiS4 + 0.1429 FeSi2 (dG = -0.543 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.177 | Average Cost: 0.044
#
#
# Path 2:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.4286 Fe5Si3 + 4 S -> Fe2SiS4 + 0.1429 FeSi2 (dG = -0.543 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.177 | Average Cost: 0.035
#
#
# Path 3:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.4286 Fe5Si3 + 4 S -> Fe2SiS4 + 0.1429 FeSi2 (dG = -0.543 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.179 | Average Cost: 0.03
#
#
# Path 4:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.4286 Fe5Si3 + 4 S -> Fe2SiS4 + 0.1429 FeSi2 (dG = -0.543 eV/atom)
# 0.5 Fe5Si3 + 4 S -> Fe2SiS4 + 0.5 FeSi (dG = -0.521 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.18 | Average Cost: 0.03
#
#
# Path 5:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.5 Fe5Si3 + 4 S -> Fe2SiS4 + 0.5 FeSi (dG = -0.521 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.182 | Average Cost: 0.046
#
#
# Path 6:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.5 Fe5Si3 + 4 S -> Fe2SiS4 + 0.5 FeSi (dG = -0.521 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.183 | Average Cost: 0.031
#
#
# Path 7:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.5 Fe5Si3 + 4 S -> Fe2SiS4 + 0.5 FeSi (dG = -0.521 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.184 | Average Cost: 0.037
#
#
# Path 8:
# 6 S + Fe3Si -> Fe2SiS4 + FeS2 (dG = -0.628 eV/atom)
# 2 Fe5Si3 + 20 S -> Si + 5 Fe2SiS4 (dG = -0.541 eV/atom)
# Si + 2 FeS2 -> Fe2SiS4 (dG = 0.055 eV/atom)
#
# Total Cost: 0.185 | Average Cost: 0.062
#
#
# Path 9:
# 0.4286 Fe5Si3 + 4 S -> Fe2SiS4 + 0.1429 FeSi2 (dG = -0.543 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.186 | Average Cost: 0.047
#
#
# Path 10:
# 0.4286 Fe5Si3 + 4 S -> Fe2SiS4 + 0.1429 FeSi2 (dG = -0.543 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.187 | Average Cost: 0.031
#
#
# Path 11:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.5 Fe5Si3 + 4 S -> Fe2SiS4 + 0.5 FeSi (dG = -0.521 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# 0.2857 Fe5Si3 + S -> FeS + 0.4286 FeSi2 (dG = -0.467 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.187 | Average Cost: 0.031
#
#
# Path 12:
# 0.4286 Fe5Si3 + 4 S -> Fe2SiS4 + 0.1429 FeSi2 (dG = -0.543 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.188 | Average Cost: 0.038
#
#
# Path 13:
# 0.4286 Fe5Si3 + 4 S -> Fe2SiS4 + 0.1429 FeSi2 (dG = -0.543 eV/atom)
# 0.5 Fe5Si3 + 4 S -> Fe2SiS4 + 0.5 FeSi (dG = -0.521 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.188 | Average Cost: 0.031
#
#
# Path 14:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 2 Fe5Si3 + 20 S -> Si + 5 Fe2SiS4 (dG = -0.541 eV/atom)
# 2 S + 0.5 Fe3Si -> FeS2 + 0.5 FeSi (dG = -0.635 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# Si + 2 FeS2 -> Fe2SiS4 (dG = 0.055 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.189 | Average Cost: 0.032
#
#
# Path 15:
# 0.5 Fe5Si3 + 4 S -> Fe2SiS4 + 0.5 FeSi (dG = -0.521 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.189 | Average Cost: 0.038
#
#
# Path 16:
# 0.4286 Fe5Si3 + 4 S -> Fe2SiS4 + 0.1429 FeSi2 (dG = -0.543 eV/atom)
# 0.5 Fe5Si3 + 4 S -> Fe2SiS4 + 0.5 FeSi (dG = -0.521 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.19 | Average Cost: 0.032
#
#
# Path 17:
# 0.5 Fe5Si3 + 4 S -> Fe2SiS4 + 0.5 FeSi (dG = -0.521 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.191 | Average Cost: 0.032
#
#
# Path 18:
# 0.5 Fe5Si3 + 4 S -> Fe2SiS4 + 0.5 FeSi (dG = -0.521 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.192 | Average Cost: 0.048
#
#
# Path 19:
# 6 S + Fe3Si -> Fe2SiS4 + FeS2 (dG = -0.628 eV/atom)
# 2 Fe5Si3 + 22 S -> SiS2 + 5 Fe2SiS4 (dG = -0.605 eV/atom)
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 2 Fe5Si3 + 20 S -> Si + 5 Fe2SiS4 (dG = -0.541 eV/atom)
# Si + 2 FeS2 -> Fe2SiS4 (dG = 0.055 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.193 | Average Cost: 0.032
#
#
# Path 20:
# 2 Fe5Si3 + 20 S -> Si + 5 Fe2SiS4 (dG = -0.541 eV/atom)
# 2 S + 0.5 Fe3Si -> FeS2 + 0.5 FeSi (dG = -0.635 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# Si + 2 FeS2 -> Fe2SiS4 (dG = 0.055 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.195 | Average Cost: 0.032
#
#
# Path 21:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 2 Fe5Si3 + 20 S -> Si + 5 Fe2SiS4 (dG = -0.541 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# 0.6667 Fe5Si3 + 4.667 S -> FeSi2 + 2.333 FeS2 (dG = -0.595 eV/atom)
# Si + 2 FeS2 -> Fe2SiS4 (dG = 0.055 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.196 | Average Cost: 0.033
#
#
# Path 22:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 2 Fe5Si3 + 20 S -> Si + 5 Fe2SiS4 (dG = -0.541 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# 0.5 Fe5Si3 + 2 S -> FeS2 + 1.5 FeSi (dG = -0.495 eV/atom)
# Si + 2 FeS2 -> Fe2SiS4 (dG = 0.055 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.197 | Average Cost: 0.033
#
#
# Path 23:
# 2 Fe5Si3 + 20 S -> Si + 5 Fe2SiS4 (dG = -0.541 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# 0.6667 Fe5Si3 + 4.667 S -> FeSi2 + 2.333 FeS2 (dG = -0.595 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# Si + 2 FeS2 -> Fe2SiS4 (dG = 0.055 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.198 | Average Cost: 0.033
#
#
# Path 24:
# 2 Fe5Si3 + 22 S -> SiS2 + 5 Fe2SiS4 (dG = -0.605 eV/atom)
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.4286 Fe5Si3 + 4 S -> Fe2SiS4 + 0.1429 FeSi2 (dG = -0.543 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.198 | Average Cost: 0.04
#
#
# Path 25:
# 2 Fe5Si3 + 22 S -> SiS2 + 5 Fe2SiS4 (dG = -0.605 eV/atom)
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.5 Fe5Si3 + 4 S -> Fe2SiS4 + 0.5 FeSi (dG = -0.521 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.198 | Average Cost: 0.04
#
#
# Path 26:
# 2 Fe5Si3 + 22 S -> SiS2 + 5 Fe2SiS4 (dG = -0.605 eV/atom)
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.4286 Fe5Si3 + 4 S -> Fe2SiS4 + 0.1429 FeSi2 (dG = -0.543 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.198 | Average Cost: 0.033
#
#
# Path 27:
# 2 Fe5Si3 + 22 S -> SiS2 + 5 Fe2SiS4 (dG = -0.605 eV/atom)
# 0.5 Fe5Si3 + 4 S -> Fe2SiS4 + 0.5 FeSi (dG = -0.521 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.199 | Average Cost: 0.033
#
#
# Path 28:
# 2 Fe5Si3 + 22 S -> SiS2 + 5 Fe2SiS4 (dG = -0.605 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.199 | Average Cost: 0.05
#
#
# Path 29:
# 2 Fe5Si3 + 22 S -> SiS2 + 5 Fe2SiS4 (dG = -0.605 eV/atom)
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.5 Fe5Si3 + 4 S -> Fe2SiS4 + 0.5 FeSi (dG = -0.521 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.2 | Average Cost: 0.033
#
#
# Path 30:
# 2 Fe5Si3 + 22 S -> SiS2 + 5 Fe2SiS4 (dG = -0.605 eV/atom)
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.2 | Average Cost: 0.04
#
#
# Path 31:
# 2 Fe5Si3 + 22 S -> SiS2 + 5 Fe2SiS4 (dG = -0.605 eV/atom)
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.2 | Average Cost: 0.067
#
#
# Path 32:
# 2 Fe5Si3 + 20 S -> Si + 5 Fe2SiS4 (dG = -0.541 eV/atom)
# 10 S + 2 Fe3Si -> FeSi2 + 5 FeS2 (dG = -0.675 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# Si + 2 FeS2 -> Fe2SiS4 (dG = 0.055 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.2 | Average Cost: 0.033
#
#
# Path 33:
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# 0.2857 Fe5Si3 + S -> FeS + 0.4286 FeSi2 (dG = -0.467 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.201 | Average Cost: 0.05
#
#
# Path 34:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 2 Fe5Si3 + 20 S -> Si + 5 Fe2SiS4 (dG = -0.541 eV/atom)
# 10 S + 2 Fe3Si -> FeSi2 + 5 FeS2 (dG = -0.675 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# Si + 2 FeS2 -> Fe2SiS4 (dG = 0.055 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.201 | Average Cost: 0.033
#
#
# Path 35:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# 0.2857 Fe5Si3 + S -> FeS + 0.4286 FeSi2 (dG = -0.467 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.201 | Average Cost: 0.05
#
#
# Path 36:
# 2 Fe5Si3 + 22 S -> SiS2 + 5 Fe2SiS4 (dG = -0.605 eV/atom)
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.201 | Average Cost: 0.04
#
#
# Path 37:
# 2 Fe5Si3 + 20 S -> Si + 5 Fe2SiS4 (dG = -0.541 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# 0.5 Fe5Si3 + 2 S -> FeS2 + 1.5 FeSi (dG = -0.495 eV/atom)
# Si + 2 FeS2 -> Fe2SiS4 (dG = 0.055 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.202 | Average Cost: 0.034
#
#
# Path 38:
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# 0.2857 Fe5Si3 + S -> FeS + 0.4286 FeSi2 (dG = -0.467 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.202 | Average Cost: 0.034
#
#
# Path 39:
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# 0.2857 Fe5Si3 + S -> FeS + 0.4286 FeSi2 (dG = -0.467 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.203 | Average Cost: 0.041
#
#
# Path 40:
# 2 Fe5Si3 + 22 S -> SiS2 + 5 Fe2SiS4 (dG = -0.605 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.203 | Average Cost: 0.034
#
#
# Path 41:
# 2 Fe5Si3 + 22 S -> SiS2 + 5 Fe2SiS4 (dG = -0.605 eV/atom)
# 0.4286 Fe5Si3 + 4 S -> Fe2SiS4 + 0.1429 FeSi2 (dG = -0.543 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.204 | Average Cost: 0.034
#
#
# Path 42:
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# 0.2857 Fe5Si3 + S -> FeS + 0.4286 FeSi2 (dG = -0.467 eV/atom)
# 0.5 Fe5Si3 + S -> FeS + 1.5 FeSi (dG = -0.391 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.205 | Average Cost: 0.034
#
#
# Path 43:
# 2 Fe5Si3 + 22 S -> SiS2 + 5 Fe2SiS4 (dG = -0.605 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.205 | Average Cost: 0.051
#
#
# Path 44:
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# 0.5 Fe5Si3 + S -> FeS + 1.5 FeSi (dG = -0.391 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.206 | Average Cost: 0.041
#
#
# Path 45:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# 0.2857 Fe5Si3 + S -> FeS + 0.4286 FeSi2 (dG = -0.467 eV/atom)
# 0.5 Fe5Si3 + S -> FeS + 1.5 FeSi (dG = -0.391 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.207 | Average Cost: 0.034
#
#
# Path 46:
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# 0.2857 Fe5Si3 + S -> FeS + 0.4286 FeSi2 (dG = -0.467 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# 0.5 Fe5Si3 + S -> FeS + 1.5 FeSi (dG = -0.391 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.208 | Average Cost: 0.035
#
#
# Path 47:
# 0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 (dG = -0.787 eV/atom)
# S + 0.4 Fe3Si -> FeS + 0.2 FeSi2 (dG = -0.545 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# 0.5 Fe5Si3 + S -> FeS + 1.5 FeSi (dG = -0.391 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.208 | Average Cost: 0.035
#
#
# Path 48:
# 5 S + Fe3Si -> Fe2SiS4 + FeS (dG = -0.586 eV/atom)
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# 0.5 Fe5Si3 + S -> FeS + 1.5 FeSi (dG = -0.391 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.209 | Average Cost: 0.052
#
#
# Path 49:
# 2 FeSi + 6 S -> SiS2 + Fe2SiS4 (dG = -0.632 eV/atom)
# S + 0.5 Fe3Si -> FeS + 0.5 FeSi (dG = -0.509 eV/atom)
# 0.5 Fe5Si3 + S -> FeS + 1.5 FeSi (dG = -0.391 eV/atom)
# SiS2 + 2 FeS -> Fe2SiS4 (dG = 0.27 eV/atom)
#
# Total Cost: 0.21 | Average Cost: 0.052

# %%
df = create_total_path_df(cleaned_paths)
df
# Out:
#                                                                      dG  \
# path total_cost rxn
# 1    0.177      0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 -0.7870
#                 5 S + Fe3Si -> Fe2SiS4 + FeS                    -0.5856
#                 0.4286 Fe5Si3 + 4 S -> Fe2SiS4 + 0.1429 FeSi2   -0.5426
#                 SiS2 + 2 FeS -> Fe2SiS4                          0.2703
# 2    0.177      0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4 -0.7870
# ...                                                                 ...
# 48   0.209      SiS2 + 2 FeS -> Fe2SiS4                          0.2703
# 49   0.210      2 FeSi + 6 S -> SiS2 + Fe2SiS4                  -0.6324
#                 S + 0.5 Fe3Si -> FeS + 0.5 FeSi                 -0.5090
#                 0.5 Fe5Si3 + S -> FeS + 1.5 FeSi                -0.3910
#                 SiS2 + 2 FeS -> Fe2SiS4                          0.2703
#
#                                                                    cost
# path total_cost rxn
# 1    0.177      0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4  0.1293
#                 5 S + Fe3Si -> Fe2SiS4 + FeS                     0.1561
#                 0.4286 Fe5Si3 + 4 S -> Fe2SiS4 + 0.1429 FeSi2    0.1624
#                 SiS2 + 2 FeS -> Fe2SiS4                          0.3347
# 2    0.177      0.6667 FeSi2 + 3.333 S -> SiS2 + 0.3333 Fe2SiS4  0.1293
# ...                                                                 ...
# 48   0.209      SiS2 + 2 FeS -> Fe2SiS4                          0.3347
# 49   0.210      2 FeSi + 6 S -> SiS2 + Fe2SiS4                   0.1494
#                 S + 0.5 Fe3Si -> FeS + 0.5 FeSi                  0.1675
#                 0.5 Fe5Si3 + S -> FeS + 1.5 FeSi                 0.1866
#                 SiS2 + 2 FeS -> Fe2SiS4                          0.3347
#
# [258 rows x 2 columns]

# %% [markdown]
# # Example 4: YBCO synthesis from barium peroxide

# %%
chemsys = "Ba-Cu-O-Y"

precursors = ["Y2O3", "BaO2", "CuO"]
targets = ["Y2Ba4Cu6O13", "O2"]

hypothetical_phases = ["Cu8O7","Ba8Cu8O19","Ba3Y2O6"]

temp = 1200
include_metastable = 0.1
k=20
chempots={Element("O"):0}
max_num_combos=5

# %%
rn, paths = run_reaction_network_analysis(all_entries, precursors, targets, temp, include_metastable, k,  chempots, max_num_combos)

# %%
with open("results/ybco_paths.json") as f:
    paths = json.load(f, cls=MontyDecoder)

# %%
cleaned_paths = set()
for idx, p in enumerate(paths):
    interdependent, consolidated_rxn = find_interdependent_rxns(p, precursors, verbose=False)
    if interdependent:
        print(f"Path {idx+1} removed")
        continue
    cleaned_paths.add(p)

# %%
hypothetical_phases = {Composition(c) for c in hypothetical_phases}

for idx, p in enumerate(cleaned_paths.copy()):
    if set(p.all_comp) & hypothetical_phases:
        cleaned_paths.remove(p)
        
cleaned_paths = sorted(list(cleaned_paths), key=lambda x: x.total_cost)

# %%
for num, path in enumerate(cleaned_paths):
    print(f"Path {num+1}:")
    print(path)
# Out:
# Path 1:
# BaO2 + CuO -> BaCuO2 + 0.5 O2 (dG = -0.16 eV/atom)
# Ba4Y2O7 + 6 CuO -> Ba4Y2Cu6O13 (dG = -0.137 eV/atom)
# 3 Y2O3 + 12 BaCuO2 -> Ba4Y2O7 + 2 Ba4Y2Cu6O13 (dG = 0.039 eV/atom)
#
# Total Cost: 0.18 | Average Cost: 0.06
#
#
# Path 2:
# BaO2 + CuO -> BaCuO2 + 0.5 O2 (dG = -0.16 eV/atom)
# 3.5 Y2O3 + 9 BaCuO2 -> Ba3Y4O9 + 1.5 Ba4Y2Cu6O13 (dG = 0.014 eV/atom)
# 0.8 Ba3Y4O9 + 5.6 CuO -> Y2Cu2O5 + 0.6 Ba4Y2Cu6O13 (dG = -0.053 eV/atom)
# 2 BaO2 + 2 CuO -> Ba2Cu2O5 + 0.5 O2 (dG = -0.225 eV/atom)
# 2 Ba2Cu2O5 + Y2Cu2O5 -> O2 + Ba4Y2Cu6O13 (dG = 0.039 eV/atom)
#
# Total Cost: 0.182 | Average Cost: 0.036
#
#
# Path 3:
# BaO2 + CuO -> BaCuO2 + 0.5 O2 (dG = -0.16 eV/atom)
# 3.5 Y2O3 + 9 BaCuO2 -> Ba3Y4O9 + 1.5 Ba4Y2Cu6O13 (dG = 0.014 eV/atom)
# 0.8 Ba3Y4O9 + 5.6 CuO -> Y2Cu2O5 + 0.6 Ba4Y2Cu6O13 (dG = -0.053 eV/atom)
# Y2Cu2O5 + 4 BaCuO2 -> Ba4Y2Cu6O13 (dG = -0.01 eV/atom)
#
# Total Cost: 0.182 | Average Cost: 0.046
#
#
# Path 4:
# BaO2 + CuO -> BaCuO2 + 0.5 O2 (dG = -0.16 eV/atom)
# 2.25 Ba2CuO3 + 2.375 Y2O3 -> Ba3Y4O9 + 0.375 Ba4Y2Cu6O13 (dG = -0.007 eV/atom)
# 0.5 Y2O3 + 4 BaCuO2 -> Ba2CuO3 + 0.5 Ba4Y2Cu6O13 (dG = 0.022 eV/atom)
# 0.8 Ba3Y4O9 + 5.6 CuO -> Y2Cu2O5 + 0.6 Ba4Y2Cu6O13 (dG = -0.053 eV/atom)
# Y2Cu2O5 + 4 BaCuO2 -> Ba4Y2Cu6O13 (dG = -0.01 eV/atom)
#
# Total Cost: 0.185 | Average Cost: 0.037
#
#
# Path 5:
# BaO2 + CuO -> BaCuO2 + 0.5 O2 (dG = -0.16 eV/atom)
# 2 Y2O3 + 3 BaO2 -> Ba3Y4O9 + 1.5 O2 (dG = -0.061 eV/atom)
# 0.8 Ba3Y4O9 + 5.6 CuO -> Y2Cu2O5 + 0.6 Ba4Y2Cu6O13 (dG = -0.053 eV/atom)
# Y2Cu2O5 + 4 BaCuO2 -> Ba4Y2Cu6O13 (dG = -0.01 eV/atom)
#
# Total Cost: 0.186 | Average Cost: 0.046
#
#
# Path 6:
# BaO2 + CuO -> BaCuO2 + 0.5 O2 (dG = -0.16 eV/atom)
# 2 BaO2 + CuO -> Ba2CuO3 + O2 (dG = -0.128 eV/atom)
# 2.25 Ba2CuO3 + 2.375 Y2O3 -> Ba3Y4O9 + 0.375 Ba4Y2Cu6O13 (dG = -0.007 eV/atom)
# 0.8 Ba3Y4O9 + 5.6 CuO -> Y2Cu2O5 + 0.6 Ba4Y2Cu6O13 (dG = -0.053 eV/atom)
# Y2Cu2O5 + 4 BaCuO2 -> Ba4Y2Cu6O13 (dG = -0.01 eV/atom)
#
# Total Cost: 0.186 | Average Cost: 0.037
#
#
# Path 7:
# 2 BaO2 + CuO -> Ba2CuO3 + O2 (dG = -0.128 eV/atom)
# 2.25 Ba2CuO3 + 2.375 Y2O3 -> Ba3Y4O9 + 0.375 Ba4Y2Cu6O13 (dG = -0.007 eV/atom)
# 0.8 Ba3Y4O9 + 5.6 CuO -> Y2Cu2O5 + 0.6 Ba4Y2Cu6O13 (dG = -0.053 eV/atom)
# 2 BaO2 + 2 CuO -> Ba2Cu2O5 + 0.5 O2 (dG = -0.225 eV/atom)
# 2 Ba2Cu2O5 + Y2Cu2O5 -> O2 + Ba4Y2Cu6O13 (dG = 0.039 eV/atom)
#
# Total Cost: 0.187 | Average Cost: 0.037
#
#
# Path 8:
# 2 Y2O3 + 3 BaO2 -> Ba3Y4O9 + 1.5 O2 (dG = -0.061 eV/atom)
# 0.8 Ba3Y4O9 + 5.6 CuO -> Y2Cu2O5 + 0.6 Ba4Y2Cu6O13 (dG = -0.053 eV/atom)
# 2 BaO2 + 2 CuO -> Ba2Cu2O5 + 0.5 O2 (dG = -0.225 eV/atom)
# 2 Ba2Cu2O5 + Y2Cu2O5 -> O2 + Ba4Y2Cu6O13 (dG = 0.039 eV/atom)
#
# Total Cost: 0.187 | Average Cost: 0.047
#
#
# Path 9:
# 2 Y2O3 + 3 BaO2 -> Ba3Y4O9 + 1.5 O2 (dG = -0.061 eV/atom)
# 0.8 Ba3Y4O9 + 5.6 CuO -> Y2Cu2O5 + 0.6 Ba4Y2Cu6O13 (dG = -0.053 eV/atom)
# BaO2 + 3 CuO -> BaCu3O4 + 0.5 O2 (dG = -0.126 eV/atom)
# 0.6667 BaCu3O4 + 1.333 BaO2 -> Ba2Cu2O5 + 0.1667 O2 (dG = -0.16 eV/atom)
# 2 Ba2Cu2O5 + Y2Cu2O5 -> O2 + Ba4Y2Cu6O13 (dG = 0.039 eV/atom)
#
# Total Cost: 0.189 | Average Cost: 0.038
#
#
# Path 10:
# BaO2 + CuO -> BaCuO2 + 0.5 O2 (dG = -0.16 eV/atom)
# Ba4Y2O7 + 6 CuO -> Ba4Y2Cu6O13 (dG = -0.137 eV/atom)
# Y2O3 + 2 Ba2(CuO2)3 -> O2 + Ba4Y2Cu6O13 (dG = 0.075 eV/atom)
# 3 Y2O3 + 12 BaCuO2 -> Ba4Y2O7 + 2 Ba4Y2Cu6O13 (dG = 0.039 eV/atom)
# 4 BaO2 + 6 CuO -> O2 + 2 Ba2(CuO2)3 (dG = -0.231 eV/atom)
#
# Total Cost: 0.19 | Average Cost: 0.038
#
#
# Path 11:
# BaO2 + CuO -> BaCuO2 + 0.5 O2 (dG = -0.16 eV/atom)
# 0.5 Y2O3 + 2 BaO2 -> O2 + 0.5 Ba4Y2O7 (dG = -0.007 eV/atom)
# Ba4Y2O7 + 6 CuO -> Ba4Y2Cu6O13 (dG = -0.137 eV/atom)
# 3 Y2O3 + 12 BaCuO2 -> Ba4Y2O7 + 2 Ba4Y2Cu6O13 (dG = 0.039 eV/atom)
#
# Total Cost: 0.191 | Average Cost: 0.048
#
#
# Path 12:
# 2 BaO2 + 2 CuO -> Ba2Cu2O5 + 0.5 O2 (dG = -0.225 eV/atom)
# 0.5 Y2O3 + CuO -> YCuO2 + 0.25 O2 (dG = 0.038 eV/atom)
# 4 Ba2Cu2O5 + 4 YCuO2 -> O2 + 2 Ba4Y2Cu6O13 (dG = 0.024 eV/atom)
#
# Total Cost: 0.192 | Average Cost: 0.064
#
#
# Path 13:
# Y2O3 + 2 Ba2(CuO2)3 -> O2 + Ba4Y2Cu6O13 (dG = 0.075 eV/atom)
# 2 BaO2 + 2 CuO -> Ba2Cu2O5 + 0.5 O2 (dG = -0.225 eV/atom)
# 0.5 Y2O3 + CuO -> YCuO2 + 0.25 O2 (dG = 0.038 eV/atom)
# 4 BaO2 + 6 CuO -> O2 + 2 Ba2(CuO2)3 (dG = -0.231 eV/atom)
# 4 Ba2Cu2O5 + 4 YCuO2 -> O2 + 2 Ba4Y2Cu6O13 (dG = 0.024 eV/atom)
#
# Total Cost: 0.192 | Average Cost: 0.038
#
#
# Path 14:
# 2 BaO2 + 2 CuO -> Ba2Cu2O5 + 0.5 O2 (dG = -0.225 eV/atom)
# BaO2 + 3 CuO -> BaCu3O4 + 0.5 O2 (dG = -0.126 eV/atom)
# 0.5 Y2O3 + CuO -> YCuO2 + 0.25 O2 (dG = 0.038 eV/atom)
# 0.6667 BaCu3O4 + 1.333 BaO2 -> Ba2Cu2O5 + 0.1667 O2 (dG = -0.16 eV/atom)
# 4 Ba2Cu2O5 + 4 YCuO2 -> O2 + 2 Ba4Y2Cu6O13 (dG = 0.024 eV/atom)
#
# Total Cost: 0.192 | Average Cost: 0.038
#
#
# Path 15:
# 4 BaO2 + 6 CuO -> O2 + 2 Ba2(CuO2)3 (dG = -0.231 eV/atom)
# Y2O3 + 2 Ba2(CuO2)3 -> O2 + Ba4Y2Cu6O13 (dG = 0.075 eV/atom)
#
# Total Cost: 0.193 | Average Cost: 0.096
#
#
# Path 16:
# BaO2 + 3 CuO -> BaCu3O4 + 0.5 O2 (dG = -0.126 eV/atom)
# 0.5 Y2O3 + CuO -> YCuO2 + 0.25 O2 (dG = 0.038 eV/atom)
# 0.6667 BaCu3O4 + 1.333 BaO2 -> Ba2Cu2O5 + 0.1667 O2 (dG = -0.16 eV/atom)
# 4 Ba2Cu2O5 + 4 YCuO2 -> O2 + 2 Ba4Y2Cu6O13 (dG = 0.024 eV/atom)
#
# Total Cost: 0.193 | Average Cost: 0.048
#
#
# Path 17:
# 0.5 Y2O3 + 2 BaO2 -> O2 + 0.5 Ba4Y2O7 (dG = -0.007 eV/atom)
# Ba4Y2O7 + 6 CuO -> Ba4Y2Cu6O13 (dG = -0.137 eV/atom)
# 4 BaO2 + 6 CuO -> O2 + 2 Ba2(CuO2)3 (dG = -0.231 eV/atom)
# Y2O3 + 2 Ba2(CuO2)3 -> O2 + Ba4Y2Cu6O13 (dG = 0.075 eV/atom)
#
# Total Cost: 0.194 | Average Cost: 0.048
#
#
# Path 18:
# 0.5 Y2O3 + 2 BaO2 -> O2 + 0.5 Ba4Y2O7 (dG = -0.007 eV/atom)
# Ba4Y2O7 + 6 CuO -> Ba4Y2Cu6O13 (dG = -0.137 eV/atom)
# 2 BaO2 + 2 CuO -> Ba2Cu2O5 + 0.5 O2 (dG = -0.225 eV/atom)
# 0.5 Y2O3 + CuO -> YCuO2 + 0.25 O2 (dG = 0.038 eV/atom)
# 4 Ba2Cu2O5 + 4 YCuO2 -> O2 + 2 Ba4Y2Cu6O13 (dG = 0.024 eV/atom)
#
# Total Cost: 0.194 | Average Cost: 0.039
#
#
# Path 19:
# 0.5 Y2O3 + 2 BaO2 -> O2 + 0.5 Ba4Y2O7 (dG = -0.007 eV/atom)
# Ba4Y2O7 + 6 CuO -> Ba4Y2Cu6O13 (dG = -0.137 eV/atom)
#
# Total Cost: 0.196 | Average Cost: 0.098
#
#
# Path 20:
# 4 BaO2 + 6 CuO -> O2 + 2 Ba2(CuO2)3 (dG = -0.231 eV/atom)
# Y2O3 + 2 Ba2(CuO2)3 -> O2 + Ba4Y2Cu6O13 (dG = 0.075 eV/atom)
# 4 CuO -> Cu4O3 + 0.5 O2 (dG = 0.105 eV/atom)
# 16 BaO2 + 6 Cu4O3 -> O2 + 8 Ba2(CuO2)3 (dG = -0.303 eV/atom)
#
# Total Cost: 0.202 | Average Cost: 0.05
#
#
# Path 21:
# 0.5 Y2O3 + 2 BaO2 -> O2 + 0.5 Ba4Y2O7 (dG = -0.007 eV/atom)
# Ba4Y2O7 + 6 CuO -> Ba4Y2Cu6O13 (dG = -0.137 eV/atom)
# Y2O3 + 2 Ba2(CuO2)3 -> O2 + Ba4Y2Cu6O13 (dG = 0.075 eV/atom)
# 4 CuO -> Cu4O3 + 0.5 O2 (dG = 0.105 eV/atom)
# 16 BaO2 + 6 Cu4O3 -> O2 + 8 Ba2(CuO2)3 (dG = -0.303 eV/atom)
#
# Total Cost: 0.208 | Average Cost: 0.042
#
#
# Path 22:
# Y2O3 + 2 Ba2(CuO2)3 -> O2 + Ba4Y2Cu6O13 (dG = 0.075 eV/atom)
# 4 CuO -> Cu4O3 + 0.5 O2 (dG = 0.105 eV/atom)
# 16 BaO2 + 6 Cu4O3 -> O2 + 8 Ba2(CuO2)3 (dG = -0.303 eV/atom)
#
# Total Cost: 0.217 | Average Cost: 0.072

# %%
df = create_total_path_df(cleaned_paths)
df
# Out:
#                                                                    dG    cost
# path total_cost rxn
# 1    0.180      BaO2 + CuO -> BaCuO2 + 0.5 O2                 -0.1599  0.1772
#                 Ba4Y2O7 + 6 CuO -> Ba4Y2Cu6O13                -0.1367  0.1810
#                 3 Y2O3 + 12 BaCuO2 -> Ba4Y2O7 + 2 Ba4Y2Cu6O13  0.0385  0.2122
# 2    0.182      2 BaO2 + 2 CuO -> Ba2Cu2O5 + 0.5 O2           -0.2245  0.1670
#                 BaO2 + CuO -> BaCuO2 + 0.5 O2                 -0.1599  0.1772
# ...                                                               ...     ...
# 21   0.208      Y2O3 + 2 Ba2(CuO2)3 -> O2 + Ba4Y2Cu6O13        0.0749  0.2193
#                 4 CuO -> Cu4O3 + 0.5 O2                        0.1051  0.2253
# 22   0.217      16 BaO2 + 6 Cu4O3 -> O2 + 8 Ba2(CuO2)3        -0.3028  0.1554
#                 Y2O3 + 2 Ba2(CuO2)3 -> O2 + Ba4Y2Cu6O13        0.0749  0.2193
#                 4 CuO -> Cu4O3 + 0.5 O2                        0.1051  0.2253
#
# [91 rows x 2 columns]

# %% [markdown]
# ### Questions?

# %% [markdown]
# That's it! For any questions/issues, please feel free to post an _Issue_ on the Github repository: https://github.com/GENESIS-EFRC/reaction-network
